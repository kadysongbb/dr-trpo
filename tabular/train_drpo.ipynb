# %%
import gym
from datetime import datetime

# DR TRPO related files
from train_helper import *
from value import NNValueFunction
from utils import Logger
from dr_policy import DRPolicyKL, DRPolicyWass

# %% [markdown]
# # Discrete State Space - KL DRPO
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyKL(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 5000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-KL_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        policy.update(observes, actions, advantages, disc_freqs, env_name)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# WARNING:tensorflow:From /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# optimal beta is: 10.759811894736535
# WARNING:tensorflow:From /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# ***** Episode 60, Mean Return = -771.7, Mean Discounted Return = -39.9 *****
# ExplainedVarNew: -1.96e-09
# ExplainedVarOld: -7.42e-07
# ValFuncLoss: 698
#
#
# optimal beta is: 10.969617453913648
# ***** Episode 120, Mean Return = -743.3, Mean Discounted Return = -38.0 *****
# ExplainedVarNew: -1.17e-10
# ExplainedVarOld: -1.71e-09
# ValFuncLoss: 192
#
#
# optimal beta is: 10.362389125335996
# ***** Episode 180, Mean Return = -701.6, Mean Discounted Return = -37.4 *****
# ExplainedVarNew: -7.51e-11
# ExplainedVarOld: -1.35e-10
# ValFuncLoss: 116
#
#
# optimal beta is: 10.80828070634243
# ***** Episode 240, Mean Return = -677.1, Mean Discounted Return = -34.7 *****
# ExplainedVarNew: -6.3e-10
# ExplainedVarOld: -3.21e-10
# ValFuncLoss: 119
#
#
# optimal beta is: 10.807662990490586
# ***** Episode 300, Mean Return = -649.2, Mean Discounted Return = -34.8 *****
# ExplainedVarNew: -1.11e-07
# ExplainedVarOld: -1.51e-10
# ValFuncLoss: 118
#
#
# optimal beta is: 10.773430905150313
# ***** Episode 360, Mean Return = -640.8, Mean Discounted Return = -35.1 *****
# ExplainedVarNew: -0.00345
# ExplainedVarOld: -2.09e-07
# ValFuncLoss: 114
#
#
# optimal beta is: 10.697910680332136
# ***** Episode 420, Mean Return = -603.9, Mean Discounted Return = -34.1 *****
# ExplainedVarNew: -0.00177
# ExplainedVarOld: -0.00328
# ValFuncLoss: 101
#
#
# optimal beta is: 10.081171016581937
# ***** Episode 480, Mean Return = -576.7, Mean Discounted Return = -31.1 *****
# ExplainedVarNew: -0.00211
# ExplainedVarOld: -0.00196
# ValFuncLoss: 106
#
#
# optimal beta is: 10.573967915247563
# ***** Episode 540, Mean Return = -569.2, Mean Discounted Return = -28.9 *****
# ExplainedVarNew: -0.00307
# ExplainedVarOld: -0.00215
# ValFuncLoss: 104
#
#
# optimal beta is: 10.985439873220868
# ***** Episode 600, Mean Return = -510.0, Mean Discounted Return = -29.9 *****
# ExplainedVarNew: -0.00142
# ExplainedVarOld: -0.00543
# ValFuncLoss: 101
#
#
# optimal beta is: 10.777822629168183
# ***** Episode 660, Mean Return = -519.0, Mean Discounted Return = -29.6 *****
# ExplainedVarNew: -0.000227
# ExplainedVarOld: -0.000833
# ValFuncLoss: 95.9
#
#
# optimal beta is: 10.200833287402903
# ***** Episode 720, Mean Return = -440.7, Mean Discounted Return = -27.2 *****
# ExplainedVarNew: -0.000712
# ExplainedVarOld: -0.000565
# ValFuncLoss: 112
#
#
# optimal beta is: 10.4231539931422
# ***** Episode 780, Mean Return = -444.9, Mean Discounted Return = -26.6 *****
# ExplainedVarNew: -0.000476
# ExplainedVarOld: -0.00084
# ValFuncLoss: 97.4
#
#
# optimal beta is: 10.033042785918841
# ***** Episode 840, Mean Return = -410.6, Mean Discounted Return = -25.3 *****
# ExplainedVarNew: -0.000223
# ExplainedVarOld: -0.000323
# ValFuncLoss: 93.5
#
#
# optimal beta is: 10.737282061703448
# ***** Episode 900, Mean Return = -388.7, Mean Discounted Return = -25.1 *****
# ExplainedVarNew: -0.00204
# ExplainedVarOld: -0.000193
# ValFuncLoss: 86.1
#
#
# optimal beta is: 10.587876767749995
# ***** Episode 960, Mean Return = -354.9, Mean Discounted Return = -23.7 *****
# ExplainedVarNew: -0.00601
# ExplainedVarOld: -0.00554
# ValFuncLoss: 88.2
#
#
# optimal beta is: 9.79445261236844
# ***** Episode 1020, Mean Return = -345.6, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -0.00398
# ExplainedVarOld: -0.00652
# ValFuncLoss: 86.7
#
#
# optimal beta is: 9.912571639119756
# ***** Episode 1080, Mean Return = -308.9, Mean Discounted Return = -21.5 *****
# ExplainedVarNew: -0.0016
# ExplainedVarOld: -0.00216
# ValFuncLoss: 92.5
#
#
# optimal beta is: 9.016287034214015
# ***** Episode 1140, Mean Return = -304.0, Mean Discounted Return = -21.0 *****
# ExplainedVarNew: -0.00543
# ExplainedVarOld: -0.00518
# ValFuncLoss: 90.2
#
#
# optimal beta is: 8.864990120953271
# ***** Episode 1200, Mean Return = -287.9, Mean Discounted Return = -18.8 *****
# ExplainedVarNew: -0.00264
# ExplainedVarOld: -0.00292
# ValFuncLoss: 86.2
#
#
# optimal beta is: 9.379266790372093
# ***** Episode 1260, Mean Return = -248.6, Mean Discounted Return = -20.6 *****
# ExplainedVarNew: -0.00202
# ExplainedVarOld: -0.00254
# ValFuncLoss: 87.3
#
#
# optimal beta is: 9.73232467410229
# ***** Episode 1320, Mean Return = -239.1, Mean Discounted Return = -16.3 *****
# ExplainedVarNew: -0.00422
# ExplainedVarOld: -0.00332
# ValFuncLoss: 74.8
#
#
# optimal beta is: 9.263510358856532
# ***** Episode 1380, Mean Return = -210.0, Mean Discounted Return = -18.1 *****
# ExplainedVarNew: -0.00906
# ExplainedVarOld: -0.00335
# ValFuncLoss: 78.4
#
#
# optimal beta is: 9.066172236752829
# ***** Episode 1440, Mean Return = -198.0, Mean Discounted Return = -17.8 *****
# ExplainedVarNew: -0.0086
# ExplainedVarOld: -0.0133
# ValFuncLoss: 77.1
#
#
# optimal beta is: 8.515605788157359
# ***** Episode 1500, Mean Return = -195.0, Mean Discounted Return = -17.9 *****
# ExplainedVarNew: -0.00597
# ExplainedVarOld: -0.00672
# ValFuncLoss: 84.1
#
#
# optimal beta is: 8.295698473248693
# ***** Episode 1560, Mean Return = -170.3, Mean Discounted Return = -17.1 *****
# ExplainedVarNew: -0.00694
# ExplainedVarOld: -0.00392
# ValFuncLoss: 81.2
#
#
# optimal beta is: 8.35751866253696
# ***** Episode 1620, Mean Return = -185.9, Mean Discounted Return = -15.1 *****
# ExplainedVarNew: -0.0039
# ExplainedVarOld: -0.00408
# ValFuncLoss: 74.7
#
#
# optimal beta is: 7.959522987635553
# ***** Episode 1680, Mean Return = -137.9, Mean Discounted Return = -15.5 *****
# ExplainedVarNew: -0.00875
# ExplainedVarOld: -0.00692
# ValFuncLoss: 95.1
#
#
# optimal beta is: 7.665192772428563
# ***** Episode 1740, Mean Return = -125.9, Mean Discounted Return = -13.4 *****
# ExplainedVarNew: -0.00882
# ExplainedVarOld: -0.0159
# ValFuncLoss: 88.2
#
#
# optimal beta is: 7.662259724225123
# ***** Episode 1800, Mean Return = -113.0, Mean Discounted Return = -15.1 *****
# ExplainedVarNew: -0.0125
# ExplainedVarOld: -0.0124
# ValFuncLoss: 96.2
#
#
# optimal beta is: 7.999356376204582
# ***** Episode 1860, Mean Return = -105.8, Mean Discounted Return = -14.3 *****
# ExplainedVarNew: -0.0106
# ExplainedVarOld: -0.0116
# ValFuncLoss: 97.3
#
#
# optimal beta is: 8.478666920578306
# ***** Episode 1920, Mean Return = -122.0, Mean Discounted Return = -15.7 *****
# ExplainedVarNew: -0.00588
# ExplainedVarOld: -0.00558
# ValFuncLoss: 87.4
#
#
# optimal beta is: 7.327880125103059
# ***** Episode 1980, Mean Return = -93.3, Mean Discounted Return = -15.6 *****
# ExplainedVarNew: -0.00559
# ExplainedVarOld: -0.00551
# ValFuncLoss: 102
#
#
# optimal beta is: 6.9727655419438435
# ***** Episode 2040, Mean Return = -92.3, Mean Discounted Return = -11.7 *****
# ExplainedVarNew: -0.00512
# ExplainedVarOld: -0.00263
# ValFuncLoss: 96.7
#
#
# optimal beta is: 7.509187878234928
# ***** Episode 2100, Mean Return = -84.7, Mean Discounted Return = -13.4 *****
# ExplainedVarNew: -0.0115
# ExplainedVarOld: -0.0106
# ValFuncLoss: 96.9
#
#
# optimal beta is: 6.448538001152946
# ***** Episode 2160, Mean Return = -52.8, Mean Discounted Return = -10.0 *****
# ExplainedVarNew: -0.0161
# ExplainedVarOld: -0.0198
# ValFuncLoss: 111
#
#
# optimal beta is: 6.692909100110188
# ***** Episode 2220, Mean Return = -63.2, Mean Discounted Return = -11.7 *****
# ExplainedVarNew: -0.00977
# ExplainedVarOld: -0.00776
# ValFuncLoss: 109
#
#
# optimal beta is: 7.204802265287091
# ***** Episode 2280, Mean Return = -75.2, Mean Discounted Return = -10.9 *****
# ExplainedVarNew: -0.0121
# ExplainedVarOld: -0.00894
# ValFuncLoss: 109
#
#
# optimal beta is: 6.344683313308606
# ***** Episode 2340, Mean Return = -47.3, Mean Discounted Return = -11.7 *****
# ExplainedVarNew: -0.0114
# ExplainedVarOld: -0.00945
# ValFuncLoss: 132
#
#
# optimal beta is: 7.125496002460964
# ***** Episode 2400, Mean Return = -61.4, Mean Discounted Return = -12.8 *****
# ExplainedVarNew: -0.0219
# ExplainedVarOld: -0.0212
# ValFuncLoss: 111
# optimal beta is: 6.49715097948477
# ***** Episode 2460, Mean Return = -60.2, Mean Discounted Return = -10.7 *****
# ExplainedVarNew: -0.0124
# ExplainedVarOld: -0.0107
# ValFuncLoss: 117
#
#
# optimal beta is: 6.343450389757259
# ***** Episode 2520, Mean Return = -61.0, Mean Discounted Return = -11.4 *****
# ExplainedVarNew: -0.0233
# ExplainedVarOld: -0.0224
# ValFuncLoss: 121
#
#
# optimal beta is: 6.69513876269245
# ***** Episode 2580, Mean Return = -49.6, Mean Discounted Return = -10.4 *****
# ExplainedVarNew: -0.0319
# ExplainedVarOld: -0.0176
# ValFuncLoss: 135
#
#
# optimal beta is: 6.681701387126764
# ***** Episode 2640, Mean Return = -50.5, Mean Discounted Return = -12.0 *****
# ExplainedVarNew: -0.0322
# ExplainedVarOld: -0.0218
# ValFuncLoss: 113
#
#
# optimal beta is: 5.981690027084864
# ***** Episode 2700, Mean Return = -47.0, Mean Discounted Return = -11.6 *****
# ExplainedVarNew: -0.0412
# ExplainedVarOld: -0.0615
# ValFuncLoss: 128
#
#
# optimal beta is: 5.28836279321935
# ***** Episode 2760, Mean Return = -29.4, Mean Discounted Return = -9.6 *****
# ExplainedVarNew: -0.0454
# ExplainedVarOld: -0.0337
# ValFuncLoss: 140
#
#
# optimal beta is: 6.489956850077493
# ***** Episode 2820, Mean Return = -33.4, Mean Discounted Return = -10.2 *****
# ExplainedVarNew: -0.0609
# ExplainedVarOld: -0.0601
# ValFuncLoss: 132
#
#
# optimal beta is: 6.75449089137385
# ***** Episode 2880, Mean Return = -63.2, Mean Discounted Return = -11.1 *****
# ExplainedVarNew: -0.063
# ExplainedVarOld: -0.075
# ValFuncLoss: 122
#
#
# optimal beta is: 6.198694339402415
# ***** Episode 2940, Mean Return = -43.3, Mean Discounted Return = -9.9 *****
# ExplainedVarNew: -0.0479
# ExplainedVarOld: -0.047
# ValFuncLoss: 133
#
#
# optimal beta is: 5.568849940194384
# ***** Episode 3000, Mean Return = -25.7, Mean Discounted Return = -8.6 *****
# ExplainedVarNew: -0.0584
# ExplainedVarOld: -0.0787
# ValFuncLoss: 142
#
#
# optimal beta is: 5.421449434977385
# ***** Episode 3060, Mean Return = -41.9, Mean Discounted Return = -9.4 *****
# ExplainedVarNew: -0.038
# ExplainedVarOld: -0.0347
# ValFuncLoss: 127
#
#
# optimal beta is: 5.074638798478015
# ***** Episode 3120, Mean Return = -20.4, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.0649
# ExplainedVarOld: -0.0682
# ValFuncLoss: 140
#
#
# optimal beta is: 5.419028183400405
# ***** Episode 3180, Mean Return = -42.0, Mean Discounted Return = -9.0 *****
# ExplainedVarNew: -0.0557
# ExplainedVarOld: -0.0667
# ValFuncLoss: 145
#
#
# optimal beta is: 4.602257501103814
# ***** Episode 3240, Mean Return = -27.4, Mean Discounted Return = -7.9 *****
# ExplainedVarNew: -0.0373
# ExplainedVarOld: -0.0498
# ValFuncLoss: 144
#
#
# optimal beta is: 5.486032006315927
# ***** Episode 3300, Mean Return = -15.1, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.0416
# ExplainedVarOld: -0.0501
# ValFuncLoss: 145
#
#
# optimal beta is: 5.957949109130145
# ***** Episode 3360, Mean Return = -27.4, Mean Discounted Return = -8.6 *****
# ExplainedVarNew: -0.0573
# ExplainedVarOld: -0.046
# ValFuncLoss: 137
#
#
# optimal beta is: 4.852962052863665
# ***** Episode 3420, Mean Return = -15.8, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0581
# ExplainedVarOld: -0.0523
# ValFuncLoss: 147
#
#
# optimal beta is: 5.813021705370061
# ***** Episode 3480, Mean Return = -34.9, Mean Discounted Return = -8.1 *****
# ExplainedVarNew: -0.0581
# ExplainedVarOld: -0.0557
# ValFuncLoss: 136
#
#
# optimal beta is: 4.727232683597028
# ***** Episode 3540, Mean Return = -27.9, Mean Discounted Return = -7.0 *****
# ExplainedVarNew: -0.0584
# ExplainedVarOld: -0.0572
# ValFuncLoss: 149
#
#
# optimal beta is: 5.281159235161591
# ***** Episode 3600, Mean Return = -12.2, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.0377
# ExplainedVarOld: -0.0574
# ValFuncLoss: 158
#
#
# optimal beta is: 5.720384194600263
# ***** Episode 3660, Mean Return = -11.5, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0478
# ExplainedVarOld: -0.0529
# ValFuncLoss: 137
#
#
# optimal beta is: 4.8456405459832235
# ***** Episode 3720, Mean Return = -35.6, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0646
# ExplainedVarOld: -0.0439
# ValFuncLoss: 148
#
#
# optimal beta is: 5.3089003480822825
# ***** Episode 3780, Mean Return = -22.6, Mean Discounted Return = -9.7 *****
# ExplainedVarNew: -0.0685
# ExplainedVarOld: -0.0807
# ValFuncLoss: 142
#
#
# optimal beta is: 5.1634284300092
# ***** Episode 3840, Mean Return = -24.9, Mean Discounted Return = -9.5 *****
# ExplainedVarNew: -0.0415
# ExplainedVarOld: -0.0754
# ValFuncLoss: 149
#
#
# optimal beta is: 4.935745862323735
# ***** Episode 3900, Mean Return = -25.8, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.0336
# ExplainedVarOld: -0.0317
# ValFuncLoss: 167
#
#
# optimal beta is: 4.782694085148771
# ***** Episode 3960, Mean Return = -20.1, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.028
# ExplainedVarOld: -0.0276
# ValFuncLoss: 152
#
#
# optimal beta is: 5.510641290670947
# ***** Episode 4020, Mean Return = -13.0, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.0394
# ExplainedVarOld: -0.0409
# ValFuncLoss: 153
#
#
# optimal beta is: 4.20440134724758
# ***** Episode 4080, Mean Return = -25.6, Mean Discounted Return = -6.4 *****
# ExplainedVarNew: -0.0562
# ExplainedVarOld: -0.0438
# ValFuncLoss: 146
#
#
# optimal beta is: 4.377110797280358
# ***** Episode 4140, Mean Return = -12.4, Mean Discounted Return = -6.9 *****
# ExplainedVarNew: -0.0357
# ExplainedVarOld: -0.0361
# ValFuncLoss: 159
#
#
# optimal beta is: 4.676608092597594
# ***** Episode 4200, Mean Return = -16.2, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0554
# ExplainedVarOld: -0.0541
# ValFuncLoss: 155
#
#
# optimal beta is: 6.351476407911668
# ***** Episode 4260, Mean Return = -10.9, Mean Discounted Return = -7.8 *****
# ExplainedVarNew: -0.0474
# ExplainedVarOld: -0.0561
# ValFuncLoss: 139
#
#
# optimal beta is: 5.396268930157922
# ***** Episode 4320, Mean Return = -9.9, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0573
# ExplainedVarOld: -0.0544
# ValFuncLoss: 174
#
#
# optimal beta is: 4.318004202363806
# ***** Episode 4380, Mean Return = -20.9, Mean Discounted Return = -6.4 *****
# ExplainedVarNew: -0.0387
# ExplainedVarOld: -0.0399
# ValFuncLoss: 166
#
#
# optimal beta is: 5.065789952310841
# ***** Episode 4440, Mean Return = -17.8, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.039
# ExplainedVarOld: -0.0485
# ValFuncLoss: 151
#
#
# optimal beta is: 5.4819536757094385
# ***** Episode 4500, Mean Return = -11.1, Mean Discounted Return = -7.9 *****
# ExplainedVarNew: -0.0446
# ExplainedVarOld: -0.0303
# ValFuncLoss: 157
#
#
# optimal beta is: 4.398990629925694
# ***** Episode 4560, Mean Return = -14.4, Mean Discounted Return = -6.0 *****
# ExplainedVarNew: -0.0271
# ExplainedVarOld: -0.0375
# ValFuncLoss: 159
#
#
# optimal beta is: 4.359722489474184
# ***** Episode 4620, Mean Return = -13.4, Mean Discounted Return = -7.2 *****
# ExplainedVarNew: -0.0662
# ExplainedVarOld: -0.0377
# ValFuncLoss: 189
#
#
# optimal beta is: 5.515781138034559
# ***** Episode 4680, Mean Return = -2.2, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -0.071
# ExplainedVarOld: -0.103
# ValFuncLoss: 137
#
#
# optimal beta is: 5.128364405160799
# ***** Episode 4740, Mean Return = -2.2, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0421
# ExplainedVarOld: -0.0743
# ValFuncLoss: 136
#
#
# optimal beta is: 4.638377977152361
# ***** Episode 4800, Mean Return = -11.9, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.0264
# ExplainedVarOld: -0.0179
# ValFuncLoss: 150
#
#
# optimal beta is: 4.554098278705628
# ***** Episode 4860, Mean Return = -12.9, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.0508
# ExplainedVarOld: -0.0426
# ValFuncLoss: 164
#
#
# optimal beta is: 4.384637558293894
# ***** Episode 4920, Mean Return = -21.6, Mean Discounted Return = -8.7 *****
# ExplainedVarNew: -0.0396
# ExplainedVarOld: -0.0363
# ValFuncLoss: 168
#
#
# optimal beta is: 4.514106103191653
# ***** Episode 4980, Mean Return = -12.3, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.0429
# ExplainedVarOld: -0.0398
# ValFuncLoss: 189
#
#
# optimal beta is: 4.38749383157436
# ***** Episode 5040, Mean Return = -6.8, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0354
# ExplainedVarOld: -0.0481
# ValFuncLoss: 160

# %%
total_length = 0
total_success_dropoff = 0
total_illegal_action = 0
for i in range(1000):
    illegal_action, success_dropoff, eps_length = episode_stats(env, policy)
    total_illegal_action += illegal_action
    total_success_dropoff += success_dropoff
    total_length += eps_length
    print('------------------------')
print(total_illegal_action/1000)
print(total_success_dropoff/1000)
print(total_length/1000)

# %% [markdown]
# # Discrete State Space - Wasserstein DRPO
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyWass(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 5000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-Wass_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs, env_name, eps)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# WARNING:tensorflow:From /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# optimal beta is: 3.3667469155807015
# WARNING:tensorflow:From /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# ***** Episode 60, Mean Return = -751.1, Mean Discounted Return = -36.8 *****
# ExplainedVarNew: -9.55e-10
# ExplainedVarOld: -1.88e-05
# ValFuncLoss: 707
#
#
# optimal beta is: 3.1700309639963336
# ***** Episode 120, Mean Return = -751.2, Mean Discounted Return = -38.3 *****
# ExplainedVarNew: -1.12e-10
# ExplainedVarOld: -1.9e-09
# ValFuncLoss: 225
#
#
# optimal beta is: 2.956200697425149
# ***** Episode 180, Mean Return = -722.1, Mean Discounted Return = -38.2 *****
# ExplainedVarNew: -9.88e-11
# ExplainedVarOld: -2.37e-10
# ValFuncLoss: 155
#
#
# optimal beta is: 3.0488891966421092
# ***** Episode 240, Mean Return = -728.0, Mean Discounted Return = -40.0 *****
# ExplainedVarNew: -1.25e-10
# ExplainedVarOld: -1.43e-10
# ValFuncLoss: 131
#
#
# optimal beta is: 3.108267867238275
# ***** Episode 300, Mean Return = -697.0, Mean Discounted Return = -39.7 *****
# ExplainedVarNew: -1.55e-10
# ExplainedVarOld: -6.51e-11
# ValFuncLoss: 169
#
#
# optimal beta is: 3.101159075257482
# ***** Episode 360, Mean Return = -652.6, Mean Discounted Return = -36.9 *****
# ExplainedVarNew: -0.000488
# ExplainedVarOld: -1.2e-10
# ValFuncLoss: 174
#
#
# optimal beta is: 2.8984766090428358
# ***** Episode 420, Mean Return = -659.0, Mean Discounted Return = -37.2 *****
# ExplainedVarNew: -0.0533
# ExplainedVarOld: -0.000494
# ValFuncLoss: 179
#
#
# optimal beta is: 3.027019447667014
# ***** Episode 480, Mean Return = -616.2, Mean Discounted Return = -35.2 *****
# ExplainedVarNew: -0.11
# ExplainedVarOld: -0.0431
# ValFuncLoss: 211
#
#
# optimal beta is: 3.3007211058849153
# ***** Episode 540, Mean Return = -653.4, Mean Discounted Return = -36.6 *****
# ExplainedVarNew: -0.0276
# ExplainedVarOld: -0.0548
# ValFuncLoss: 154
#
#
# optimal beta is: 2.941398900017308
# ***** Episode 600, Mean Return = -592.7, Mean Discounted Return = -39.5 *****
# ExplainedVarNew: -0.00204
# ExplainedVarOld: -0.051
# ValFuncLoss: 192
#
#
# optimal beta is: 2.6013503429609335
# ***** Episode 660, Mean Return = -511.5, Mean Discounted Return = -37.0 *****
# ExplainedVarNew: -0.00478
# ExplainedVarOld: -0.00415
# ValFuncLoss: 221
#
#
# optimal beta is: 3.181702013239808
# ***** Episode 720, Mean Return = -504.5, Mean Discounted Return = -33.5 *****
# ExplainedVarNew: -0.00197
# ExplainedVarOld: -0.00244
# ValFuncLoss: 233
#
#
# optimal beta is: 2.4210123709672677
# ***** Episode 780, Mean Return = -495.7, Mean Discounted Return = -34.1 *****
# ExplainedVarNew: -0.000592
# ExplainedVarOld: -0.000645
# ValFuncLoss: 230
#
#
# optimal beta is: 2.809495538161104
# ***** Episode 840, Mean Return = -484.2, Mean Discounted Return = -34.3 *****
# ExplainedVarNew: -0.00256
# ExplainedVarOld: -0.00108
# ValFuncLoss: 223
#
#
# optimal beta is: 3.1513261100361465
# ***** Episode 900, Mean Return = -543.4, Mean Discounted Return = -32.3 *****
# ExplainedVarNew: -0.00331
# ExplainedVarOld: -0.00375
# ValFuncLoss: 221
#
#
# optimal beta is: 3.829647604198063
# ***** Episode 960, Mean Return = -566.5, Mean Discounted Return = -35.8 *****
# ExplainedVarNew: -0.00692
# ExplainedVarOld: -0.00344
# ValFuncLoss: 187
#
#
# ***** Episode 1020, Mean Return = -559.7, Mean Discounted Return = -36.4 *****
# ExplainedVarNew: -0.00965
# ExplainedVarOld: -0.00573
# ValFuncLoss: 193
#
#
# ***** Episode 1080, Mean Return = -388.0, Mean Discounted Return = -32.0 *****
# ExplainedVarNew: -0.0196
# ExplainedVarOld: -0.00926
# ValFuncLoss: 270
#
#
# ***** Episode 1140, Mean Return = -353.1, Mean Discounted Return = -26.8 *****
# ExplainedVarNew: -0.0281
# ExplainedVarOld: -0.0375
# ValFuncLoss: 269
#
#
# ***** Episode 1200, Mean Return = -402.5, Mean Discounted Return = -30.3 *****
# ExplainedVarNew: -0.036
# ExplainedVarOld: -0.0268
# ValFuncLoss: 240
#
#
# ***** Episode 1260, Mean Return = -378.3, Mean Discounted Return = -29.3 *****
# ExplainedVarNew: -0.0489
# ExplainedVarOld: -0.055
# ValFuncLoss: 244
#
#
# ***** Episode 1320, Mean Return = -361.3, Mean Discounted Return = -26.9 *****
# ExplainedVarNew: -0.073
# ExplainedVarOld: -0.052
# ValFuncLoss: 284
#
#
# ***** Episode 1380, Mean Return = -250.3, Mean Discounted Return = -21.0 *****
# ExplainedVarNew: -0.0362
# ExplainedVarOld: -0.0419
# ValFuncLoss: 308
#
#
# ***** Episode 1440, Mean Return = -268.4, Mean Discounted Return = -27.1 *****
# ExplainedVarNew: -0.00864
# ExplainedVarOld: -0.011
# ValFuncLoss: 315
#
#
# ***** Episode 1500, Mean Return = -260.9, Mean Discounted Return = -25.0 *****
# ExplainedVarNew: -0.0477
# ExplainedVarOld: -0.0126
# ValFuncLoss: 306
#
#
# ***** Episode 1560, Mean Return = -179.3, Mean Discounted Return = -22.9 *****
# ExplainedVarNew: -0.0276
# ExplainedVarOld: -0.0191
# ValFuncLoss: 389
#
#
# ***** Episode 1620, Mean Return = -193.8, Mean Discounted Return = -20.3 *****
# ExplainedVarNew: -0.0504
# ExplainedVarOld: -0.0287
# ValFuncLoss: 365
#
#
# ***** Episode 1680, Mean Return = -205.8, Mean Discounted Return = -23.9 *****
# ExplainedVarNew: -0.0443
# ExplainedVarOld: -0.0441
# ValFuncLoss: 296
#
#
# ***** Episode 1740, Mean Return = -192.1, Mean Discounted Return = -20.0 *****
# ExplainedVarNew: -0.0548
# ExplainedVarOld: -0.0592
# ValFuncLoss: 328
#
#
# ***** Episode 1800, Mean Return = -181.9, Mean Discounted Return = -23.1 *****
# ExplainedVarNew: -0.0428
# ExplainedVarOld: -0.0591
# ValFuncLoss: 366
#
#
# ***** Episode 1860, Mean Return = -169.9, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -0.0295
# ExplainedVarOld: -0.0267
# ValFuncLoss: 345
#
#
# ***** Episode 1920, Mean Return = -176.2, Mean Discounted Return = -19.6 *****
# ExplainedVarNew: -0.0388
# ExplainedVarOld: -0.0338
# ValFuncLoss: 322
#
#
# ***** Episode 1980, Mean Return = -125.0, Mean Discounted Return = -17.9 *****
# ExplainedVarNew: -0.057
# ExplainedVarOld: -0.0593
# ValFuncLoss: 377
#
#
# ***** Episode 2040, Mean Return = -188.9, Mean Discounted Return = -19.1 *****
# ExplainedVarNew: -0.0897
# ExplainedVarOld: -0.0947
# ValFuncLoss: 296
#
#
# ***** Episode 2100, Mean Return = -157.7, Mean Discounted Return = -21.4 *****
# ExplainedVarNew: -0.0505
# ExplainedVarOld: -0.0474
# ValFuncLoss: 358
#
#
# ***** Episode 2160, Mean Return = -157.4, Mean Discounted Return = -15.9 *****
# ExplainedVarNew: -0.0389
# ExplainedVarOld: -0.0351
# ValFuncLoss: 333
#
#
# ***** Episode 2220, Mean Return = -140.0, Mean Discounted Return = -17.4 *****
# ExplainedVarNew: -0.0474
# ExplainedVarOld: -0.0445
# ValFuncLoss: 311
#
#
# ***** Episode 2280, Mean Return = -134.1, Mean Discounted Return = -17.4 *****
# ExplainedVarNew: -0.0955
# ExplainedVarOld: -0.0838
# ValFuncLoss: 384
#
#
# ***** Episode 2340, Mean Return = -127.8, Mean Discounted Return = -17.3 *****
# ExplainedVarNew: -0.0569
# ExplainedVarOld: -0.0713
# ValFuncLoss: 347
#
#
# ***** Episode 2400, Mean Return = -141.0, Mean Discounted Return = -18.2 *****
# ExplainedVarNew: -0.0699
# ExplainedVarOld: -0.0809
# ValFuncLoss: 317
#
#
# ***** Episode 2460, Mean Return = -141.1, Mean Discounted Return = -19.9 *****
# ExplainedVarNew: -0.0605
# ExplainedVarOld: -0.0579
# ValFuncLoss: 315
#
#
# ***** Episode 2520, Mean Return = -144.0, Mean Discounted Return = -20.0 *****
# ExplainedVarNew: -0.102
# ExplainedVarOld: -0.0947
# ValFuncLoss: 344
#
#
# ***** Episode 2580, Mean Return = -94.1, Mean Discounted Return = -20.4 *****
# ExplainedVarNew: -0.0789
# ExplainedVarOld: -0.109
# ValFuncLoss: 377
#
#
# ***** Episode 2640, Mean Return = -139.2, Mean Discounted Return = -20.6 *****
# ExplainedVarNew: -0.046
# ExplainedVarOld: -0.0428
# ValFuncLoss: 358
#
#
# ***** Episode 2700, Mean Return = -125.1, Mean Discounted Return = -20.0 *****
# ExplainedVarNew: -0.0722
# ExplainedVarOld: -0.0679
# ValFuncLoss: 326
#
#
# ***** Episode 2760, Mean Return = -126.8, Mean Discounted Return = -19.5 *****
# ExplainedVarNew: -0.0613
# ExplainedVarOld: -0.0571
# ValFuncLoss: 368
# ***** Episode 2820, Mean Return = -166.4, Mean Discounted Return = -19.8 *****
# ExplainedVarNew: -0.0514
# ExplainedVarOld: -0.0577
# ValFuncLoss: 314
#
#
# ***** Episode 2880, Mean Return = -118.7, Mean Discounted Return = -19.3 *****
# ExplainedVarNew: -0.0593
# ExplainedVarOld: -0.0838
# ValFuncLoss: 364
#
#
# ***** Episode 2940, Mean Return = -150.7, Mean Discounted Return = -20.2 *****
# ExplainedVarNew: -0.0558
# ExplainedVarOld: -0.0755
# ValFuncLoss: 252
#
#
# ***** Episode 3000, Mean Return = -105.0, Mean Discounted Return = -17.3 *****
# ExplainedVarNew: -0.0562
# ExplainedVarOld: -0.0683
# ValFuncLoss: 348
#
#
# ***** Episode 3060, Mean Return = -138.1, Mean Discounted Return = -17.1 *****
# ExplainedVarNew: -0.0596
# ExplainedVarOld: -0.0494
# ValFuncLoss: 322
#
#
# ***** Episode 3120, Mean Return = -112.1, Mean Discounted Return = -17.3 *****
# ExplainedVarNew: -0.0762
# ExplainedVarOld: -0.0619
# ValFuncLoss: 342
#
#
# ***** Episode 3180, Mean Return = -131.8, Mean Discounted Return = -18.9 *****
# ExplainedVarNew: -0.0812
# ExplainedVarOld: -0.11
# ValFuncLoss: 291
#
#
# ***** Episode 3240, Mean Return = -60.7, Mean Discounted Return = -12.9 *****
# ExplainedVarNew: -0.0497
# ExplainedVarOld: -0.0583
# ValFuncLoss: 299
#
#
# ***** Episode 3300, Mean Return = -150.6, Mean Discounted Return = -18.1 *****
# ExplainedVarNew: -0.0485
# ExplainedVarOld: -0.0493
# ValFuncLoss: 274
#
#
# ***** Episode 3360, Mean Return = -61.2, Mean Discounted Return = -12.9 *****
# ExplainedVarNew: -0.0636
# ExplainedVarOld: -0.0622
# ValFuncLoss: 359
#
#
# ***** Episode 3420, Mean Return = -116.7, Mean Discounted Return = -15.0 *****
# ExplainedVarNew: -0.0653
# ExplainedVarOld: -0.0651
# ValFuncLoss: 313
#
#
# ***** Episode 3480, Mean Return = -101.8, Mean Discounted Return = -12.9 *****
# ExplainedVarNew: -0.0687
# ExplainedVarOld: -0.0663
# ValFuncLoss: 355
#
#
# ***** Episode 3540, Mean Return = -142.3, Mean Discounted Return = -21.1 *****
# ExplainedVarNew: -0.0713
# ExplainedVarOld: -0.0936
# ValFuncLoss: 284
#
#
# ***** Episode 3600, Mean Return = -134.9, Mean Discounted Return = -15.9 *****
# ExplainedVarNew: -0.0597
# ExplainedVarOld: -0.0631
# ValFuncLoss: 288
#
#
# ***** Episode 3660, Mean Return = -77.1, Mean Discounted Return = -16.2 *****
# ExplainedVarNew: -0.0816
# ExplainedVarOld: -0.0864
# ValFuncLoss: 305
#
#
# ***** Episode 3720, Mean Return = -109.4, Mean Discounted Return = -17.6 *****
# ExplainedVarNew: -0.0548
# ExplainedVarOld: -0.056
# ValFuncLoss: 292
#
#
# ***** Episode 3780, Mean Return = -111.6, Mean Discounted Return = -13.9 *****
# ExplainedVarNew: -0.0703
# ExplainedVarOld: -0.0805
# ValFuncLoss: 290
#
#
# ***** Episode 3840, Mean Return = -94.9, Mean Discounted Return = -16.2 *****
# ExplainedVarNew: -0.0909
# ExplainedVarOld: -0.0854
# ValFuncLoss: 348
#
#
# ***** Episode 3900, Mean Return = -142.4, Mean Discounted Return = -17.7 *****
# ExplainedVarNew: -0.0625
# ExplainedVarOld: -0.0579
# ValFuncLoss: 270
#
#
# ***** Episode 3960, Mean Return = -81.9, Mean Discounted Return = -15.6 *****
# ExplainedVarNew: -0.0664
# ExplainedVarOld: -0.0638
# ValFuncLoss: 292
#
#
# ***** Episode 4020, Mean Return = -67.3, Mean Discounted Return = -14.9 *****
# ExplainedVarNew: -0.0415
# ExplainedVarOld: -0.0693
# ValFuncLoss: 284
#
#
# ***** Episode 4080, Mean Return = -76.1, Mean Discounted Return = -17.1 *****
# ExplainedVarNew: -0.0415
# ExplainedVarOld: -0.0574
# ValFuncLoss: 337
#
#
# ***** Episode 4140, Mean Return = -77.9, Mean Discounted Return = -14.1 *****
# ExplainedVarNew: -0.0679
# ExplainedVarOld: -0.0436
# ValFuncLoss: 322
#
#
# ***** Episode 4200, Mean Return = -80.9, Mean Discounted Return = -16.0 *****
# ExplainedVarNew: -0.0711
# ExplainedVarOld: -0.0601
# ValFuncLoss: 303
#
#
# ***** Episode 4260, Mean Return = -87.1, Mean Discounted Return = -18.2 *****
# ExplainedVarNew: -0.0832
# ExplainedVarOld: -0.1
# ValFuncLoss: 265
#
#
# ***** Episode 4320, Mean Return = -85.1, Mean Discounted Return = -12.4 *****
# ExplainedVarNew: -0.0387
# ExplainedVarOld: -0.0491
# ValFuncLoss: 281
#
#
# ***** Episode 4380, Mean Return = -71.8, Mean Discounted Return = -12.1 *****
# ExplainedVarNew: -0.061
# ExplainedVarOld: -0.0532
# ValFuncLoss: 254
#
#
# ***** Episode 4440, Mean Return = -104.5, Mean Discounted Return = -14.6 *****
# ExplainedVarNew: -0.0619
# ExplainedVarOld: -0.0567
# ValFuncLoss: 386
#
#
# ***** Episode 4500, Mean Return = -103.4, Mean Discounted Return = -14.9 *****
# ExplainedVarNew: -0.105
# ExplainedVarOld: -0.0993
# ValFuncLoss: 281
#
#
# ***** Episode 4560, Mean Return = -51.9, Mean Discounted Return = -11.5 *****
# ExplainedVarNew: -0.064
# ExplainedVarOld: -0.0848
# ValFuncLoss: 236
#
#
# ***** Episode 4620, Mean Return = -127.8, Mean Discounted Return = -15.7 *****
# ExplainedVarNew: -0.0321
# ExplainedVarOld: -0.029
# ValFuncLoss: 248
#
#
# ***** Episode 4680, Mean Return = -88.7, Mean Discounted Return = -13.0 *****
# ExplainedVarNew: -0.065
# ExplainedVarOld: -0.059
# ValFuncLoss: 255
#
#
# ***** Episode 4740, Mean Return = -79.6, Mean Discounted Return = -14.2 *****
# ExplainedVarNew: -0.056
# ExplainedVarOld: -0.0771
# ValFuncLoss: 292
#
#
# ***** Episode 4800, Mean Return = -73.6, Mean Discounted Return = -12.4 *****
# ExplainedVarNew: -0.0547
# ExplainedVarOld: -0.246
# ValFuncLoss: 216
#
#
# ***** Episode 4860, Mean Return = -104.1, Mean Discounted Return = -13.8 *****
# ExplainedVarNew: -0.0676
# ExplainedVarOld: -0.0493
# ValFuncLoss: 234
#
#
# ***** Episode 4920, Mean Return = -95.1, Mean Discounted Return = -14.0 *****
# ExplainedVarNew: -0.076
# ExplainedVarOld: -0.0869
# ValFuncLoss: 221
#
#
# ***** Episode 4980, Mean Return = -91.0, Mean Discounted Return = -13.1 *****
# ExplainedVarNew: -0.0416
# ExplainedVarOld: -0.0482
# ValFuncLoss: 209
#
#
# ***** Episode 5040, Mean Return = -77.5, Mean Discounted Return = -14.0 *****
# ExplainedVarNew: -0.0685
# ExplainedVarOld: -0.0618
# ValFuncLoss: 232

# %%
total_length = 0
total_success_dropoff = 0
total_illegal_action = 0
for i in range(1000):
    illegal_action, success_dropoff, eps_length = episode_stats(env, policy)
    total_illegal_action += illegal_action
    total_success_dropoff += success_dropoff
    total_length += eps_length
    print('------------------------')
print(total_illegal_action/1000)
print(total_success_dropoff/1000)
print(total_length/1000)
