# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines.bench import Monitor
from stable_baselines.common.policies import MlpPolicy
from stable_baselines import results_plotter
from stable_baselines import *

# %%
import gym
import numpy as np

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make('CartPole-v1')
env = Monitor(env, log_dir, allow_early_resets=True)

model = TRPO(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 50000
model.learn(total_timesteps=time_steps)
# Out:
# ********** Iteration 0 ************
# Optimizing Policy...
# sampling
# done in 0.289 seconds
# computegrad
# done in 0.116 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0731          0
#          1   0.000591      0.197
#          2   0.000155      0.211
#          3    3.7e-06       0.43
#          4   1.45e-07      0.467
#          5   1.62e-06      0.467
#          6   7.84e-10       0.47
#          7   7.38e-09       0.47
#          8   2.57e-12       0.47
# done in 0.152 seconds
# Expected: 0.034 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.063 seconds
# -----------------------------------------
# | EpLenMean               | 21.9        |
# | EpRewMean               | 21.9        |
# | EpThisIter              | 44          |
# | EpisodesSoFar           | 44          |
# | TimeElapsed             | 0.692       |
# | TimestepsSoFar          | 1024        |
# | entloss                 | 0.0         |
# | entropy                 | 0.6837654   |
# | explained_variance_t... | -0.000327   |
# | meankl                  | 0.00969729  |
# | optimgain               | 0.033751436 |
# | surrgain                | 0.033751436 |
# -----------------------------------------
# ********** Iteration 1 ************
# Optimizing Policy...
# sampling
# done in 0.239 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0447          0
#          1    0.00121      0.186
#          2   0.000772      0.347
#          3   3.75e-05      0.393
#          4    1.4e-06      0.494
#          5   5.72e-07      0.515
#          6   8.92e-09      0.515
#          7    9.2e-11      0.515
# done in 0.009 seconds
# Expected: 0.032 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 28.9        |
# | EpRewMean               | 28.9        |
# | EpThisIter              | 36          |
# | EpisodesSoFar           | 80          |
# | TimeElapsed             | 0.976       |
# | TimestepsSoFar          | 2048        |
# | entloss                 | 0.0         |
# | entropy                 | 0.65877736  |
# | explained_variance_t... | 0.00513     |
# | meankl                  | 0.010628972 |
# | optimgain               | 0.03386791  |
# | surrgain                | 0.03386791  |
# -----------------------------------------
# ********** Iteration 2 ************
# Optimizing Policy...
# sampling
# done in 0.234 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0146          0
#          1    0.00444      0.168
#          2    0.00159      0.353
#          3    0.00018      0.397
#          4   1.11e-05      0.501
#          5   1.21e-07      0.583
#          6   6.39e-09      0.586
#          7   2.92e-10      0.586
#          8   5.17e-10      0.586
#          9   5.43e-11      0.586
# done in 0.013 seconds
# Expected: 0.028 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 37.5        |
# | EpRewMean               | 37.5        |
# | EpThisIter              | 23          |
# | EpisodesSoFar           | 103         |
# | TimeElapsed             | 1.26        |
# | TimestepsSoFar          | 3072        |
# | entloss                 | 0.0         |
# | entropy                 | 0.62640077  |
# | explained_variance_t... | 0.00407     |
# | meankl                  | 0.010753147 |
# | optimgain               | 0.029929476 |
# | surrgain                | 0.029929476 |
# -----------------------------------------
# ********** Iteration 3 ************
# Optimizing Policy...
# sampling
# done in 0.237 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.027          0
#          1    0.00216        0.1
#          2    0.00268      0.204
#          3    0.00125      0.279
#          4   0.000271      0.418
#          5   5.85e-06       0.84
#          6   4.35e-07      0.868
#          7   6.99e-06      0.869
#          8   9.05e-07      0.873
#          9   4.89e-09      0.873
#         10   2.64e-08      0.873
# done in 0.014 seconds
# Expected: 0.028 Actual: 0.028
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 51.2        |
# | EpRewMean               | 51.2        |
# | EpThisIter              | 15          |
# | EpisodesSoFar           | 118         |
# | TimeElapsed             | 1.55        |
# | TimestepsSoFar          | 4096        |
# | entloss                 | 0.0         |
# | entropy                 | 0.6087533   |
# | explained_variance_t... | -0.00232    |
# | meankl                  | 0.009552833 |
# | optimgain               | 0.027805692 |
# | surrgain                | 0.027805692 |
# -----------------------------------------
# ********** Iteration 4 ************
# Optimizing Policy...
# sampling
# done in 0.236 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0633          0
#          1    0.00402      0.116
#          2    0.00371      0.275
#          3    0.00266      0.318
#          4    0.00085      0.575
#          5   5.07e-05      0.882
#          6   7.46e-06      0.968
#          7   0.000198       0.98
#          8    1.2e-06          1
#          9    4.7e-06          1
#         10   2.96e-07       1.01
# done in 0.013 seconds
# Expected: 0.037 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 70.3        |
# | EpRewMean               | 70.3        |
# | EpThisIter              | 7           |
# | EpisodesSoFar           | 125         |
# | TimeElapsed             | 1.83        |
# | TimestepsSoFar          | 5120        |
# | entloss                 | 0.0         |
# | entropy                 | 0.58667624  |
# | explained_variance_t... | -0.00655    |
# | meankl                  | 0.010971978 |
# | optimgain               | 0.03406947  |
# | surrgain                | 0.03406947  |
# -----------------------------------------
# ********** Iteration 5 ************
# Optimizing Policy...
# sampling
# done in 0.234 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0225          0
#          1    0.00444     0.0546
#          2   0.000672     0.0755
#          3    0.00156     0.0874
#          4   0.000305      0.244
#          5   1.34e-05      0.485
#          6   1.47e-06       0.55
#          7   4.34e-05      0.554
#          8   1.73e-05       0.56
#          9   2.46e-06      0.562
#         10   3.83e-07      0.563
# done in 0.013 seconds
# Expected: 0.020 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 90.1        |
# | EpRewMean               | 90.1        |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 131         |
# | TimeElapsed             | 2.11        |
# | TimestepsSoFar          | 6144        |
# | entloss                 | 0.0         |
# | entropy                 | 0.5837907   |
# | explained_variance_t... | 0.015       |
# | meankl                  | 0.010899907 |
# | optimgain               | 0.019649701 |
# | surrgain                | 0.019649701 |
# -----------------------------------------
# ********** Iteration 6 ************
# Optimizing Policy...
# sampling
# done in 0.235 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0469          0
#          1    0.00652     0.0588
#          2    0.00781     0.0769
#          3   0.000846      0.123
#          4   0.000392      0.131
#          5   9.13e-05      0.434
#          6   1.11e-05       0.74
#          7   2.23e-05       0.74
#          8   0.000231      0.764
#          9   8.87e-07      0.776
#         10   1.31e-05      0.777
# done in 0.013 seconds
# Expected: 0.024 Actual: 0.018
# Stepsize OK!
# vf
# done in 0.021 seconds
# ------------------------------------------
# | EpLenMean               | 103          |
# | EpRewMean               | 103          |
# | EpThisIter              | 4            |
# | EpisodesSoFar           | 135          |
# | TimeElapsed             | 2.39         |
# | TimestepsSoFar          | 7168         |
# | entloss                 | 0.0          |
# | entropy                 | 0.5807717    |
# | explained_variance_t... | 0.0146       |
# | meankl                  | 0.0057946816 |
# | optimgain               | 0.017833477  |
# | surrgain                | 0.017833477  |
# ------------------------------------------
# ********** Iteration 7 ************
# Optimizing Policy...
# sampling
# done in 0.233 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00566          0
#          1    0.00401     0.0345
#          2    0.00399     0.0732
#          3    0.00105      0.193
#          4   0.000465      0.242
#          5   7.17e-05      0.653
#          6   5.83e-05      0.885
#          7   1.51e-05      0.887
#          8   1.78e-06      0.928
#          9   5.86e-07      0.928
#         10   4.64e-07      0.934
# done in 0.013 seconds
# Expected: 0.021 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 131         |
# | EpRewMean               | 131         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 139         |
# | TimeElapsed             | 2.68        |
# | TimestepsSoFar          | 8192        |
# | entloss                 | 0.0         |
# | entropy                 | 0.5674447   |
# | explained_variance_t... | 0.0267      |
# | meankl                  | 0.009731235 |
# | optimgain               | 0.02025129  |
# | surrgain                | 0.02025129  |
# -----------------------------------------
# ********** Iteration 8 ************
# Optimizing Policy...
# sampling
# done in 0.231 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0174          0
#          1   0.000785     0.0194
#          2    4.9e-05     0.0283
#          3   2.41e-05     0.0415
#          4   2.22e-05     0.0446
#          5      2e-06      0.221
#          6   1.26e-05      0.222
#          7   1.76e-07      0.237
#          8   2.19e-08      0.243
#          9   5.84e-09      0.243
#         10   3.18e-07      0.243
# done in 0.013 seconds
# Expected: 0.009 Actual: 0.008
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 154         |
# | EpRewMean               | 154         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 141         |
# | TimeElapsed             | 2.95        |
# | TimestepsSoFar          | 9216        |
# | entloss                 | 0.0         |
# | entropy                 | 0.5841494   |
# | explained_variance_t... | -0.0497     |
# | meankl                  | 0.00785682  |
# | optimgain               | 0.008082117 |
# | surrgain                | 0.008082117 |
# -----------------------------------------
# ********** Iteration 9 ************
# Optimizing Policy...
# sampling
# done in 0.227 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0297          0
#          1     0.0177     0.0336
#          2    0.00491     0.0949
#          3    0.00781      0.459
#          4    0.00171      0.601
#          5   0.000423      0.897
#          6    0.00388       1.33
#          7   6.61e-05       1.35
#          8   1.18e-05       1.47
#          9   0.000269       1.49
#         10   1.76e-06       1.52
# done in 0.013 seconds
# Expected: 0.038 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.025 seconds
# ------------------------------------------
# | EpLenMean               | 168          |
# | EpRewMean               | 168          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 144          |
# | TimeElapsed             | 3.23         |
# | TimestepsSoFar          | 10240        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5800838    |
# | explained_variance_t... | -0.125       |
# | meankl                  | 0.0076860543 |
# | optimgain               | 0.015166319  |
# | surrgain                | 0.015166319  |
# ------------------------------------------
# ********** Iteration 10 ************
# Optimizing Policy...
# sampling
# done in 0.235 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00846          0
#          1    0.00428      0.035
#          2    0.00118     0.0456
#          3    0.00258       0.16
#          4   4.96e-05      0.513
#          5   4.49e-05      0.725
#          6   0.000358      0.731
#          7    1.4e-05      0.761
#          8   0.000127        0.8
#          9   6.55e-07      0.811
#         10   2.62e-06      0.814
# done in 0.013 seconds
# Expected: 0.020 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.021 seconds
# ------------------------------------------
# | EpLenMean               | 187          |
# | EpRewMean               | 187          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 147          |
# | TimeElapsed             | 3.52         |
# | TimestepsSoFar          | 11264        |
# | entloss                 | 0.0          |
# | entropy                 | 0.58628315   |
# | explained_variance_t... | -0.182       |
# | meankl                  | 0.0030380953 |
# | optimgain               | 0.004957529  |
# | surrgain                | 0.004957529  |
# ------------------------------------------
# ********** Iteration 11 ************
# Optimizing Policy...
# sampling
# done in 0.231 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00123          0
#          1   0.000425    0.00407
#          2   0.000216     0.0256
#          3   0.000127     0.0631
#          4    8.3e-05     0.0783
#          5   1.96e-05      0.219
#          6   0.000168      0.221
#          7   1.65e-06      0.384
#          8   1.83e-07      0.405
#          9    5.7e-06      0.405
#         10   2.77e-06      0.406
# done in 0.014 seconds
# Expected: 0.008 Actual: 0.008
# violated KL constraint. shrinking step.
# Expected: 0.008 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 203          |
# | EpRewMean               | 203          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 149          |
# | TimeElapsed             | 3.8          |
# | TimestepsSoFar          | 12288        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5990921    |
# | explained_variance_t... | -0.111       |
# | meankl                  | 0.0036502276 |
# | optimgain               | 0.0046375655 |
# | surrgain                | 0.0046375655 |
# ------------------------------------------
# ********** Iteration 12 ************
# Optimizing Policy...
# sampling
# done in 0.247 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0328          0
#          1      0.007     0.0286
#          2     0.0025     0.0934
#          3    0.00266      0.183
#          4    0.00101      0.425
#          5   6.81e-05      0.858
#          6    0.00193       0.87
#          7   1.47e-05        1.1
#          8    8.8e-07       1.15
#          9   1.27e-06       1.15
#         10   3.55e-05       1.15
# done in 0.015 seconds
# Expected: 0.029 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 229         |
# | EpRewMean               | 229         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 152         |
# | TimeElapsed             | 4.1         |
# | TimestepsSoFar          | 13312       |
# | entloss                 | 0.0         |
# | entropy                 | 0.57575154  |
# | explained_variance_t... | -0.0798     |
# | meankl                  | 0.004319505 |
# | optimgain               | 0.014432283 |
# | surrgain                | 0.014432283 |
# -----------------------------------------
# ********** Iteration 13 ************
# Optimizing Policy...
# sampling
# done in 0.260 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0123          0
#          1   0.000176    0.00956
#          2   0.000132     0.0222
#          3   0.000676        0.1
#          4   3.94e-05      0.198
#          5    0.00016      0.246
#          6   2.02e-05      0.249
#          7    3.9e-06      0.339
#          8   5.18e-07      0.381
#          9    3.6e-06      0.381
#         10   2.72e-06      0.385
# done in 0.017 seconds
# Expected: 0.009 Actual: 0.008
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 253          |
# | EpRewMean               | 253          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 154          |
# | TimeElapsed             | 4.41         |
# | TimestepsSoFar          | 14336        |
# | entloss                 | 0.0          |
# | entropy                 | 0.58785695   |
# | explained_variance_t... | -0.0997      |
# | meankl                  | 0.0056710113 |
# | optimgain               | 0.007573382  |
# | surrgain                | 0.007573382  |
# ------------------------------------------
# ********** Iteration 14 ************
# Optimizing Policy...
# sampling
# done in 0.254 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0309          0
#          1    0.00676     0.0268
#          2     0.0011     0.0913
#          3   0.000799       0.11
#          4   0.000271       0.36
#          5   3.27e-05      0.475
#          6    0.00136      0.489
#          7   9.25e-06      0.594
#          8   2.34e-06      0.665
#          9   4.77e-07      0.665
#         10   1.67e-05      0.667
# done in 0.016 seconds
# Expected: 0.021 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.021 seconds
# ------------------------------------------
# | EpLenMean               | 276          |
# | EpRewMean               | 276          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 157          |
# | TimeElapsed             | 4.72         |
# | TimestepsSoFar          | 15360        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5881727    |
# | explained_variance_t... | -0.0846      |
# | meankl                  | 0.0075491765 |
# | optimgain               | 0.017456401  |
# | surrgain                | 0.017456401  |
# ------------------------------------------
# ********** Iteration 15 ************
# Optimizing Policy...
# sampling
# done in 0.262 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0293          0
#          1    0.00929      0.074
#          2   0.000444     0.0821
#          3   0.000969      0.324
#          4   0.000338      0.393
#          5   5.86e-05      0.478
#          6    0.00233      0.643
#          7   1.85e-05      0.678
#          8   0.000152      0.721
#          9   1.92e-06      0.734
#         10      5e-06      0.748
# done in 0.014 seconds
# Expected: 0.023 Actual: 0.016
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 288         |
# | EpRewMean               | 288         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 161         |
# | TimeElapsed             | 5.03        |
# | TimestepsSoFar          | 16384       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5562278   |
# | explained_variance_t... | -0.0367     |
# | meankl                  | 0.005802746 |
# | optimgain               | 0.015540616 |
# | surrgain                | 0.015540616 |
# -----------------------------------------
# ********** Iteration 16 ************
# Optimizing Policy...
# sampling
# done in 0.243 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0521          0
#          1     0.0373     0.0402
#          2    0.00278      0.179
#          3    0.00459      0.418
#          4    0.00661      0.545
#          5   4.68e-05       1.32
#          6    0.00452       1.34
#          7   7.72e-06       1.44
#          8   1.84e-06       1.47
#          9   4.53e-06       1.47
#         10   2.57e-05       1.47
# done in 0.014 seconds
# Expected: 0.042 Actual: 0.027
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 306         |
# | EpRewMean               | 306         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 164         |
# | TimeElapsed             | 5.32        |
# | TimestepsSoFar          | 17408       |
# | entloss                 | 0.0         |
# | entropy                 | 0.56811476  |
# | explained_variance_t... | -0.0482     |
# | meankl                  | 0.005420616 |
# | optimgain               | 0.026657574 |
# | surrgain                | 0.026657574 |
# -----------------------------------------
# ********** Iteration 17 ************
# Optimizing Policy...
# sampling
# done in 0.238 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0508          0
#          1    0.00406     0.0199
#          2   0.000143     0.0481
#          3    0.00055     0.0966
#          4   6.95e-05       0.14
#          5   3.11e-05      0.274
#          6   8.28e-05      0.275
#          7   2.95e-06      0.395
#          8   4.34e-07      0.422
#          9   5.51e-06      0.427
#         10   1.06e-05      0.428
# done in 0.013 seconds
# Expected: 0.014 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 318         |
# | EpRewMean               | 318         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 167         |
# | TimeElapsed             | 5.6         |
# | TimestepsSoFar          | 18432       |
# | entloss                 | 0.0         |
# | entropy                 | 0.56558996  |
# | explained_variance_t... | -0.0743     |
# | meankl                  | 0.008098881 |
# | optimgain               | 0.014324613 |
# | surrgain                | 0.014324613 |
# -----------------------------------------
# ********** Iteration 18 ************
# Optimizing Policy...
# sampling
# done in 0.275 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0136          0
#          1    0.00573     0.0617
#          2    0.00448     0.0741
#          3   0.000858      0.103
#          4   0.000221      0.144
#          5   2.22e-05      0.338
#          6   0.000439      0.468
#          7   5.08e-06      0.475
#          8   8.19e-05      0.497
#          9   7.68e-07      0.507
#         10   7.41e-06      0.511
# done in 0.015 seconds
# Expected: 0.018 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 334         |
# | EpRewMean               | 334         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 169         |
# | TimeElapsed             | 5.93        |
# | TimestepsSoFar          | 19456       |
# | entloss                 | 0.0         |
# | entropy                 | 0.56706715  |
# | explained_variance_t... | 0.031       |
# | meankl                  | 0.010229794 |
# | optimgain               | 0.017180633 |
# | surrgain                | 0.017180633 |
# -----------------------------------------
# ********** Iteration 19 ************
# Optimizing Policy...
# sampling
# done in 0.247 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0297          0
#          1     0.0103     0.0382
#          2    0.00156     0.0543
#          3    0.00794      0.438
#          4    0.00168      0.542
#          5   0.000134       0.64
#          6    0.00031      0.897
#          7   1.08e-05        0.9
#          8   5.78e-06      0.934
#          9   0.000117      0.941
#         10    1.5e-06       0.96
# done in 0.013 seconds
# Expected: 0.027 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 350         |
# | EpRewMean               | 350         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 171         |
# | TimeElapsed             | 6.22        |
# | TimestepsSoFar          | 20480       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5788517   |
# | explained_variance_t... | 0.251       |
# | meankl                  | 0.005538038 |
# | optimgain               | 0.01653275  |
# | surrgain                | 0.01653275  |
# -----------------------------------------
# ********** Iteration 20 ************
# Optimizing Policy...
# sampling
# done in 0.230 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0333          0
#          1    0.00428      0.019
#          2   0.000606     0.0448
#          3   0.000349      0.141
#          4   0.000375       0.16
#          5   4.76e-05      0.313
#          6    0.00019      0.314
#          7   5.17e-06      0.521
#          8   1.37e-06      0.542
#          9    5.7e-06      0.552
#         10   3.21e-06      0.552
# done in 0.014 seconds
# Expected: 0.016 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 366          |
# | EpRewMean               | 366          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 174          |
# | TimeElapsed             | 6.5          |
# | TimestepsSoFar          | 21504        |
# | entloss                 | 0.0          |
# | entropy                 | 0.59259284   |
# | explained_variance_t... | -0.053       |
# | meankl                  | 0.0074915346 |
# | optimgain               | 0.013966717  |
# | surrgain                | 0.013966717  |
# ------------------------------------------
# ********** Iteration 21 ************
# Optimizing Policy...
# sampling
# done in 0.219 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00644          0
#          1       0.01     0.0314
#          2   0.000684     0.0532
#          3     0.0014     0.0896
#          4   0.000417      0.195
#          5   5.47e-05      0.503
#          6    0.00366      0.568
#          7   3.04e-05      0.618
#          8   2.77e-06      0.717
#          9   2.64e-05       0.72
#         10   7.03e-06      0.726
# done in 0.015 seconds
# Expected: 0.017 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 372         |
# | EpRewMean               | 372         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 176         |
# | TimeElapsed             | 6.77        |
# | TimestepsSoFar          | 22528       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5855187   |
# | explained_variance_t... | -0.0253     |
# | meankl                  | 0.009464666 |
# | optimgain               | 0.014001841 |
# | surrgain                | 0.014001841 |
# -----------------------------------------
# ********** Iteration 22 ************
# Optimizing Policy...
# sampling
# done in 0.273 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.043          0
#          1    0.00395     0.0216
#          2    0.00203     0.0619
#          3    0.00689      0.212
#          4   9.01e-05      0.448
#          5   0.000243       0.53
#          6   0.000383      0.534
#          7   1.88e-05      0.611
#          8   2.74e-06      0.689
#          9   3.76e-05      0.692
#         10   0.000256      0.701
# done in 0.015 seconds
# Expected: 0.023 Actual: 0.019
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 373         |
# | EpRewMean               | 373         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 180         |
# | TimeElapsed             | 7.09        |
# | TimestepsSoFar          | 23552       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5669023   |
# | explained_variance_t... | -0.0116     |
# | meankl                  | 0.006713713 |
# | optimgain               | 0.018876377 |
# | surrgain                | 0.018876377 |
# -----------------------------------------
# ********** Iteration 23 ************
# Optimizing Policy...
# sampling
# done in 0.268 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00912          0
#          1    0.00784     0.0256
#          2   0.000918     0.0405
#          3    0.00137      0.126
#          4    0.00091      0.175
#          5   0.000122      0.448
#          6    7.7e-05      0.682
#          7   0.000118      0.684
#          8   1.38e-05      0.776
#          9   9.93e-05      0.782
#         10   2.09e-06      0.808
# done in 0.016 seconds
# Expected: 0.019 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 370         |
# | EpRewMean               | 370         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 182         |
# | TimeElapsed             | 7.41        |
# | TimestepsSoFar          | 24576       |
# | entloss                 | 0.0         |
# | entropy                 | 0.56087697  |
# | explained_variance_t... | 0.0114      |
# | meankl                  | 0.007297905 |
# | optimgain               | 0.014314523 |
# | surrgain                | 0.014314523 |
# -----------------------------------------
# ********** Iteration 24 ************
# Optimizing Policy...
# sampling
# done in 0.262 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0384          0
#          1      0.019     0.0312
#          2    0.00481     0.0756
#          3    0.00743      0.396
#          4    0.00106      0.471
#          5   0.000323      0.557
#          6   0.000108      0.874
#          7   7.44e-05      0.875
#          8   1.01e-05      0.943
#          9   0.000169      0.951
#         10   1.47e-05      0.984
# done in 0.014 seconds
# Expected: 0.032 Actual: 0.024
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 371         |
# | EpRewMean               | 371         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 186         |
# | TimeElapsed             | 7.72        |
# | TimestepsSoFar          | 25600       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5298868   |
# | explained_variance_t... | -0.046      |
# | meankl                  | 0.007282345 |
# | optimgain               | 0.02444657  |
# | surrgain                | 0.02444657  |
# -----------------------------------------
# ********** Iteration 25 ************
# Optimizing Policy...
# sampling
# done in 0.243 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00996          0
#          1    0.00856     0.0125
#          2   0.000304      0.061
#          3   0.000235     0.0684
#          4   0.000198      0.121
#          5    1.9e-05      0.302
#          6   2.94e-05      0.302
#          7   1.42e-06      0.394
#          8   2.28e-06      0.418
#          9   3.51e-07      0.419
#         10   5.32e-07      0.419
# done in 0.016 seconds
# Expected: 0.013 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 373          |
# | EpRewMean               | 373          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 188          |
# | TimeElapsed             | 8.01         |
# | TimestepsSoFar          | 26624        |
# | entloss                 | 0.0          |
# | entropy                 | 0.6176932    |
# | explained_variance_t... | 0.0192       |
# | meankl                  | 0.0067658992 |
# | optimgain               | 0.011845985  |
# | surrgain                | 0.011845985  |
# ------------------------------------------
# ********** Iteration 26 ************
# Optimizing Policy...
# sampling
# done in 0.242 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.191          0
#          1     0.0126     0.0264
#          2    0.00431     0.0924
#          3    0.00134      0.133
#          4   0.000592      0.408
#          5    0.00259      0.468
#          6   0.000123      0.474
#          7   1.67e-05      0.763
#          8   1.89e-05       0.84
#          9   2.82e-06       0.84
#         10   1.56e-05      0.841
# done in 0.015 seconds
# Expected: 0.029 Actual: 0.021
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 375         |
# | EpRewMean               | 375         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 190         |
# | TimeElapsed             | 8.3         |
# | TimestepsSoFar          | 27648       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5575554   |
# | explained_variance_t... | -0.0101     |
# | meankl                  | 0.007923414 |
# | optimgain               | 0.020623181 |
# | surrgain                | 0.020623181 |
# -----------------------------------------
# ********** Iteration 27 ************
# Optimizing Policy...
# sampling
# done in 0.245 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0       0.12          0
#          1     0.0129     0.0177
#          2    0.00281     0.0687
#          3   0.000314      0.095
#          4   0.000308      0.144
#          5    0.00163      0.239
#          6   4.85e-05      0.245
#          7   1.04e-05      0.359
#          8   2.45e-05      0.413
#          9   4.83e-05      0.414
#         10   4.81e-06      0.415
# done in 0.014 seconds
# Expected: 0.020 Actual: 0.021
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 382         |
# | EpRewMean               | 382         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 192         |
# | TimeElapsed             | 8.59        |
# | TimestepsSoFar          | 28672       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5748565   |
# | explained_variance_t... | 0.00269     |
# | meankl                  | 0.011453323 |
# | optimgain               | 0.021092307 |
# | surrgain                | 0.021092307 |
# -----------------------------------------
# ********** Iteration 28 ************
# Optimizing Policy...
# sampling
# done in 0.240 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0       0.02          0
#          1    0.00906    0.00843
#          2     0.0037     0.0552
#          3    0.00113      0.088
#          4   0.000244      0.438
#          5   0.000574      0.463
#          6   0.000166      0.464
#          7   3.19e-05      0.601
#          8   9.47e-06      0.733
#          9   2.74e-05      0.733
#         10   9.47e-06      0.733
# done in 0.017 seconds
# Expected: 0.021 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 380         |
# | EpRewMean               | 380         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 194         |
# | TimeElapsed             | 8.89        |
# | TimestepsSoFar          | 29696       |
# | entloss                 | 0.0         |
# | entropy                 | 0.55280757  |
# | explained_variance_t... | -0.00205    |
# | meankl                  | 0.00805533  |
# | optimgain               | 0.017444398 |
# | surrgain                | 0.017444398 |
# -----------------------------------------
# ********** Iteration 29 ************
# Optimizing Policy...
# sampling
# done in 0.245 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0256          0
#          1   0.000431    0.00548
#          2   0.000725      0.047
#          3    0.00025     0.0702
#          4   0.000447     0.0931
#          5   0.000115      0.227
#          6    3.9e-05      0.228
#          7   2.15e-05      0.364
#          8   3.46e-06      0.444
#          9   0.000117      0.445
#         10   1.18e-05       0.46
# done in 0.015 seconds
# Expected: 0.011 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 387         |
# | EpRewMean               | 387         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 197         |
# | TimeElapsed             | 9.18        |
# | TimestepsSoFar          | 30720       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5858694   |
# | explained_variance_t... | -0.00774    |
# | meankl                  | 0.010981154 |
# | optimgain               | 0.011612883 |
# | surrgain                | 0.011612883 |
# -----------------------------------------
# ********** Iteration 30 ************
# Optimizing Policy...
# sampling
# done in 0.247 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00157          0
#          1    0.00107    0.00284
#          2   0.000186     0.0152
#          3   0.000536      0.132
#          4   6.62e-05      0.215
#          5   0.000702      0.245
#          6   2.99e-05      0.249
#          7   2.38e-06      0.307
#          8    7.8e-06      0.341
#          9   9.36e-06      0.341
#         10   6.35e-07      0.342
# done in 0.014 seconds
# Expected: 0.009 Actual: 0.008
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 399         |
# | EpRewMean               | 399         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 199         |
# | TimeElapsed             | 9.48        |
# | TimestepsSoFar          | 31744       |
# | entloss                 | 0.0         |
# | entropy                 | 0.59743416  |
# | explained_variance_t... | -0.00305    |
# | meankl                  | 0.013108092 |
# | optimgain               | 0.007877531 |
# | surrgain                | 0.007877531 |
# -----------------------------------------
# ********** Iteration 31 ************
# Optimizing Policy...
# sampling
# done in 0.254 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00383          0
#          1    0.00585    0.00679
#          2   0.000315     0.0322
#          3   0.000465     0.0487
#          4   0.000105      0.161
#          5   0.000319      0.286
#          6   4.95e-05      0.287
#          7   1.22e-05      0.474
#          8    1.9e-06      0.518
#          9   5.28e-05      0.518
#         10   1.52e-05      0.519
# done in 0.015 seconds
# Expected: 0.012 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 406         |
# | EpRewMean               | 406         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 202         |
# | TimeElapsed             | 9.78        |
# | TimestepsSoFar          | 32768       |
# | entloss                 | 0.0         |
# | entropy                 | 0.60378593  |
# | explained_variance_t... | -0.00838    |
# | meankl                  | 0.007189722 |
# | optimgain               | 0.005043134 |
# | surrgain                | 0.005043134 |
# -----------------------------------------
# ********** Iteration 32 ************
# Optimizing Policy...
# sampling
# done in 0.243 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0257          0
#          1    0.00813    0.00862
#          2    0.00235     0.0968
#          3    0.00693      0.232
#          4   0.000822      0.313
#          5   0.000574      0.572
#          6   0.000299      0.573
#          7   0.000107       0.96
#          8   2.21e-05       1.07
#          9   0.000375       1.09
#         10    0.00158       1.11
# done in 0.014 seconds
# Expected: 0.026 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 405         |
# | EpRewMean               | 405         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 204         |
# | TimeElapsed             | 10.1        |
# | TimestepsSoFar          | 33792       |
# | entloss                 | 0.0         |
# | entropy                 | 0.57949704  |
# | explained_variance_t... | -0.00681    |
# | meankl                  | 0.011703387 |
# | optimgain               | 0.017061807 |
# | surrgain                | 0.017061807 |
# -----------------------------------------
# ********** Iteration 33 ************
# Optimizing Policy...
# sampling
# done in 0.248 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.133          0
#          1      0.069     0.0996
#          2     0.0196      0.116
#          3   0.000871      0.165
#          4   0.000217      0.348
#          5   0.000102      0.996
#          6   0.000146      0.997
#          7   0.000151       1.07
#          8   5.92e-05       1.07
#          9    3.4e-06       1.13
#         10   4.85e-05       1.13
# done in 0.014 seconds
# Expected: 0.038 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 377         |
# | EpRewMean               | 377         |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 210         |
# | TimeElapsed             | 10.4        |
# | TimestepsSoFar          | 34816       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5216788   |
# | explained_variance_t... | -0.00221    |
# | meankl                  | 0.010254215 |
# | optimgain               | 0.030017594 |
# | surrgain                | 0.030017594 |
# -----------------------------------------
# ********** Iteration 34 ************
# Optimizing Policy...
# sampling
# done in 0.231 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00214          0
#          1    0.00654      0.013
#          2   0.000634     0.0267
#          3    0.00067     0.0745
#          4   0.000127      0.388
#          5    0.00057      0.549
#          6   5.29e-05      0.551
#          7   8.52e-06      0.599
#          8   0.000121      0.671
#          9   8.83e-05      0.681
#         10   1.52e-07      0.682
# done in 0.013 seconds
# Expected: 0.015 Actual: 0.006
# Stepsize OK!
# vf
# done in 0.018 seconds
# ------------------------------------------
# | EpLenMean               | 375          |
# | EpRewMean               | 375          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 212          |
# | TimeElapsed             | 10.6         |
# | TimestepsSoFar          | 35840        |
# | entloss                 | 0.0          |
# | entropy                 | 0.572806     |
# | explained_variance_t... | -0.00559     |
# | meankl                  | 0.0032796923 |
# | optimgain               | 0.0059426855 |
# | surrgain                | 0.0059426855 |
# ------------------------------------------
# ********** Iteration 35 ************
# Optimizing Policy...
# sampling
# done in 0.235 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0156          0
#          1     0.0857     0.0867
#          2    0.00561      0.125
#          3    0.00453      0.173
#          4    0.00037      0.347
#          5   0.000834      0.597
#          6   3.21e-05      0.599
#          7   1.32e-05       0.68
#          8   5.37e-05      0.715
#          9   0.000136      0.717
#         10   6.08e-06      0.718
# done in 0.015 seconds
# Expected: 0.028 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 382          |
# | EpRewMean               | 382          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 214          |
# | TimeElapsed             | 10.9         |
# | TimestepsSoFar          | 36864        |
# | entloss                 | 0.0          |
# | entropy                 | 0.55894375   |
# | explained_variance_t... | -0.00321     |
# | meankl                  | 0.0096473275 |
# | optimgain               | 0.025210096  |
# | surrgain                | 0.025210096  |
# ------------------------------------------
# ********** Iteration 36 ************
# Optimizing Policy...
# sampling
# done in 0.238 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0541          0
#          1    0.00407    0.00854
#          2    0.00098      0.033
#          3   0.000747     0.0541
#          4   6.91e-05      0.491
#          5    0.00699       0.51
#          6    4.6e-05      0.562
#          7    9.7e-06      0.711
#          8   0.000106      0.729
#          9   0.000108      0.736
#         10   1.06e-06      0.736
# done in 0.013 seconds
# Expected: 0.018 Actual: -0.000
# surrogate didn't improve. shrinking step.
# Expected: 0.018 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.018 seconds
# ------------------------------------------
# | EpLenMean               | 380          |
# | EpRewMean               | 380          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 217          |
# | TimeElapsed             | 11.2         |
# | TimestepsSoFar          | 37888        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5640555    |
# | explained_variance_t... | -0.0035      |
# | meankl                  | 0.0009847978 |
# | optimgain               | 0.0035713636 |
# | surrgain                | 0.0035713636 |
# ------------------------------------------
# ********** Iteration 37 ************
# Optimizing Policy...
# sampling
# done in 0.246 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0101          0
#          1    0.00588    0.00592
#          2   0.000206      0.026
#          3   0.000449     0.0965
#          4    6.1e-05       0.17
#          5    0.00514      0.202
#          6   2.16e-05      0.248
#          7   2.08e-06      0.337
#          8   6.66e-05      0.347
#          9   9.77e-05      0.364
#         10   4.64e-07      0.365
# done in 0.015 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 387         |
# | EpRewMean               | 387         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 219         |
# | TimeElapsed             | 11.5        |
# | TimestepsSoFar          | 38912       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5490041   |
# | explained_variance_t... | -0.00291    |
# | meankl                  | 0.011752744 |
# | optimgain               | 0.009642804 |
# | surrgain                | 0.009642804 |
# -----------------------------------------
# ********** Iteration 38 ************
# Optimizing Policy...
# sampling
# done in 0.234 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0045          0
#          1   0.000259    0.00246
#          2   0.000256     0.0411
#          3   0.000381      0.162
#          4   3.95e-05      0.178
#          5    0.00224      0.187
#          6   1.36e-05      0.234
#          7   2.66e-06        0.3
#          8   1.27e-05       0.33
#          9   7.83e-07      0.331
#         10   2.72e-06      0.339
# done in 0.014 seconds
# Expected: 0.008 Actual: 0.013
# violated KL constraint. shrinking step.
# Expected: 0.008 Actual: 0.006
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 402         |
# | EpRewMean               | 402         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 221         |
# | TimeElapsed             | 11.8        |
# | TimestepsSoFar          | 39936       |
# | entloss                 | 0.0         |
# | entropy                 | 0.57263094  |
# | explained_variance_t... | -0.00301    |
# | meankl                  | 0.005442471 |
# | optimgain               | 0.005557497 |
# | surrgain                | 0.005557497 |
# -----------------------------------------
# ********** Iteration 39 ************
# Optimizing Policy...
# sampling
# done in 0.237 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.003          0
#          1    0.00072    0.00282
#          2   0.000463     0.0244
#          3   0.000235      0.049
#          4   6.04e-05      0.111
#          5   0.000642      0.187
#          6   1.62e-05       0.19
#          7   1.25e-06      0.327
#          8   1.83e-06      0.334
#          9   1.06e-06      0.334
#         10   4.46e-07      0.334
# done in 0.018 seconds
# Expected: 0.008 Actual: 0.006
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 403         |
# | EpRewMean               | 403         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 223         |
# | TimeElapsed             | 12.1        |
# | TimestepsSoFar          | 40960       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5842774   |
# | explained_variance_t... | -0.00355    |
# | meankl                  | 0.004989941 |
# | optimgain               | 0.006209987 |
# | surrgain                | 0.006209987 |
# -----------------------------------------
# ********** Iteration 40 ************
# Optimizing Policy...
# sampling
# done in 0.245 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00498          0
#          1     0.0028    0.00654
#          2   0.000237     0.0243
#          3   0.000385     0.0946
#          4    1.2e-05      0.178
#          5    0.00135      0.249
#          6   1.04e-05      0.269
#          7   2.37e-06      0.305
#          8   1.17e-05       0.31
#          9   5.45e-06      0.312
#         10   1.05e-06      0.312
# done in 0.014 seconds
# Expected: 0.009 Actual: 0.007
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 414         |
# | EpRewMean               | 414         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 225         |
# | TimeElapsed             | 12.4        |
# | TimestepsSoFar          | 41984       |
# | entloss                 | 0.0         |
# | entropy                 | 0.56685203  |
# | explained_variance_t... | -0.00526    |
# | meankl                  | 0.005663531 |
# | optimgain               | 0.007260584 |
# | surrgain                | 0.007260584 |
# -----------------------------------------
# ********** Iteration 41 ************
# Optimizing Policy...
# sampling
# done in 0.255 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.011          0
#          1     0.0069     0.0108
#          2    0.00346     0.0553
#          3    0.00149       0.18
#          4   0.000268      0.414
#          5   0.000119      0.494
#          6    0.00119      0.497
#          7    2.4e-05      0.678
#          8   3.73e-05      0.731
#          9      9e-06      0.733
#         10    0.00119      0.764
# done in 0.015 seconds
# Expected: 0.022 Actual: 0.013
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 421         |
# | EpRewMean               | 421         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 227         |
# | TimeElapsed             | 12.7        |
# | TimestepsSoFar          | 43008       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5541991   |
# | explained_variance_t... | -0.00142    |
# | meankl                  | 0.005143117 |
# | optimgain               | 0.012519725 |
# | surrgain                | 0.012519725 |
# -----------------------------------------
# ********** Iteration 42 ************
# Optimizing Policy...
# sampling
# done in 0.232 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0054          0
#          1    0.00954     0.0275
#          2    0.00193     0.0411
#          3   0.000568      0.207
#          4    0.00115       0.39
#          5   0.000159      0.492
#          6    0.00461      0.507
#          7   2.21e-05      0.757
#          8   6.22e-05      0.809
#          9   8.62e-06      0.812
#         10   0.000377      0.848
# done in 0.015 seconds
# Expected: 0.020 Actual: 0.016
# violated KL constraint. shrinking step.
# Expected: 0.020 Actual: 0.010
# Stepsize OK!
# vf
# done in 0.018 seconds
# ------------------------------------------
# | EpLenMean               | 421          |
# | EpRewMean               | 421          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 229          |
# | TimeElapsed             | 13           |
# | TimestepsSoFar          | 44032        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5480103    |
# | explained_variance_t... | -0.00597     |
# | meankl                  | 0.0034619325 |
# | optimgain               | 0.010206243  |
# | surrgain                | 0.010206243  |
# ------------------------------------------
# ********** Iteration 43 ************
# Optimizing Policy...
# sampling
# done in 0.252 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0183          0
#          1    0.00779    0.00992
#          2     0.0007     0.0448
#          3    0.00123      0.123
#          4   6.79e-05      0.436
#          5   3.07e-05      0.479
#          6   4.22e-05       0.48
#          7   6.83e-06      0.554
#          8   6.54e-05      0.581
#          9   2.08e-07      0.589
#         10   1.52e-05      0.589
# done in 0.016 seconds
# Expected: 0.017 Actual: 0.010
# violated KL constraint. shrinking step.
# Expected: 0.017 Actual: 0.007
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 424          |
# | EpRewMean               | 424          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 231          |
# | TimeElapsed             | 13.3         |
# | TimestepsSoFar          | 45056        |
# | entloss                 | 0.0          |
# | entropy                 | 0.56238675   |
# | explained_variance_t... | -0.00274     |
# | meankl                  | 0.0022180853 |
# | optimgain               | 0.006604009  |
# | surrgain                | 0.006604009  |
# ------------------------------------------
# ********** Iteration 44 ************
# Optimizing Policy...
# sampling
# done in 0.257 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.157          0
#          1   0.000442      0.017
#          2   0.000248     0.0286
#          3   0.000329     0.0535
#          4   0.000196      0.303
#          5    0.00175      0.311
#          6   9.07e-06      0.509
#          7   7.42e-07      0.536
#          8    0.00022      0.538
#          9   3.58e-06      0.546
#         10   1.34e-07      0.547
# done in 0.015 seconds
# Expected: 0.016 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 426         |
# | EpRewMean               | 426         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 233         |
# | TimeElapsed             | 13.6        |
# | TimestepsSoFar          | 46080       |
# | entloss                 | 0.0         |
# | entropy                 | 0.57896566  |
# | explained_variance_t... | -0.00383    |
# | meankl                  | 0.009233887 |
# | optimgain               | 0.014531871 |
# | surrgain                | 0.014531871 |
# -----------------------------------------
# ********** Iteration 45 ************
# Optimizing Policy...
# sampling
# done in 0.283 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0344          0
#          1    0.00558    0.00895
#          2    0.00276     0.0633
#          3    0.00167      0.119
#          4   9.88e-05      0.292
#          5     0.0104      0.323
#          6   1.21e-05      0.396
#          7   4.04e-06      0.502
#          8   8.28e-06      0.516
#          9   1.29e-05      0.516
#         10    1.9e-07      0.517
# done in 0.014 seconds
# Expected: 0.019 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 426         |
# | EpRewMean               | 426         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 235         |
# | TimeElapsed             | 13.9        |
# | TimestepsSoFar          | 47104       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5413574   |
# | explained_variance_t... | -0.00277    |
# | meankl                  | 0.006788938 |
# | optimgain               | 0.015479213 |
# | surrgain                | 0.015479213 |
# -----------------------------------------
# ********** Iteration 46 ************
# Optimizing Policy...
# sampling
# done in 0.254 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0016          0
#          1    0.00012    0.00182
#          2   5.77e-05     0.0162
#          3   7.61e-05     0.0241
#          4   1.04e-05       0.11
#          5   0.000457      0.148
#          6   7.85e-06      0.154
#          7   2.92e-07      0.234
#          8   1.14e-05      0.239
#          9   5.62e-06       0.24
#         10    1.3e-07      0.241
# done in 0.015 seconds
# Expected: 0.005 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 432          |
# | EpRewMean               | 432          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 237          |
# | TimeElapsed             | 14.2         |
# | TimestepsSoFar          | 48128        |
# | entloss                 | 0.0          |
# | entropy                 | 0.58972687   |
# | explained_variance_t... | -0.00304     |
# | meankl                  | 0.0071978834 |
# | optimgain               | 0.004068136  |
# | surrgain                | 0.004068136  |
# ------------------------------------------
# ********** Iteration 47 ************
# Optimizing Policy...
# sampling
# done in 0.241 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00199          0
#          1    0.00029    0.00266
#          2    0.00136     0.0749
#          3    5.1e-05       0.21
#          4   2.07e-05      0.217
#          5   0.000996      0.223
#          6   1.34e-05      0.253
#          7   1.87e-06      0.305
#          8   2.11e-05      0.319
#          9   7.55e-07      0.319
#         10   1.34e-06      0.319
# done in 0.015 seconds
# Expected: 0.009 Actual: 0.007
# violated KL constraint. shrinking step.
# Expected: 0.009 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.036 seconds
# ------------------------------------------
# | EpLenMean               | 432          |
# | EpRewMean               | 432          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 239          |
# | TimeElapsed             | 14.5         |
# | TimestepsSoFar          | 49152        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5785606    |
# | explained_variance_t... | -0.00451     |
# | meankl                  | 0.0028215055 |
# | optimgain               | 0.0039856783 |
# | surrgain                | 0.0039856783 |
# ------------------------------------------
# ********** Iteration 48 ************
# Optimizing Policy...
# sampling
# done in 0.255 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000154          0
#          1   0.000495    0.00435
#          2     0.0001     0.0109
#          3   5.55e-05     0.0478
#          4   7.99e-06     0.0793
#          5   4.14e-06      0.152
#          6   6.43e-06      0.153
#          7   4.88e-07      0.171
#          8    2.5e-06       0.18
#          9   2.92e-07      0.181
#         10   3.22e-06      0.181
# done in 0.019 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 437         |
# | EpRewMean               | 437         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 241         |
# | TimeElapsed             | 14.8        |
# | TimestepsSoFar          | 50176       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5937203   |
# | explained_variance_t... | -0.00382    |
# | meankl                  | 0.011740007 |
# | optimgain               | 0.004292805 |
# | surrgain                | 0.004292805 |
# -----------------------------------------

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_EPISODES, "TRPO CartPole-v1")
plt.show()
