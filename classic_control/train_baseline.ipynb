# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines.bench import Monitor
from stable_baselines.common.policies import MlpPolicy
from stable_baselines import results_plotter
from stable_baselines import *

# %%
import gym
import numpy as np

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make('Acrobot-v1')
env = Monitor(env, log_dir, allow_early_resets=True)

model = TRPO(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 200000
model.learn(total_timesteps=time_steps)
# Out:
# ********** Iteration 0 ************
# Optimizing Policy...
# sampling
# done in 0.407 seconds
# computegrad
# done in 0.110 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00363          0
#          1    0.00485     0.0777
#          2    0.00151      0.157
#          3   0.000382      0.231
#          4    0.00027      0.312
#          5    0.00181      0.445
#          6   0.000137      0.515
#          7   6.22e-05      0.587
#          8    0.00016      0.628
#          9   1.97e-05      0.667
#         10   2.38e-06      0.744
# done in 0.153 seconds
# Expected: 0.020 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.063 seconds
# ------------------------------------------
# | EpLenMean               | 500          |
# | EpRewMean               | -500         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 2            |
# | TimeElapsed             | 0.806        |
# | TimestepsSoFar          | 1024         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0909736    |
# | explained_variance_t... | -0.00231     |
# | meankl                  | 0.0076772054 |
# | optimgain               | 0.019974332  |
# | surrgain                | 0.019974332  |
# ------------------------------------------
# ********** Iteration 1 ************
# Optimizing Policy...
# sampling
# done in 0.370 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0116          0
#          1    0.00274     0.0723
#          2    0.00426      0.142
#          3   0.000391       0.25
#          4     0.0028      0.305
#          5    0.00034      0.493
#          6   0.000246      0.512
#          7   8.32e-05       0.55
#          8   0.000105      0.672
#          9   1.84e-05      0.748
#         10    2.7e-05      0.821
# done in 0.016 seconds
# Expected: 0.023 Actual: 0.023
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 500         |
# | EpRewMean               | -500        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 4           |
# | TimeElapsed             | 1.22        |
# | TimestepsSoFar          | 2048        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0865996   |
# | explained_variance_t... | -0.00297    |
# | meankl                  | 0.008789505 |
# | optimgain               | 0.022894152 |
# | surrgain                | 0.022894152 |
# -----------------------------------------
# ********** Iteration 2 ************
# Optimizing Policy...
# sampling
# done in 0.400 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0459          0
#          1    0.00637     0.0697
#          2    0.00455      0.143
#          3     0.0018      0.246
#          4    0.00405      0.298
#          5    0.00182      0.422
#          6    0.00273      0.574
#          7    0.00092      0.741
#          8   0.000573          1
#          9   0.000304       1.13
#         10   0.000344       1.22
# done in 0.015 seconds
# Expected: 0.033 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 497         |
# | EpRewMean               | -497        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 6           |
# | TimeElapsed             | 1.68        |
# | TimestepsSoFar          | 3072        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0710312   |
# | explained_variance_t... | 0.0331      |
# | meankl                  | 0.007561953 |
# | optimgain               | 0.03181695  |
# | surrgain                | 0.03181695  |
# -----------------------------------------
# ********** Iteration 3 ************
# Optimizing Policy...
# sampling
# done in 0.358 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0198          0
#          1    0.00719     0.0653
#          2    0.00517      0.133
#          3    0.00538      0.182
#          4    0.00435       0.51
#          5    0.00364      0.665
#          6    0.00296      0.884
#          7    0.00201       1.08
#          8    0.00223       1.19
#          9   0.000292       1.44
#         10   0.000364       1.63
# done in 0.016 seconds
# Expected: 0.037 Actual: 0.040
# violated KL constraint. shrinking step.
# Expected: 0.037 Actual: 0.021
# Stepsize OK!
# vf
# done in 0.024 seconds
# ------------------------------------------
# | EpLenMean               | 496          |
# | EpRewMean               | -496         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 8            |
# | TimeElapsed             | 2.09         |
# | TimestepsSoFar          | 4096         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0628011    |
# | explained_variance_t... | 0.0266       |
# | meankl                  | 0.0033309837 |
# | optimgain               | 0.020546157  |
# | surrgain                | 0.020546157  |
# ------------------------------------------
# ********** Iteration 4 ************
# Optimizing Policy...
# sampling
# done in 0.381 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00402          0
#          1    0.00159     0.0402
#          2    0.00241      0.108
#          3   0.000369      0.158
#          4    0.00162      0.191
#          5   0.000728      0.422
#          6   9.69e-05      0.446
#          7   0.000117      0.505
#          8   3.12e-05      0.651
#          9   1.11e-05      0.675
#         10   1.41e-05      0.722
# done in 0.015 seconds
# Expected: 0.017 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.021 seconds
# ------------------------------------------
# | EpLenMean               | 497          |
# | EpRewMean               | -497         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 10           |
# | TimeElapsed             | 2.52         |
# | TimestepsSoFar          | 5120         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0839026    |
# | explained_variance_t... | -0.00547     |
# | meankl                  | 0.0073532206 |
# | optimgain               | 0.01653188   |
# | surrgain                | 0.01653188   |
# ------------------------------------------
# ********** Iteration 5 ************
# Optimizing Policy...
# sampling
# done in 0.363 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0145          0
#          1    0.00907     0.0565
#          2    0.00593      0.143
#          3    0.00492      0.235
#          4     0.0085      0.315
#          5    0.00386      0.485
#          6     0.0114      0.859
#          7    0.00149       1.17
#          8   0.000572       1.56
#          9    0.00051       1.63
#         10   0.000308       1.74
# done in 0.016 seconds
# Expected: 0.038 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 498         |
# | EpRewMean               | -497        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 12          |
# | TimeElapsed             | 2.94        |
# | TimestepsSoFar          | 6144        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0521979   |
# | explained_variance_t... | 0.0625      |
# | meankl                  | 0.006560081 |
# | optimgain               | 0.033515237 |
# | surrgain                | 0.033515237 |
# -----------------------------------------
# ********** Iteration 6 ************
# Optimizing Policy...
# sampling
# done in 0.370 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0208          0
#          1    0.00279     0.0328
#          2    0.00523      0.106
#          3    0.00468      0.195
#          4    0.00193      0.278
#          5    0.00241      0.399
#          6    0.00116      0.499
#          7   0.000682      0.742
#          8   0.000632      0.995
#          9    0.00276       1.05
#         10   0.000184       1.14
# done in 0.016 seconds
# Expected: 0.027 Actual: 0.027
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 498         |
# | EpRewMean               | -498        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 14          |
# | TimeElapsed             | 3.36        |
# | TimestepsSoFar          | 7168        |
# | entloss                 | 0.0         |
# | entropy                 | 1.056875    |
# | explained_variance_t... | 0.0311      |
# | meankl                  | 0.008021822 |
# | optimgain               | 0.02690271  |
# | surrgain                | 0.02690271  |
# -----------------------------------------
# ********** Iteration 7 ************
# Optimizing Policy...
# sampling
# done in 0.363 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0229          0
#          1    0.00275     0.0289
#          2    0.00291     0.0591
#          3    0.00266      0.185
#          4    0.00264      0.266
#          5    0.00306      0.327
#          6    0.00117      0.555
#          7    0.00083      0.862
#          8   0.000415       1.04
#          9    0.00192       1.07
#         10   0.000301        1.2
# done in 0.016 seconds
# Expected: 0.027 Actual: 0.024
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 498          |
# | EpRewMean               | -498         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 16           |
# | TimeElapsed             | 3.77         |
# | TimestepsSoFar          | 8192         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0623941    |
# | explained_variance_t... | 0.0569       |
# | meankl                  | 0.0070394324 |
# | optimgain               | 0.023644656  |
# | surrgain                | 0.023644656  |
# ------------------------------------------
# ********** Iteration 8 ************
# Optimizing Policy...
# sampling
# done in 0.351 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0174          0
#          1     0.0132     0.0351
#          2     0.0101      0.116
#          3    0.00886      0.196
#          4    0.00895      0.331
#          5    0.00347      0.505
#          6    0.00779      0.885
#          7    0.00609       1.21
#          8    0.00257       1.57
#          9     0.0173       1.71
#         10   0.000804       1.86
# done in 0.014 seconds
# Expected: 0.042 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.022 seconds
# ------------------------------------------
# | EpLenMean               | 493          |
# | EpRewMean               | -492         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 18           |
# | TimeElapsed             | 4.17         |
# | TimestepsSoFar          | 9216         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0596762    |
# | explained_variance_t... | 0.249        |
# | meankl                  | 0.0070803678 |
# | optimgain               | 0.03237402   |
# | surrgain                | 0.03237402   |
# ------------------------------------------
# ********** Iteration 9 ************
# Optimizing Policy...
# sampling
# done in 0.376 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0101          0
#          1    0.00457     0.0404
#          2     0.0116      0.142
#          3    0.00243       0.23
#          4    0.00587      0.367
#          5    0.00496      0.525
#          6    0.00185      0.612
#          7    0.00136      0.933
#          8   0.000665       1.11
#          9   0.000366       1.22
#         10   0.000262        1.4
# done in 0.015 seconds
# Expected: 0.032 Actual: 0.026
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 493         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 20          |
# | TimeElapsed             | 4.59        |
# | TimestepsSoFar          | 10240       |
# | entloss                 | 0.0         |
# | entropy                 | 1.046108    |
# | explained_variance_t... | 0.187       |
# | meankl                  | 0.006290942 |
# | optimgain               | 0.025942942 |
# | surrgain                | 0.025942942 |
# -----------------------------------------
# ********** Iteration 10 ************
# Optimizing Policy...
# sampling
# done in 0.367 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.049          0
#          1    0.00809      0.045
#          2    0.00497     0.0624
#          3    0.00572      0.141
#          4    0.00461       0.25
#          5    0.00161      0.295
#          6    0.00055      0.567
#          7   0.000621      0.758
#          8   0.000567      0.911
#          9   0.000463      0.919
#         10    0.00034          1
# done in 0.015 seconds
# Expected: 0.030 Actual: 0.026
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 494         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 22          |
# | TimeElapsed             | 5.01        |
# | TimestepsSoFar          | 11264       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0637362   |
# | explained_variance_t... | 0.144       |
# | meankl                  | 0.009204559 |
# | optimgain               | 0.025715658 |
# | surrgain                | 0.025715658 |
# -----------------------------------------
# ********** Iteration 11 ************
# Optimizing Policy...
# sampling
# done in 0.354 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0188          0
#          1    0.00482     0.0266
#          2    0.00923     0.0798
#          3     0.0106      0.202
#          4    0.00365      0.305
#          5    0.00456      0.423
#          6    0.00201      0.732
#          7    0.00149      0.943
#          8    0.00103       1.14
#          9    0.00743       1.21
#         10   0.000282       1.33
# done in 0.015 seconds
# Expected: 0.033 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 494         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 24          |
# | TimeElapsed             | 5.41        |
# | TimestepsSoFar          | 12288       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0337393   |
# | explained_variance_t... | 0.0375      |
# | meankl                  | 0.010746827 |
# | optimgain               | 0.03333838  |
# | surrgain                | 0.03333838  |
# -----------------------------------------
# ********** Iteration 12 ************
# Optimizing Policy...
# sampling
# done in 0.358 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0312          0
#          1    0.00418     0.0288
#          2    0.00882     0.0931
#          3     0.0042      0.127
#          4    0.00281      0.243
#          5    0.00271      0.329
#          6    0.00208      0.561
#          7    0.00271      0.919
#          8   0.000829       1.16
#          9    0.00676       1.21
#         10     0.0008       1.38
# done in 0.016 seconds
# Expected: 0.031 Actual: 0.034
# violated KL constraint. shrinking step.
# Expected: 0.031 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.026 seconds
# ------------------------------------------
# | EpLenMean               | 493          |
# | EpRewMean               | -493         |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 27           |
# | TimeElapsed             | 5.83         |
# | TimestepsSoFar          | 13312        |
# | entloss                 | 0.0          |
# | entropy                 | 1.0179532    |
# | explained_variance_t... | 0.122        |
# | meankl                  | 0.0033667595 |
# | optimgain               | 0.017428335  |
# | surrgain                | 0.017428335  |
# ------------------------------------------
# ********** Iteration 13 ************
# Optimizing Policy...
# sampling
# done in 0.368 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0411          0
#          1    0.00289     0.0364
#          2     0.0106      0.143
#          3    0.00794      0.278
#          4     0.0061      0.385
#          5    0.00625      0.642
#          6    0.00107      0.694
#          7   0.000396      0.958
#          8   0.000405       1.05
#          9   0.000161       1.19
#         10   0.000536       1.29
# done in 0.014 seconds
# Expected: 0.033 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 493         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 29          |
# | TimeElapsed             | 6.25        |
# | TimestepsSoFar          | 14336       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0479546   |
# | explained_variance_t... | 0.0485      |
# | meankl                  | 0.008465096 |
# | optimgain               | 0.03186508  |
# | surrgain                | 0.03186508  |
# -----------------------------------------
# ********** Iteration 14 ************
# Optimizing Policy...
# sampling
# done in 0.344 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0235          0
#          1    0.00866     0.0236
#          2    0.00961     0.0649
#          3     0.0197      0.208
#          4     0.0102      0.341
#          5    0.00574      0.402
#          6    0.00282       0.66
#          7    0.00273      0.856
#          8    0.00189       1.06
#          9     0.0134       1.12
#         10   0.000827       1.34
# done in 0.015 seconds
# Expected: 0.036 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 494         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 31          |
# | TimeElapsed             | 6.64        |
# | TimestepsSoFar          | 15360       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0200347   |
# | explained_variance_t... | 0.117       |
# | meankl                  | 0.009388495 |
# | optimgain               | 0.03151366  |
# | surrgain                | 0.03151366  |
# -----------------------------------------
# ********** Iteration 15 ************
# Optimizing Policy...
# sampling
# done in 0.356 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0253          0
#          1    0.00415     0.0266
#          2    0.00858     0.0611
#          3      0.009      0.233
#          4    0.00271      0.295
#          5    0.00845      0.416
#          6   0.000661      0.463
#          7   0.000773      0.719
#          8   0.000405      0.811
#          9   0.000369          1
#         10   0.000634       1.04
# done in 0.016 seconds
# Expected: 0.028 Actual: 0.027
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 494         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 33          |
# | TimeElapsed             | 7.04        |
# | TimestepsSoFar          | 16384       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0258257   |
# | explained_variance_t... | 0.0143      |
# | meankl                  | 0.008055553 |
# | optimgain               | 0.02710111  |
# | surrgain                | 0.02710111  |
# -----------------------------------------
# ********** Iteration 16 ************
# Optimizing Policy...
# sampling
# done in 0.378 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0196          0
#          1    0.00672     0.0274
#          2    0.00151     0.0427
#          3     0.0058     0.0651
#          4    0.00237      0.255
#          5    0.00112      0.313
#          6   0.000452       0.64
#          7   0.000281      0.796
#          8    0.00872      0.929
#          9   8.49e-05       1.05
#         10   8.14e-05       1.05
# done in 0.016 seconds
# Expected: 0.024 Actual: 0.029
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 495         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 35          |
# | TimeElapsed             | 7.47        |
# | TimestepsSoFar          | 17408       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0657907   |
# | explained_variance_t... | 0.00125     |
# | meankl                  | 0.012028855 |
# | optimgain               | 0.029198416 |
# | surrgain                | 0.029198416 |
# -----------------------------------------
# ********** Iteration 17 ************
# Optimizing Policy...
# sampling
# done in 0.363 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0195          0
#          1    0.00664     0.0295
#          2    0.00555     0.0561
#          3     0.0117       0.12
#          4    0.00505      0.208
#          5    0.00478       0.26
#          6    0.00124      0.409
#          7    0.00161       0.55
#          8    0.00105      0.704
#          9   0.000568      0.919
#         10    0.00482       0.99
# done in 0.017 seconds
# Expected: 0.028 Actual: 0.026
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 495         |
# | EpRewMean               | -495        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 37          |
# | TimeElapsed             | 7.88        |
# | TimestepsSoFar          | 18432       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9725212   |
# | explained_variance_t... | 0.00032     |
# | meankl                  | 0.007806306 |
# | optimgain               | 0.025783632 |
# | surrgain                | 0.025783632 |
# -----------------------------------------
# ********** Iteration 18 ************
# Optimizing Policy...
# sampling
# done in 0.355 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0226          0
#          1    0.00182     0.0187
#          2    0.00906     0.0721
#          3    0.00282        0.2
#          4    0.00167      0.231
#          5    0.00292      0.321
#          6    0.00144       0.45
#          7   0.000219      0.657
#          8    0.00295      0.704
#          9   0.000256      0.734
#         10   5.86e-05      0.909
# done in 0.014 seconds
# Expected: 0.023 Actual: 0.013
# Stepsize OK!
# vf
# done in 0.021 seconds
# ------------------------------------------
# | EpLenMean               | 495          |
# | EpRewMean               | -495         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 39           |
# | TimeElapsed             | 8.29         |
# | TimestepsSoFar          | 19456        |
# | entloss                 | 0.0          |
# | entropy                 | 1.0502701    |
# | explained_variance_t... | 0.000888     |
# | meankl                  | 0.008168168  |
# | optimgain               | 0.0127911065 |
# | surrgain                | 0.0127911065 |
# ------------------------------------------
# ********** Iteration 19 ************
# Optimizing Policy...
# sampling
# done in 0.363 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0296          0
#          1    0.00156     0.0221
#          2    0.00156     0.0284
#          3    0.00377     0.0682
#          4    0.00147        0.2
#          5    0.00214      0.345
#          6    0.00034      0.413
#          7   0.000225      0.515
#          8    0.00296      0.689
#          9    0.00017      0.723
#         10   0.000325      0.797
# done in 0.014 seconds
# Expected: 0.020 Actual: 0.019
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 495         |
# | EpRewMean               | -495        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 41          |
# | TimeElapsed             | 8.7         |
# | TimestepsSoFar          | 20480       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0340173   |
# | explained_variance_t... | 0.00218     |
# | meankl                  | 0.008223461 |
# | optimgain               | 0.01856963  |
# | surrgain                | 0.01856963  |
# -----------------------------------------
# ********** Iteration 20 ************
# Optimizing Policy...
# sampling
# done in 0.376 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0298          0
#          1    0.00975     0.0305
#          2     0.0538      0.207
#          3    0.00679      0.697
#          4     0.0206       0.82
#          5    0.00689      0.968
#          6    0.00591       1.02
#          7    0.00205       1.42
#          8    0.00359       1.65
#          9    0.00538       2.13
#         10    0.00124       2.15
# done in 0.015 seconds
# Expected: 0.051 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 491         |
# | EpRewMean               | -491        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 43          |
# | TimeElapsed             | 9.12        |
# | TimestepsSoFar          | 21504       |
# | entloss                 | 0.0         |
# | entropy                 | 0.98172045  |
# | explained_variance_t... | 0.234       |
# | meankl                  | 0.008651924 |
# | optimgain               | 0.041282885 |
# | surrgain                | 0.041282885 |
# -----------------------------------------
# ********** Iteration 21 ************
# Optimizing Policy...
# sampling
# done in 0.357 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0426          0
#          1    0.00843     0.0356
#          2     0.0246      0.169
#          3    0.00577      0.351
#          4    0.00726      0.389
#          5    0.00664      0.558
#          6    0.00871      0.871
#          7    0.00991      0.976
#          8    0.00226       1.47
#          9    0.00312       1.76
#         10     0.0116       1.85
# done in 0.014 seconds
# Expected: 0.044 Actual: 0.037
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 490         |
# | EpRewMean               | -490        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 45          |
# | TimeElapsed             | 9.53        |
# | TimestepsSoFar          | 22528       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9274184   |
# | explained_variance_t... | 0.187       |
# | meankl                  | 0.009270569 |
# | optimgain               | 0.03653313  |
# | surrgain                | 0.03653313  |
# -----------------------------------------
# ********** Iteration 22 ************
# Optimizing Policy...
# sampling
# done in 0.367 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0198          0
#          1     0.0103     0.0389
#          2    0.00447     0.0757
#          3    0.00609      0.193
#          4   0.000883      0.283
#          5    0.00689       0.32
#          6    0.00117      0.548
#          7   0.000992      0.784
#          8   0.000359       1.02
#          9    0.00196       1.04
#         10    0.00014       1.09
# done in 0.014 seconds
# Expected: 0.029 Actual: 0.028
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 490         |
# | EpRewMean               | -490        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 47          |
# | TimeElapsed             | 9.94        |
# | TimestepsSoFar          | 23552       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0385371   |
# | explained_variance_t... | 0.0175      |
# | meankl                  | 0.006507408 |
# | optimgain               | 0.027712611 |
# | surrgain                | 0.027712611 |
# -----------------------------------------
# ********** Iteration 23 ************
# Optimizing Policy...
# sampling
# done in 0.363 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0084          0
#          1      0.011     0.0448
#          2     0.0168      0.147
#          3     0.0103      0.425
#          4     0.0156      0.491
#          5    0.00115       1.51
#          6     0.0066       1.66
#          7    0.00106       1.82
#          8   0.000205       2.01
#          9    0.00412       2.07
#         10   0.000349       2.12
# done in 0.013 seconds
# Expected: 0.046 Actual: 0.037
# Stepsize OK!
# vf
# done in 0.023 seconds
# ----------------------------------------
# | EpLenMean               | 491        |
# | EpRewMean               | -490       |
# | EpThisIter              | 2          |
# | EpisodesSoFar           | 49         |
# | TimeElapsed             | 10.4       |
# | TimestepsSoFar          | 24576      |
# | entloss                 | 0.0        |
# | entropy                 | 1.0347233  |
# | explained_variance_t... | 0.0424     |
# | meankl                  | 0.00799112 |
# | optimgain               | 0.0370944  |
# | surrgain                | 0.0370944  |
# ----------------------------------------
# ********** Iteration 24 ************
# Optimizing Policy...
# sampling
# done in 0.357 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0218          0
#          1     0.0148     0.0491
#          2   0.000719     0.0919
#          3     0.0079      0.131
#          4   0.000803      0.259
#          5   0.000376      0.291
#          6   0.000106      0.589
#          7   4.86e-05      0.709
#          8    0.00203      0.758
#          9   3.14e-05      0.853
#         10   0.000499       0.87
# done in 0.014 seconds
# Expected: 0.023 Actual: 0.018
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 491         |
# | EpRewMean               | -490        |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 52          |
# | TimeElapsed             | 10.8        |
# | TimestepsSoFar          | 25600       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0325475   |
# | explained_variance_t... | 0.000536    |
# | meankl                  | 0.009736748 |
# | optimgain               | 0.017648987 |
# | surrgain                | 0.017648987 |
# -----------------------------------------
# ********** Iteration 25 ************
# Optimizing Policy...
# sampling
# done in 0.369 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0229          0
#          1    0.00216     0.0357
#          2    0.00293     0.0554
#          3   0.000885      0.101
#          4   0.000561       0.11
#          5    0.00084      0.222
#          6   0.000322      0.241
#          7   0.000173       0.28
#          8   6.26e-05      0.404
#          9   6.87e-05      0.439
#         10   0.000241      0.528
# done in 0.016 seconds
# Expected: 0.017 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.025 seconds
# ------------------------------------------
# | EpLenMean               | 491          |
# | EpRewMean               | -490         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 54           |
# | TimeElapsed             | 11.2         |
# | TimestepsSoFar          | 26624        |
# | entloss                 | 0.0          |
# | entropy                 | 0.96781373   |
# | explained_variance_t... | -0.0032      |
# | meankl                  | 0.006350465  |
# | optimgain               | 0.0143187605 |
# | surrgain                | 0.0143187605 |
# ------------------------------------------
# ********** Iteration 26 ************
# Optimizing Policy...
# sampling
# done in 0.390 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0254          0
#          1    0.00369     0.0356
#          2    0.00638     0.0635
#          3     0.0131       0.22
#          4    0.00154       0.36
#          5    0.00127      0.383
#          6   0.000336      0.454
#          7   0.000576      0.633
#          8   0.000348      0.778
#          9   5.69e-05      0.838
#         10    0.00115      0.866
# done in 0.015 seconds
# Expected: 0.026 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 491         |
# | EpRewMean               | -490        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 56          |
# | TimeElapsed             | 11.6        |
# | TimestepsSoFar          | 27648       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9930252   |
# | explained_variance_t... | 0.00313     |
# | meankl                  | 0.008817987 |
# | optimgain               | 0.025454365 |
# | surrgain                | 0.025454365 |
# -----------------------------------------
# ********** Iteration 27 ************
# Optimizing Policy...
# sampling
# done in 0.351 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0102          0
#          1     0.0202      0.079
#          2     0.0108       0.15
#          3    0.00249      0.186
#          4    0.00192      0.209
#          5      0.012      0.429
#          6   0.000787      0.603
#          7     0.0003      0.759
#          8   0.000204      0.916
#          9    0.00328      0.997
#         10   7.96e-05       1.03
# done in 0.016 seconds
# Expected: 0.029 Actual: 0.022
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 493         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 58          |
# | TimeElapsed             | 12          |
# | TimestepsSoFar          | 28672       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0096599   |
# | explained_variance_t... | 0.00227     |
# | meankl                  | 0.006233773 |
# | optimgain               | 0.021678744 |
# | surrgain                | 0.021678744 |
# -----------------------------------------
# ********** Iteration 28 ************
# Optimizing Policy...
# sampling
# done in 0.358 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00929          0
#          1    0.00326     0.0203
#          2    0.00647      0.102
#          3    0.00356      0.159
#          4     0.0063      0.207
#          5    0.00387      0.438
#          6   0.000962      0.487
#          7   0.000518      0.656
#          8    0.00057      0.751
#          9   0.000129      0.951
#         10    0.00161       0.97
# done in 0.017 seconds
# Expected: 0.025 Actual: 0.023
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 493         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 60          |
# | TimeElapsed             | 12.4        |
# | TimestepsSoFar          | 29696       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9326755   |
# | explained_variance_t... | 0.00362     |
# | meankl                  | 0.010337073 |
# | optimgain               | 0.02289632  |
# | surrgain                | 0.02289632  |
# -----------------------------------------
# ********** Iteration 29 ************
# Optimizing Policy...
# sampling
# done in 0.369 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0617          0
#          1    0.00589     0.0436
#          2     0.0306      0.161
#          3    0.00628      0.355
#          4    0.00594      0.401
#          5    0.00168      0.546
#          6    0.00914      0.616
#          7     0.0015      0.777
#          8   0.000372      0.864
#          9   0.000341       1.06
#         10    0.00144       1.08
# done in 0.015 seconds
# Expected: 0.036 Actual: 0.037
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 493         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 62          |
# | TimeElapsed             | 12.9        |
# | TimestepsSoFar          | 30720       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9187795   |
# | explained_variance_t... | 0.082       |
# | meankl                  | 0.011520205 |
# | optimgain               | 0.0370351   |
# | surrgain                | 0.0370351   |
# -----------------------------------------
# ********** Iteration 30 ************
# Optimizing Policy...
# sampling
# done in 0.368 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.011          0
#          1    0.00237     0.0216
#          2    0.00374     0.0451
#          3    0.00237      0.171
#          4    0.00707      0.268
#          5    0.00123      0.418
#          6    0.00163      0.438
#          7   0.000398      0.566
#          8   0.000269      0.661
#          9   0.000131      0.725
#         10   0.000687      0.733
# done in 0.016 seconds
# Expected: 0.021 Actual: 0.021
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 493         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 64          |
# | TimeElapsed             | 13.3        |
# | TimestepsSoFar          | 31744       |
# | entloss                 | 0.0         |
# | entropy                 | 0.922063    |
# | explained_variance_t... | -0.000543   |
# | meankl                  | 0.008278182 |
# | optimgain               | 0.020551883 |
# | surrgain                | 0.020551883 |
# -----------------------------------------
# ********** Iteration 31 ************
# Optimizing Policy...
# sampling
# done in 0.362 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0153          0
#          1    0.00899     0.0405
#          2     0.0254      0.147
#          3    0.00804      0.223
#          4    0.00946       0.31
#          5    0.00616       0.44
#          6    0.00281      0.479
#          7    0.00386      0.703
#          8    0.00192       1.23
#          9    0.00119       1.45
#         10    0.00864       1.58
# done in 0.014 seconds
# Expected: 0.038 Actual: 0.042
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 493         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 66          |
# | TimeElapsed             | 13.7        |
# | TimestepsSoFar          | 32768       |
# | entloss                 | 0.0         |
# | entropy                 | 0.8847737   |
# | explained_variance_t... | 0.019       |
# | meankl                  | 0.010581214 |
# | optimgain               | 0.04180934  |
# | surrgain                | 0.04180934  |
# -----------------------------------------
# ********** Iteration 32 ************
# Optimizing Policy...
# sampling
# done in 0.363 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.032          0
#          1     0.0149     0.0343
#          2     0.0177     0.0664
#          3     0.0112       0.16
#          4    0.00925      0.251
#          5    0.00706       0.36
#          6    0.00805      0.499
#          7    0.00372       1.02
#          8    0.00183       1.22
#          9    0.00576       1.41
#         10    0.00153       1.43
# done in 0.015 seconds
# Expected: 0.040 Actual: 0.036
# Stepsize OK!
# vf
# done in 0.021 seconds
# ----------------------------------------
# | EpLenMean               | 495        |
# | EpRewMean               | -494       |
# | EpThisIter              | 2          |
# | EpisodesSoFar           | 68         |
# | TimeElapsed             | 14.1       |
# | TimestepsSoFar          | 33792      |
# | entloss                 | 0.0        |
# | entropy                 | 0.84739256 |
# | explained_variance_t... | -0.268     |
# | meankl                  | 0.01227621 |
# | optimgain               | 0.0358648  |
# | surrgain                | 0.0358648  |
# ----------------------------------------
# ********** Iteration 33 ************
# Optimizing Policy...
# sampling
# done in 0.364 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0228          0
#          1     0.0253     0.0342
#          2     0.0239      0.088
#          3    0.00796      0.247
#          4     0.0125      0.348
#          5    0.00774      0.419
#          6    0.00488      0.527
#          7    0.00544      0.637
#          8     0.0024      0.886
#          9       0.01       1.14
#         10    0.00262       1.17
# done in 0.016 seconds
# Expected: 0.038 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 495         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 70          |
# | TimeElapsed             | 14.5        |
# | TimestepsSoFar          | 34816       |
# | entloss                 | 0.0         |
# | entropy                 | 0.8788029   |
# | explained_variance_t... | 0.132       |
# | meankl                  | 0.010547789 |
# | optimgain               | 0.03828667  |
# | surrgain                | 0.03828667  |
# -----------------------------------------
# ********** Iteration 34 ************
# Optimizing Policy...
# sampling
# done in 0.351 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0678          0
#          1     0.0197     0.0254
#          2    0.00999     0.0541
#          3     0.0124      0.171
#          4     0.0098      0.233
#          5    0.00924      0.385
#          6    0.00504      0.549
#          7    0.00393      0.722
#          8    0.00693      0.835
#          9    0.00584      0.858
#         10    0.00188       1.03
# done in 0.013 seconds
# Expected: 0.036 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 495         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 72          |
# | TimeElapsed             | 14.9        |
# | TimestepsSoFar          | 35840       |
# | entloss                 | 0.0         |
# | entropy                 | 0.88760144  |
# | explained_variance_t... | 0.000439    |
# | meankl                  | 0.008756842 |
# | optimgain               | 0.03204401  |
# | surrgain                | 0.03204401  |
# -----------------------------------------
# ********** Iteration 35 ************
# Optimizing Policy...
# sampling
# done in 0.365 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00876          0
#          1     0.0264     0.0317
#          2     0.0131      0.109
#          3     0.0173      0.218
#          4    0.00957      0.312
#          5    0.00667      0.414
#          6    0.00327      0.633
#          7    0.00544      0.849
#          8    0.00403       1.01
#          9    0.00214       1.02
#         10    0.00335       1.28
# done in 0.016 seconds
# Expected: 0.036 Actual: 0.031
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 495         |
# | EpRewMean               | -494        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 74          |
# | TimeElapsed             | 15.3        |
# | TimestepsSoFar          | 36864       |
# | entloss                 | 0.0         |
# | entropy                 | 0.83763623  |
# | explained_variance_t... | 0.0263      |
# | meankl                  | 0.009223679 |
# | optimgain               | 0.03115117  |
# | surrgain                | 0.03115117  |
# -----------------------------------------
# ********** Iteration 36 ************
# Optimizing Policy...
# sampling
# done in 0.364 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.107          0
#          1     0.0247     0.0315
#          2     0.0288       0.11
#          3     0.0162      0.212
#          4     0.0122      0.295
#          5    0.00767       0.43
#          6     0.0085       0.69
#          7     0.0038      0.959
#          8      0.051       1.09
#          9      0.006       1.33
#         10    0.00839       1.56
# done in 0.014 seconds
# Expected: 0.048 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.019 seconds
# ----------------------------------------
# | EpLenMean               | 494        |
# | EpRewMean               | -494       |
# | EpThisIter              | 2          |
# | EpisodesSoFar           | 76         |
# | TimeElapsed             | 15.7       |
# | TimestepsSoFar          | 37888      |
# | entloss                 | 0.0        |
# | entropy                 | 0.8609921  |
# | explained_variance_t... | 0.0326     |
# | meankl                  | 0.00965306 |
# | optimgain               | 0.04142681 |
# | surrgain                | 0.04142681 |
# ----------------------------------------
# ********** Iteration 37 ************
# Optimizing Policy...
# sampling
# done in 0.362 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0201          0
#          1     0.0255     0.0318
#          2     0.0279      0.108
#          3     0.0184      0.266
#          4    0.00998      0.343
#          5    0.00605      0.452
#          6    0.00587      0.588
#          7    0.00675      0.833
#          8    0.00257       1.01
#          9      0.014       1.04
#         10    0.00313       1.21
# done in 0.015 seconds
# Expected: 0.040 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 494         |
# | EpRewMean               | -493        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 78          |
# | TimeElapsed             | 16.1        |
# | TimestepsSoFar          | 38912       |
# | entloss                 | 0.0         |
# | entropy                 | 0.85916436  |
# | explained_variance_t... | 0.18        |
# | meankl                  | 0.009338274 |
# | optimgain               | 0.03415791  |
# | surrgain                | 0.03415791  |
# -----------------------------------------
# ********** Iteration 38 ************
# Optimizing Policy...
# sampling
# done in 0.371 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0614          0
#          1     0.0174       0.07
#          2     0.0124      0.165
#          3     0.0281      0.206
#          4     0.0121      0.337
#          5    0.00942      0.446
#          6    0.00624      0.541
#          7    0.00503      0.801
#          8    0.00346       1.11
#          9    0.00516       1.34
#         10     0.0182       1.42
# done in 0.016 seconds
# Expected: 0.045 Actual: 0.045
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 488          |
# | EpRewMean               | -488         |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 81           |
# | TimeElapsed             | 16.6         |
# | TimestepsSoFar          | 39936        |
# | entloss                 | 0.0          |
# | entropy                 | 0.79134      |
# | explained_variance_t... | 0.0177       |
# | meankl                  | 0.0106154075 |
# | optimgain               | 0.044511236  |
# | surrgain                | 0.044511236  |
# ------------------------------------------
# ********** Iteration 39 ************
# Optimizing Policy...
# sampling
# done in 0.354 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.015          0
#          1     0.0315     0.0468
# ...
#          5      0.021      0.554
#          6     0.0032      0.811
#          7    0.00481       1.11
#          8    0.00219        1.3
#          9     0.0394       1.51
#         10    0.00181       1.86
# done in 0.016 seconds
# Expected: 0.042 Actual: 0.031
# violated KL constraint. shrinking step.
# Expected: 0.042 Actual: 0.019
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 104         |
# | EpRewMean               | -103        |
# | EpThisIter              | 9           |
# | EpisodesSoFar           | 888         |
# | TimeElapsed             | 80.1        |
# | TimestepsSoFar          | 188416      |
# | entloss                 | 0.0         |
# | entropy                 | 0.38860995  |
# | explained_variance_t... | 0.66        |
# | meankl                  | 0.004285816 |
# | optimgain               | 0.018769635 |
# | surrgain                | 0.018769635 |
# -----------------------------------------
# ********** Iteration 184 ************
# Optimizing Policy...
# sampling
# done in 0.369 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0204          0
#          1     0.0332     0.0943
#          2     0.0174      0.149
#          3     0.0123      0.201
#          4     0.0172      0.353
#          5     0.0116      0.565
#          6    0.00898      0.636
#          7    0.00677      0.958
#          8    0.00884       1.45
#          9    0.00385        1.7
#         10     0.0306       1.83
# done in 0.015 seconds
# Expected: 0.048 Actual: 0.042
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 104         |
# | EpRewMean               | -103        |
# | EpThisIter              | 10          |
# | EpisodesSoFar           | 898         |
# | TimeElapsed             | 80.6        |
# | TimestepsSoFar          | 189440      |
# | entloss                 | 0.0         |
# | entropy                 | 0.4267215   |
# | explained_variance_t... | 0.741       |
# | meankl                  | 0.009783779 |
# | optimgain               | 0.041756585 |
# | surrgain                | 0.041756585 |
# -----------------------------------------
# ********** Iteration 185 ************
# Optimizing Policy...
# sampling
# done in 0.369 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0211          0
#          1     0.0114     0.0452
#          2     0.0147     0.0782
#          3     0.0123      0.184
#          4     0.0112      0.359
#          5     0.0157      0.477
#          6    0.00439      0.621
#          7    0.00637      0.861
#          8    0.00495       1.27
#          9    0.00407       1.54
#         10     0.0312       1.81
# done in 0.015 seconds
# Expected: 0.043 Actual: 0.039
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 100         |
# | EpRewMean               | -99         |
# | EpThisIter              | 11          |
# | EpisodesSoFar           | 909         |
# | TimeElapsed             | 81          |
# | TimestepsSoFar          | 190464      |
# | entloss                 | 0.0         |
# | entropy                 | 0.40725088  |
# | explained_variance_t... | 0.822       |
# | meankl                  | 0.014482629 |
# | optimgain               | 0.038788244 |
# | surrgain                | 0.038788244 |
# -----------------------------------------
# ********** Iteration 186 ************
# Optimizing Policy...
# sampling
# done in 0.366 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0297          0
#          1      0.013     0.0281
#          2      0.018      0.126
#          3      0.011      0.238
#          4     0.0122      0.363
#          5    0.00553      0.425
#          6    0.00614      0.614
#          7    0.00344       0.78
#          8    0.00285       1.03
#          9    0.00886       1.21
#         10    0.00242       1.25
# done in 0.020 seconds
# Expected: 0.039 Actual: 0.037
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 98.4        |
# | EpRewMean               | -97.4       |
# | EpThisIter              | 11          |
# | EpisodesSoFar           | 920         |
# | TimeElapsed             | 81.4        |
# | TimestepsSoFar          | 191488      |
# | entloss                 | 0.0         |
# | entropy                 | 0.3941519   |
# | explained_variance_t... | 0.843       |
# | meankl                  | 0.009427906 |
# | optimgain               | 0.03686343  |
# | surrgain                | 0.03686343  |
# -----------------------------------------
# ********** Iteration 187 ************
# Optimizing Policy...
# sampling
# done in 0.347 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.013          0
#          1     0.0107     0.0407
#          2     0.0194      0.183
#          3     0.0194      0.267
#          4     0.0129       0.34
#          5     0.0155      0.503
#          6    0.00759      0.896
#          7    0.00669       1.18
#          8    0.00551       1.46
#          9    0.00284       1.79
#         10     0.0228       1.96
# done in 0.015 seconds
# Expected: 0.046 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.017 seconds
# -----------------------------------------
# | EpLenMean               | 96.2        |
# | EpRewMean               | -95.2       |
# | EpThisIter              | 10          |
# | EpisodesSoFar           | 930         |
# | TimeElapsed             | 81.8        |
# | TimestepsSoFar          | 192512      |
# | entloss                 | 0.0         |
# | entropy                 | 0.39759925  |
# | explained_variance_t... | 0.857       |
# | meankl                  | 0.011680726 |
# | optimgain               | 0.03337371  |
# | surrgain                | 0.03337371  |
# -----------------------------------------
# ********** Iteration 188 ************
# Optimizing Policy...
# sampling
# done in 0.366 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0876          0
#          1     0.0213     0.0427
#          2    0.00891     0.0772
#          3    0.00754       0.12
#          4     0.0113      0.184
#          5    0.00806      0.296
#          6    0.00444      0.471
#          7     0.0037      0.904
#          8    0.00198       1.25
#          9    0.00968       1.37
#         10    0.00203       1.42
# done in 0.016 seconds
# Expected: 0.040 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 95.9        |
# | EpRewMean               | -94.9       |
# | EpThisIter              | 11          |
# | EpisodesSoFar           | 941         |
# | TimeElapsed             | 82.2        |
# | TimestepsSoFar          | 193536      |
# | entloss                 | 0.0         |
# | entropy                 | 0.36258313  |
# | explained_variance_t... | 0.87        |
# | meankl                  | 0.009945113 |
# | optimgain               | 0.032890894 |
# | surrgain                | 0.032890894 |
# -----------------------------------------
# ********** Iteration 189 ************
# Optimizing Policy...
# sampling
# done in 0.395 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0206          0
#          1     0.0152      0.037
#          2     0.0245      0.135
#          3     0.0127      0.255
#          4      0.012      0.493
#          5     0.0134      0.841
#          6    0.00857      0.935
#          7     0.0033       1.56
#          8    0.00618          2
#          9     0.0126       2.37
#         10    0.00419       2.43
# done in 0.015 seconds
# Expected: 0.053 Actual: 0.043
# violated KL constraint. shrinking step.
# Expected: 0.053 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.018 seconds
# ------------------------------------------
# | EpLenMean               | 97.3         |
# | EpRewMean               | -96.3        |
# | EpThisIter              | 10           |
# | EpisodesSoFar           | 951          |
# | TimeElapsed             | 82.6         |
# | TimestepsSoFar          | 194560       |
# | entloss                 | 0.0          |
# | entropy                 | 0.34255207   |
# | explained_variance_t... | 0.786        |
# | meankl                  | 0.0050073313 |
# | optimgain               | 0.025283325  |
# | surrgain                | 0.025283325  |
# ------------------------------------------
# ********** Iteration 190 ************
# Optimizing Policy...
# sampling
# done in 0.384 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0339          0
#          1     0.0127     0.0465
#          2     0.0275       0.14
#          3     0.0184      0.237
#          4     0.0364      0.408
#          5     0.0112      0.593
#          6    0.00803       1.11
#          7     0.0084       1.49
#          8    0.00535       1.85
#          9    0.00521       2.03
#         10    0.00754       2.53
# done in 0.014 seconds
# Expected: 0.056 Actual: 0.090
# violated KL constraint. shrinking step.
# Expected: 0.056 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.017 seconds
# ------------------------------------------
# | EpLenMean               | 95.2         |
# | EpRewMean               | -94.2        |
# | EpThisIter              | 12           |
# | EpisodesSoFar           | 963          |
# | TimeElapsed             | 83.1         |
# | TimestepsSoFar          | 195584       |
# | entloss                 | 0.0          |
# | entropy                 | 0.37670088   |
# | explained_variance_t... | 0.878        |
# | meankl                  | 0.0046466785 |
# | optimgain               | 0.034368373  |
# | surrgain                | 0.034368373  |
# ------------------------------------------
# ********** Iteration 191 ************
# Optimizing Policy...
# sampling
# done in 0.358 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0197          0
#          1     0.0197     0.0494
#          2     0.0134     0.0937
#          3     0.0137       0.16
#          4    0.00673      0.272
#          5      0.012      0.507
#          6    0.00868      0.668
#          7    0.00336      0.956
#          8    0.00758       1.51
#          9    0.00757       1.83
#         10    0.00214       1.86
# done in 0.015 seconds
# Expected: 0.044 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 101         |
# | EpRewMean               | -99.6       |
# | EpThisIter              | 8           |
# | EpisodesSoFar           | 971         |
# | TimeElapsed             | 83.5        |
# | TimestepsSoFar          | 196608      |
# | entloss                 | 0.0         |
# | entropy                 | 0.36169767  |
# | explained_variance_t... | 0.304       |
# | meankl                  | 0.012874759 |
# | optimgain               | 0.025046635 |
# | surrgain                | 0.025046635 |
# -----------------------------------------
# ********** Iteration 192 ************
# Optimizing Policy...
# sampling
# done in 0.374 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0185          0
#          1     0.0124     0.0391
#          2     0.0147      0.122
#          3    0.00562      0.179
#          4     0.0102      0.252
#          5    0.00364      0.343
#          6      0.004      0.504
#          7    0.00546      0.714
#          8    0.00328       1.07
#          9    0.00189       1.37
#         10    0.00907        1.6
# done in 0.015 seconds
# Expected: 0.038 Actual: 0.029
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 96.7        |
# | EpRewMean               | -95.7       |
# | EpThisIter              | 12          |
# | EpisodesSoFar           | 983         |
# | TimeElapsed             | 83.9        |
# | TimestepsSoFar          | 197632      |
# | entloss                 | 0.0         |
# | entropy                 | 0.33907714  |
# | explained_variance_t... | 0.831       |
# | meankl                  | 0.010996289 |
# | optimgain               | 0.029404175 |
# | surrgain                | 0.029404175 |
# -----------------------------------------
# ********** Iteration 193 ************
# Optimizing Policy...
# sampling
# done in 0.384 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0547          0
#          1     0.0246     0.0624
#          2      0.016       0.12
#          3     0.0111      0.208
#          4     0.0153      0.375
#          5     0.0273      0.603
#          6    0.00812       1.12
#          7    0.00396       1.45
#          8    0.00459       1.78
#          9    0.00314       1.99
#         10     0.0041       2.23
# done in 0.014 seconds
# Expected: 0.054 Actual: 0.033
# violated KL constraint. shrinking step.
# Expected: 0.054 Actual: 0.021
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 96.4        |
# | EpRewMean               | -95.4       |
# | EpThisIter              | 11          |
# | EpisodesSoFar           | 994         |
# | TimeElapsed             | 84.3        |
# | TimestepsSoFar          | 198656      |
# | entloss                 | 0.0         |
# | entropy                 | 0.34249657  |
# | explained_variance_t... | 0.86        |
# | meankl                  | 0.00439631  |
# | optimgain               | 0.021247275 |
# | surrgain                | 0.021247275 |
# -----------------------------------------
# ********** Iteration 194 ************
# Optimizing Policy...
# sampling
# done in 0.390 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0165          0
#          1     0.0241      0.113
#          2     0.0374      0.259
#          3     0.0216      0.391
#          4      0.042      0.562
#          5     0.0187      0.898
#          6     0.0129       1.26
#          7     0.0132       1.74
#          8    0.00903       2.63
#          9    0.00379       3.05
#         10    0.00555       3.49
# done in 0.018 seconds
# Expected: 0.068 Actual: 0.033
# violated KL constraint. shrinking step.
# Expected: 0.068 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 102         |
# | EpRewMean               | -101        |
# | EpThisIter              | 9           |
# | EpisodesSoFar           | 1003        |
# | TimeElapsed             | 84.8        |
# | TimestepsSoFar          | 199680      |
# | entloss                 | 0.0         |
# | entropy                 | 0.31295174  |
# | explained_variance_t... | 0.56        |
# | meankl                  | 0.012394037 |
# | optimgain               | 0.019632014 |
# | surrgain                | 0.019632014 |
# -----------------------------------------
# ********** Iteration 195 ************
# Optimizing Policy...
# sampling
# done in 0.361 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0128          0
#          1     0.0201     0.0938
#          2     0.0207      0.219
#          3    0.00927      0.295
#          4     0.0235      0.443
#          5      0.014      0.734
#          6     0.0135       1.03
#          7    0.00418       1.45
#          8     0.0056       1.76
#          9    0.00207       2.13
#         10    0.00555       2.32
# done in 0.015 seconds
# Expected: 0.052 Actual: 0.070
# violated KL constraint. shrinking step.
# Expected: 0.052 Actual: 0.029
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 96.5         |
# | EpRewMean               | -95.5        |
# | EpThisIter              | 11           |
# | EpisodesSoFar           | 1014         |
# | TimeElapsed             | 85.2         |
# | TimestepsSoFar          | 200704       |
# | entloss                 | 0.0          |
# | entropy                 | 0.3326221    |
# | explained_variance_t... | 0.774        |
# | meankl                  | 0.0036159318 |
# | optimgain               | 0.02901154   |
# | surrgain                | 0.02901154   |
# ------------------------------------------

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_EPISODES, "TRPO")
plt.show()
