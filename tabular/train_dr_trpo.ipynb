# %%
import gym
import pybullet
import pybullet_envs
from gym import wrappers
from datetime import datetime

# DR TRPO related files
from train_helper import *
from value import NNValueFunction
from utils import Logger
from dr_policy import DRPolicyKL, DRPolicyWass

# %% [markdown]
# # Discrete State Space - KL DR TRPO Policy
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyKL(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 5000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-KL_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 60, Mean Return = -765.9, Mean Discounted Return = -39.9 *****
# ExplainedVarNew: -8.31e-09
# ExplainedVarOld: -4.01e-06
# ValFuncLoss: 676
#
#
# ***** Episode 120, Mean Return = -499.3, Mean Discounted Return = -29.1 *****
# ExplainedVarNew: -8.27e-10
# ExplainedVarOld: -8.8e-09
# ValFuncLoss: 108
#
#
# ***** Episode 180, Mean Return = -305.3, Mean Discounted Return = -20.1 *****
# ExplainedVarNew: -1.35e-08
# ExplainedVarOld: -3.09e-09
# ValFuncLoss: 103
#
#
# ***** Episode 240, Mean Return = -254.0, Mean Discounted Return = -15.9 *****
# ExplainedVarNew: -0.00981
# ExplainedVarOld: -2.01e-08
# ValFuncLoss: 49
#
#
# ***** Episode 300, Mean Return = -182.4, Mean Discounted Return = -12.0 *****
# ExplainedVarNew: -0.00545
# ExplainedVarOld: -0.0155
# ValFuncLoss: 29.4
#
#
# ***** Episode 360, Mean Return = -171.2, Mean Discounted Return = -13.6 *****
# ExplainedVarNew: -0.0015
# ExplainedVarOld: -0.0041
# ValFuncLoss: 26.6
#
#
# ***** Episode 420, Mean Return = -142.7, Mean Discounted Return = -11.1 *****
# ExplainedVarNew: -0.00177
# ExplainedVarOld: -0.000637
# ValFuncLoss: 26
#
#
# ***** Episode 480, Mean Return = -81.9, Mean Discounted Return = -8.0 *****
# ExplainedVarNew: -0.0237
# ExplainedVarOld: -0.00162
# ValFuncLoss: 47.8
#
#
# ***** Episode 540, Mean Return = -97.6, Mean Discounted Return = -9.7 *****
# ExplainedVarNew: -0.0118
# ExplainedVarOld: -0.0154
# ValFuncLoss: 33.2
#
#
# ***** Episode 600, Mean Return = -54.6, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.0169
# ExplainedVarOld: -0.0154
# ValFuncLoss: 53.7
#
#
# ***** Episode 660, Mean Return = -48.5, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.018
# ExplainedVarOld: -0.0196
# ValFuncLoss: 58.4
#
#
# ***** Episode 720, Mean Return = -57.4, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.0127
# ExplainedVarOld: -0.0157
# ValFuncLoss: 50.2
#
#
# ***** Episode 780, Mean Return = -44.8, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.00905
# ExplainedVarOld: -0.00994
# ValFuncLoss: 65.9
#
#
# ***** Episode 840, Mean Return = -49.6, Mean Discounted Return = -5.2 *****
# ExplainedVarNew: -0.0182
# ExplainedVarOld: -0.0144
# ValFuncLoss: 63.8
#
#
# ***** Episode 900, Mean Return = -32.5, Mean Discounted Return = -5.9 *****
# ExplainedVarNew: -0.0123
# ExplainedVarOld: -0.0116
# ValFuncLoss: 71.4
#
#
# ***** Episode 960, Mean Return = -32.5, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.0227
# ExplainedVarOld: -0.0249
# ValFuncLoss: 72.8
#
#
# ***** Episode 1020, Mean Return = -39.8, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.015
# ExplainedVarOld: -0.0107
# ValFuncLoss: 74.4
#
#
# ***** Episode 1080, Mean Return = -36.1, Mean Discounted Return = -5.2 *****
# ExplainedVarNew: -0.0374
# ExplainedVarOld: -0.0368
# ValFuncLoss: 71.1
#
#
# ***** Episode 1140, Mean Return = -33.8, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.0266
# ExplainedVarOld: -0.0304
# ValFuncLoss: 82.6
#
#
# ***** Episode 1200, Mean Return = -24.6, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.01
# ExplainedVarOld: -0.00994
# ValFuncLoss: 108
#
#
# ***** Episode 1260, Mean Return = -10.1, Mean Discounted Return = -3.4 *****
# ExplainedVarNew: -0.0197
# ExplainedVarOld: -0.0197
# ValFuncLoss: 98.5
#
#
# ***** Episode 1320, Mean Return = -21.8, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0457
# ExplainedVarOld: -0.0316
# ValFuncLoss: 88.3
#
#
# ***** Episode 1380, Mean Return = -19.6, Mean Discounted Return = -5.1 *****
# ExplainedVarNew: -0.00487
# ExplainedVarOld: -0.00422
# ValFuncLoss: 120
#
#
# ***** Episode 1440, Mean Return = -14.6, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.00801
# ExplainedVarOld: -0.00847
# ValFuncLoss: 129
#
#
# ***** Episode 1500, Mean Return = -12.4, Mean Discounted Return = -4.8 *****
# ExplainedVarNew: -0.0244
# ExplainedVarOld: -0.00693
# ValFuncLoss: 110
#
#
# ***** Episode 1560, Mean Return = -13.1, Mean Discounted Return = -4.1 *****
# ExplainedVarNew: -0.0478
# ExplainedVarOld: -0.0406
# ValFuncLoss: 127
#
#
# ***** Episode 1620, Mean Return = -27.6, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.00501
# ExplainedVarOld: -0.00913
# ValFuncLoss: 162
#
#
# ***** Episode 1680, Mean Return = -14.1, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0429
# ExplainedVarOld: -0.00986
# ValFuncLoss: 134
#
#
# ***** Episode 1740, Mean Return = -32.2, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0447
# ExplainedVarOld: -0.0408
# ValFuncLoss: 90.3
#
#
# ***** Episode 1800, Mean Return = -4.8, Mean Discounted Return = -3.1 *****
# ExplainedVarNew: -0.0535
# ExplainedVarOld: -0.0665
# ValFuncLoss: 111
#
#
# ***** Episode 1860, Mean Return = -14.9, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0352
# ExplainedVarOld: -0.0373
# ValFuncLoss: 151
#
#
# ***** Episode 1920, Mean Return = 0.3, Mean Discounted Return = -3.4 *****
# ExplainedVarNew: -0.0499
# ExplainedVarOld: -0.0768
# ValFuncLoss: 104
#
#
# ***** Episode 1980, Mean Return = -23.1, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0181
# ExplainedVarOld: -0.0153
# ValFuncLoss: 156
#
#
# ***** Episode 2040, Mean Return = -13.5, Mean Discounted Return = -5.3 *****
# ExplainedVarNew: -0.0504
# ExplainedVarOld: -0.032
# ValFuncLoss: 160
#
#
# ***** Episode 2100, Mean Return = -2.6, Mean Discounted Return = -3.3 *****
# ExplainedVarNew: -0.0939
# ExplainedVarOld: -0.0753
# ValFuncLoss: 119
#
#
# ***** Episode 2160, Mean Return = -13.0, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0286
# ExplainedVarOld: -0.0293
# ValFuncLoss: 152
#
#
# ***** Episode 2220, Mean Return = -3.3, Mean Discounted Return = -4.2 *****
# ExplainedVarNew: -0.0644
# ExplainedVarOld: -0.0467
# ValFuncLoss: 135
#
#
# ***** Episode 2280, Mean Return = -6.6, Mean Discounted Return = -2.8 *****
# ExplainedVarNew: -0.0586
# ExplainedVarOld: -0.0488
# ValFuncLoss: 144
#
#
# ***** Episode 2340, Mean Return = -4.0, Mean Discounted Return = -3.1 *****
# ExplainedVarNew: -0.0225
# ExplainedVarOld: -0.0192
# ValFuncLoss: 246
#
#
# ***** Episode 2400, Mean Return = -17.0, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -0.0198
# ExplainedVarOld: -0.0185
# ValFuncLoss: 200
#
#
# ***** Episode 2460, Mean Return = -1.2, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0562
# ExplainedVarOld: -0.0508
# ValFuncLoss: 132
#
#
# ***** Episode 2520, Mean Return = -13.9, Mean Discounted Return = -5.5 *****
# ExplainedVarNew: -0.0488
# ExplainedVarOld: -0.0532
# ValFuncLoss: 99.3
#
#
# ***** Episode 2580, Mean Return = 4.3, Mean Discounted Return = -2.8 *****
# ExplainedVarNew: -0.0849
# ExplainedVarOld: -0.0797
# ValFuncLoss: 108
#
#
# ***** Episode 2640, Mean Return = -11.9, Mean Discounted Return = -7.0 *****
# ExplainedVarNew: -0.0847
# ExplainedVarOld: -0.0502
# ValFuncLoss: 180
#
#
# ***** Episode 2700, Mean Return = -14.1, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0405
# ExplainedVarOld: -0.038
# ValFuncLoss: 196
#
#
# ***** Episode 2760, Mean Return = -26.8, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.0304
# ExplainedVarOld: -0.0372
# ValFuncLoss: 241
#
#
# ***** Episode 2820, Mean Return = -4.7, Mean Discounted Return = -5.5 *****
# ExplainedVarNew: -0.0766
# ExplainedVarOld: -0.0749
# ValFuncLoss: 155
#
#
# ***** Episode 2880, Mean Return = -16.0, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.202
# ExplainedVarOld: -0.0594
# ValFuncLoss: 139
#
#
# ***** Episode 2940, Mean Return = -8.6, Mean Discounted Return = -4.3 *****
# ExplainedVarNew: -0.0816
# ExplainedVarOld: -0.112
# ValFuncLoss: 165
#
#
# ***** Episode 3000, Mean Return = -11.7, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.0111
# ExplainedVarOld: -0.0117
# ValFuncLoss: 505
#
#
# ***** Episode 3060, Mean Return = -16.1, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -0.0269
# ExplainedVarOld: -0.0185
# ValFuncLoss: 305
#
#
# ***** Episode 3120, Mean Return = 4.1, Mean Discounted Return = -2.7 *****
# ExplainedVarNew: -0.106
# ExplainedVarOld: -0.132
# ValFuncLoss: 132
#
#
# ***** Episode 3180, Mean Return = -11.1, Mean Discounted Return = -5.3 *****
# ExplainedVarNew: -0.061
# ExplainedVarOld: -0.062
# ValFuncLoss: 136
#
#
# ***** Episode 3240, Mean Return = -8.9, Mean Discounted Return = -5.2 *****
# ExplainedVarNew: -0.0556
# ExplainedVarOld: -0.0553
# ValFuncLoss: 111
#
#
# ***** Episode 3300, Mean Return = -10.7, Mean Discounted Return = -3.3 *****
# ExplainedVarNew: -0.0258
# ExplainedVarOld: -0.0276
# ValFuncLoss: 118
#
#
# ***** Episode 3360, Mean Return = -13.2, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.0347
# ExplainedVarOld: -0.0318
# ValFuncLoss: 164
# ***** Episode 3420, Mean Return = -27.8, Mean Discounted Return = -6.0 *****
# ExplainedVarNew: -0.0228
# ExplainedVarOld: -0.0205
# ValFuncLoss: 197
#
#
# ***** Episode 3480, Mean Return = -5.6, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.049
# ExplainedVarOld: -0.048
# ValFuncLoss: 150
#
#
# ***** Episode 3540, Mean Return = -15.2, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0276
# ExplainedVarOld: -0.0351
# ValFuncLoss: 208
#
#
# ***** Episode 3600, Mean Return = -21.0, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0297
# ExplainedVarOld: -0.0238
# ValFuncLoss: 221
#
#
# ***** Episode 3660, Mean Return = -7.1, Mean Discounted Return = -3.8 *****
# ExplainedVarNew: -0.0413
# ExplainedVarOld: -0.0487
# ValFuncLoss: 194
#
#
# ***** Episode 3720, Mean Return = -6.6, Mean Discounted Return = -4.8 *****
# ExplainedVarNew: -0.0386
# ExplainedVarOld: -0.049
# ValFuncLoss: 179
#
#
# ***** Episode 3780, Mean Return = -16.1, Mean Discounted Return = -8.0 *****
# ExplainedVarNew: -0.0577
# ExplainedVarOld: -0.0408
# ValFuncLoss: 124
#
#
# ***** Episode 3840, Mean Return = -19.3, Mean Discounted Return = -4.7 *****
# ExplainedVarNew: -0.0209
# ExplainedVarOld: -0.0146
# ValFuncLoss: 280
#
#
# ***** Episode 3900, Mean Return = -10.1, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.0653
# ExplainedVarOld: -0.0847
# ValFuncLoss: 134
#
#
# ***** Episode 3960, Mean Return = -15.0, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.0237
# ExplainedVarOld: -0.0284
# ValFuncLoss: 165
#
#
# ***** Episode 4020, Mean Return = 0.7, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0786
# ExplainedVarOld: -0.0879
# ValFuncLoss: 107
#
#
# ***** Episode 4080, Mean Return = -17.5, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0244
# ExplainedVarOld: -0.0246
# ValFuncLoss: 169
#
#
# ***** Episode 4140, Mean Return = -2.3, Mean Discounted Return = -3.2 *****
# ExplainedVarNew: -0.0401
# ExplainedVarOld: -0.0351
# ValFuncLoss: 116
#
#
# ***** Episode 4200, Mean Return = -7.6, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0313
# ExplainedVarOld: -0.035
# ValFuncLoss: 112
#
#
# ***** Episode 4260, Mean Return = -18.2, Mean Discounted Return = -6.8 *****
# ExplainedVarNew: -0.0964
# ExplainedVarOld: -0.0244
# ValFuncLoss: 178
#
#
# ***** Episode 4320, Mean Return = -10.6, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0382
# ExplainedVarOld: -0.0356
# ValFuncLoss: 237
#
#
# ***** Episode 4380, Mean Return = -10.8, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.09
# ExplainedVarOld: -0.0733
# ValFuncLoss: 150
#
#
# ***** Episode 4440, Mean Return = -15.4, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.104
# ExplainedVarOld: -0.103
# ValFuncLoss: 161
#
#
# ***** Episode 4500, Mean Return = -2.3, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.134
# ExplainedVarOld: -0.116
# ValFuncLoss: 139
#
#
# ***** Episode 4560, Mean Return = -3.7, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -0.0573
# ExplainedVarOld: -0.0491
# ValFuncLoss: 138
#
#
# ***** Episode 4620, Mean Return = -10.7, Mean Discounted Return = -5.3 *****
# ExplainedVarNew: -0.17
# ExplainedVarOld: -0.159
# ValFuncLoss: 188
#
#
# ***** Episode 4680, Mean Return = -18.5, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.164
# ExplainedVarOld: -0.187
# ValFuncLoss: 159
#
#
# ***** Episode 4740, Mean Return = -22.4, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.0594
# ExplainedVarOld: -0.105
# ValFuncLoss: 132
#
#
# ***** Episode 4800, Mean Return = -25.1, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.0324
# ExplainedVarOld: -0.0316
# ValFuncLoss: 193
#
#
# ***** Episode 4860, Mean Return = -5.8, Mean Discounted Return = -4.7 *****
# ExplainedVarNew: -0.0858
# ExplainedVarOld: -0.0922
# ValFuncLoss: 138
#
#
# ***** Episode 4920, Mean Return = -6.4, Mean Discounted Return = -3.1 *****
# ExplainedVarNew: -0.0526
# ExplainedVarOld: -0.0687
# ValFuncLoss: 165
#
#
# ***** Episode 4980, Mean Return = -1.4, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0433
# ExplainedVarOld: -0.0546
# ValFuncLoss: 146
#
#
# ***** Episode 5040, Mean Return = -7.6, Mean Discounted Return = -4.9 *****
# ExplainedVarNew: -0.0406
# ExplainedVarOld: -0.0389
# ValFuncLoss: 177

# %% [markdown]
# # Discrete State Space - Wasserstein DR TRPO Policy
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyWass(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 5000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-Wass_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 60, Mean Return = -793.4, Mean Discounted Return = -39.0 *****
# ExplainedVarNew: -8.92e-10
# ExplainedVarOld: -5.32e-08
# ValFuncLoss: 742
#
#
# ***** Episode 120, Mean Return = -803.1, Mean Discounted Return = -38.2 *****
# ExplainedVarNew: -6.52e-12
# ExplainedVarOld: -9.67e-11
# ValFuncLoss: 392
#
#
# ***** Episode 180, Mean Return = -825.6, Mean Discounted Return = -38.8 *****
# ExplainedVarNew: -5.6e-12
# ExplainedVarOld: -1.29e-11
# ValFuncLoss: 243
#
#
# ***** Episode 240, Mean Return = -797.5, Mean Discounted Return = -38.6 *****
# ExplainedVarNew: -9.44e-12
# ExplainedVarOld: -9.33e-12
# ValFuncLoss: 297
#
#
# ***** Episode 300, Mean Return = -689.1, Mean Discounted Return = -35.1 *****
# ExplainedVarNew: -2.54e-11
# ExplainedVarOld: -7.79e-12
# ValFuncLoss: 185
#
#
# ***** Episode 360, Mean Return = -659.3, Mean Discounted Return = -36.4 *****
# ExplainedVarNew: -0.00166
# ExplainedVarOld: -9.46e-12
# ValFuncLoss: 168
#
#
# ***** Episode 420, Mean Return = -648.7, Mean Discounted Return = -38.3 *****
# ExplainedVarNew: -0.00144
# ExplainedVarOld: -0.00114
# ValFuncLoss: 174
#
#
# ***** Episode 480, Mean Return = -555.2, Mean Discounted Return = -35.2 *****
# ExplainedVarNew: -0.00706
# ExplainedVarOld: -0.00499
# ValFuncLoss: 205
#
#
# ***** Episode 540, Mean Return = -510.5, Mean Discounted Return = -31.3 *****
# ExplainedVarNew: -0.00128
# ExplainedVarOld: -0.00167
# ValFuncLoss: 211
#
#
# ***** Episode 600, Mean Return = -490.4, Mean Discounted Return = -32.3 *****
# ExplainedVarNew: -0.00678
# ExplainedVarOld: -0.00658
# ValFuncLoss: 227
#
#
# ***** Episode 660, Mean Return = -359.2, Mean Discounted Return = -26.9 *****
# ExplainedVarNew: -0.00337
# ExplainedVarOld: -0.00295
# ValFuncLoss: 247
#
#
# ***** Episode 720, Mean Return = -391.3, Mean Discounted Return = -27.9 *****
# ExplainedVarNew: -0.00743
# ExplainedVarOld: -0.00708
# ValFuncLoss: 223
#
#
# ***** Episode 780, Mean Return = -435.1, Mean Discounted Return = -29.4 *****
# ExplainedVarNew: -0.00598
# ExplainedVarOld: -0.00579
# ValFuncLoss: 202
#
#
# ***** Episode 840, Mean Return = -346.9, Mean Discounted Return = -28.1 *****
# ExplainedVarNew: -0.00557
# ExplainedVarOld: -0.00406
# ValFuncLoss: 227
#
#
# ***** Episode 900, Mean Return = -343.4, Mean Discounted Return = -25.7 *****
# ExplainedVarNew: -0.00739
# ExplainedVarOld: -0.00694
# ValFuncLoss: 198
#
#
# ***** Episode 960, Mean Return = -328.3, Mean Discounted Return = -22.6 *****
# ExplainedVarNew: -0.0144
# ExplainedVarOld: -0.0128
# ValFuncLoss: 233
#
#
# ***** Episode 1020, Mean Return = -312.2, Mean Discounted Return = -23.4 *****
# ExplainedVarNew: -0.0115
# ExplainedVarOld: -0.0103
# ValFuncLoss: 224
#
#
# ***** Episode 1080, Mean Return = -256.8, Mean Discounted Return = -18.8 *****
# ExplainedVarNew: -0.00854
# ExplainedVarOld: -0.00793
# ValFuncLoss: 193
#
#
# ***** Episode 1140, Mean Return = -327.8, Mean Discounted Return = -25.5 *****
# ExplainedVarNew: -0.0137
# ExplainedVarOld: -0.0111
# ValFuncLoss: 245
#
#
# ***** Episode 1200, Mean Return = -315.5, Mean Discounted Return = -25.2 *****
# ExplainedVarNew: -0.0377
# ExplainedVarOld: -0.0135
# ValFuncLoss: 191
#
#
# ***** Episode 1260, Mean Return = -217.1, Mean Discounted Return = -18.7 *****
# ExplainedVarNew: -0.0683
# ExplainedVarOld: -0.05
# ValFuncLoss: 218
#
#
# ***** Episode 1320, Mean Return = -290.3, Mean Discounted Return = -24.5 *****
# ExplainedVarNew: -0.0617
# ExplainedVarOld: -0.0676
# ValFuncLoss: 166
#
#
# ***** Episode 1380, Mean Return = -239.9, Mean Discounted Return = -19.0 *****
# ExplainedVarNew: -0.0661
# ExplainedVarOld: -0.0689
# ValFuncLoss: 188
#
#
# ***** Episode 1440, Mean Return = -249.4, Mean Discounted Return = -22.0 *****
# ExplainedVarNew: -0.0582
# ExplainedVarOld: -0.0709
# ValFuncLoss: 169
#
#
# ***** Episode 1500, Mean Return = -238.7, Mean Discounted Return = -19.1 *****
# ExplainedVarNew: -0.0683
# ExplainedVarOld: -0.051
# ValFuncLoss: 180
#
#
# ***** Episode 1560, Mean Return = -253.4, Mean Discounted Return = -21.2 *****
# ExplainedVarNew: -0.148
# ExplainedVarOld: -0.0878
# ValFuncLoss: 178
#
#
# ***** Episode 1620, Mean Return = -295.3, Mean Discounted Return = -21.6 *****
# ExplainedVarNew: -0.0321
# ExplainedVarOld: -0.113
# ValFuncLoss: 196
#
#
# ***** Episode 1680, Mean Return = -273.6, Mean Discounted Return = -19.6 *****
# ExplainedVarNew: -0.0149
# ExplainedVarOld: -0.0301
# ValFuncLoss: 195
#
#
# ***** Episode 1740, Mean Return = -243.6, Mean Discounted Return = -19.0 *****
# ExplainedVarNew: -0.0325
# ExplainedVarOld: -0.0146
# ValFuncLoss: 182
#
#
# ***** Episode 1800, Mean Return = -232.2, Mean Discounted Return = -18.4 *****
# ExplainedVarNew: -0.0694
# ExplainedVarOld: -0.0392
# ValFuncLoss: 189
#
#
# ***** Episode 1860, Mean Return = -200.4, Mean Discounted Return = -15.9 *****
# ExplainedVarNew: -0.0585
# ExplainedVarOld: -0.0577
# ValFuncLoss: 187
#
#
# ***** Episode 1920, Mean Return = -189.2, Mean Discounted Return = -14.9 *****
# ExplainedVarNew: -0.0666
# ExplainedVarOld: -0.0867
# ValFuncLoss: 154
#
#
# ***** Episode 1980, Mean Return = -251.2, Mean Discounted Return = -17.6 *****
# ExplainedVarNew: -0.0749
# ExplainedVarOld: -0.0669
# ValFuncLoss: 158
#
#
# ***** Episode 2040, Mean Return = -206.4, Mean Discounted Return = -16.7 *****
# ExplainedVarNew: -0.102
# ExplainedVarOld: -0.0671
# ValFuncLoss: 148
#
#
# ***** Episode 2100, Mean Return = -199.2, Mean Discounted Return = -19.3 *****
# ExplainedVarNew: -0.049
# ExplainedVarOld: -0.0835
# ValFuncLoss: 142
#
#
# ***** Episode 2160, Mean Return = -238.9, Mean Discounted Return = -17.8 *****
# ExplainedVarNew: -0.0514
# ExplainedVarOld: -0.0675
# ValFuncLoss: 132
#
#
# ***** Episode 2220, Mean Return = -138.3, Mean Discounted Return = -16.5 *****
# ExplainedVarNew: -0.03
# ExplainedVarOld: -0.0545
# ValFuncLoss: 139
#
#
# ***** Episode 2280, Mean Return = -151.5, Mean Discounted Return = -14.6 *****
# ExplainedVarNew: -0.0454
# ExplainedVarOld: -0.0423
# ValFuncLoss: 115
#
#
# ***** Episode 2340, Mean Return = -183.6, Mean Discounted Return = -16.2 *****
# ExplainedVarNew: -0.0619
# ExplainedVarOld: -0.04
# ValFuncLoss: 113
#
#
# ***** Episode 2400, Mean Return = -132.8, Mean Discounted Return = -12.9 *****
# ExplainedVarNew: -0.0403
# ExplainedVarOld: -0.0575
# ValFuncLoss: 123
#
#
# ***** Episode 2460, Mean Return = -191.3, Mean Discounted Return = -14.1 *****
# ExplainedVarNew: -0.0163
# ExplainedVarOld: -0.0339
# ValFuncLoss: 123
#
#
# ***** Episode 2520, Mean Return = -144.4, Mean Discounted Return = -14.2 *****
# ExplainedVarNew: -0.0123
# ExplainedVarOld: -0.011
# ValFuncLoss: 125
#
#
# ***** Episode 2580, Mean Return = -160.4, Mean Discounted Return = -14.0 *****
# ExplainedVarNew: -0.0287
# ExplainedVarOld: -0.0166
# ValFuncLoss: 76.6
#
#
# ***** Episode 2640, Mean Return = -168.2, Mean Discounted Return = -15.9 *****
# ExplainedVarNew: -0.0271
# ExplainedVarOld: -0.0316
# ValFuncLoss: 124
#
#
# ***** Episode 2700, Mean Return = -158.4, Mean Discounted Return = -13.8 *****
# ExplainedVarNew: -0.0431
# ExplainedVarOld: -0.0351
# ValFuncLoss: 93.9
#
#
# ***** Episode 2760, Mean Return = -148.6, Mean Discounted Return = -14.7 *****
# ExplainedVarNew: -0.0746
# ExplainedVarOld: -0.041
# ValFuncLoss: 110
#
#
# ***** Episode 2820, Mean Return = -117.4, Mean Discounted Return = -13.1 *****
# ExplainedVarNew: -0.0674
# ExplainedVarOld: -0.0788
# ValFuncLoss: 111
#
#
# ***** Episode 2880, Mean Return = -173.8, Mean Discounted Return = -12.7 *****
# ExplainedVarNew: -0.0527
# ExplainedVarOld: -0.115
# ValFuncLoss: 70.8
#
#
# ***** Episode 2940, Mean Return = -128.7, Mean Discounted Return = -12.3 *****
# ExplainedVarNew: -0.0633
# ExplainedVarOld: -0.0604
# ValFuncLoss: 63.3
#
#
# ***** Episode 3000, Mean Return = -139.5, Mean Discounted Return = -13.1 *****
# ExplainedVarNew: -0.034
# ExplainedVarOld: -0.0393
# ValFuncLoss: 70.6
#
#
# ***** Episode 3060, Mean Return = -156.7, Mean Discounted Return = -12.9 *****
# ExplainedVarNew: -0.0425
# ExplainedVarOld: -0.0373
# ValFuncLoss: 85.8
#
#
# ***** Episode 3120, Mean Return = -134.0, Mean Discounted Return = -12.1 *****
# ExplainedVarNew: -0.0662
# ExplainedVarOld: -0.0628
# ValFuncLoss: 66
#
#
# ***** Episode 3180, Mean Return = -141.4, Mean Discounted Return = -14.2 *****
# ExplainedVarNew: -0.0506
# ExplainedVarOld: -0.0473
# ValFuncLoss: 74
#
#
# ***** Episode 3240, Mean Return = -109.2, Mean Discounted Return = -11.5 *****
# ExplainedVarNew: -0.0783
# ExplainedVarOld: -0.0784
# ValFuncLoss: 103
#
#
# ***** Episode 3300, Mean Return = -121.6, Mean Discounted Return = -10.8 *****
# ExplainedVarNew: -0.0773
# ExplainedVarOld: -0.0614
# ValFuncLoss: 88
# ***** Episode 3360, Mean Return = -92.0, Mean Discounted Return = -9.3 *****
# ExplainedVarNew: -0.135
# ExplainedVarOld: -0.097
# ValFuncLoss: 75.2
#
#
# ***** Episode 3420, Mean Return = -154.6, Mean Discounted Return = -13.9 *****
# ExplainedVarNew: -0.0674
# ExplainedVarOld: -0.302
# ValFuncLoss: 72.9
#
#
# ***** Episode 3480, Mean Return = -111.7, Mean Discounted Return = -10.2 *****
# ExplainedVarNew: -0.109
# ExplainedVarOld: -0.128
# ValFuncLoss: 57.7
#
#
# ***** Episode 3540, Mean Return = -137.2, Mean Discounted Return = -11.6 *****
# ExplainedVarNew: -0.14
# ExplainedVarOld: -0.147
# ValFuncLoss: 58.4
#
#
# ***** Episode 3600, Mean Return = -134.1, Mean Discounted Return = -10.7 *****
# ExplainedVarNew: -0.158
# ExplainedVarOld: -0.152
# ValFuncLoss: 47.4
#
#
# ***** Episode 3660, Mean Return = -101.0, Mean Discounted Return = -10.3 *****
# ExplainedVarNew: -0.106
# ExplainedVarOld: -0.129
# ValFuncLoss: 61.8
#
#
# ***** Episode 3720, Mean Return = -88.0, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -0.0967
# ExplainedVarOld: -0.093
# ValFuncLoss: 46.9
#
#
# ***** Episode 3780, Mean Return = -121.7, Mean Discounted Return = -9.7 *****
# ExplainedVarNew: -0.134
# ExplainedVarOld: -0.133
# ValFuncLoss: 38.4
#
#
# ***** Episode 3840, Mean Return = -89.8, Mean Discounted Return = -9.5 *****
# ExplainedVarNew: -0.0851
# ExplainedVarOld: -0.108
# ValFuncLoss: 44.7
#
#
# ***** Episode 3900, Mean Return = -116.2, Mean Discounted Return = -10.5 *****
# ExplainedVarNew: -0.0627
# ExplainedVarOld: -0.109
# ValFuncLoss: 33.7
#
#
# ***** Episode 3960, Mean Return = -125.8, Mean Discounted Return = -9.7 *****
# ExplainedVarNew: -0.0422
# ExplainedVarOld: -0.725
# ValFuncLoss: 26
#
#
# ***** Episode 4020, Mean Return = -87.8, Mean Discounted Return = -9.0 *****
# ExplainedVarNew: -0.0853
# ExplainedVarOld: -0.0662
# ValFuncLoss: 39
#
#
# ***** Episode 4080, Mean Return = -89.1, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0568
# ExplainedVarOld: -0.0597
# ValFuncLoss: 32.8
#
#
# ***** Episode 4140, Mean Return = -91.8, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.082
# ExplainedVarOld: -0.0855
# ValFuncLoss: 31.9
#
#
# ***** Episode 4200, Mean Return = -94.1, Mean Discounted Return = -8.2 *****
# ExplainedVarNew: -0.0472
# ExplainedVarOld: -0.101
# ValFuncLoss: 30.6
#
#
# ***** Episode 4260, Mean Return = -110.7, Mean Discounted Return = -8.5 *****
# ExplainedVarNew: -0.0635
# ExplainedVarOld: -0.0692
# ValFuncLoss: 23.8
#
#
# ***** Episode 4320, Mean Return = -111.9, Mean Discounted Return = -8.6 *****
# ExplainedVarNew: -0.0718
# ExplainedVarOld: -0.0743
# ValFuncLoss: 24.9
#
#
# ***** Episode 4380, Mean Return = -96.3, Mean Discounted Return = -7.8 *****
# ExplainedVarNew: -0.0749
# ExplainedVarOld: -0.0756
# ValFuncLoss: 28
#
#
# ***** Episode 4440, Mean Return = -97.8, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0535
# ExplainedVarOld: -0.0696
# ValFuncLoss: 31.5
#
#
# ***** Episode 4500, Mean Return = -88.9, Mean Discounted Return = -7.7 *****
# ExplainedVarNew: -0.0732
# ExplainedVarOld: -0.0688
# ValFuncLoss: 32.2
#
#
# ***** Episode 4560, Mean Return = -118.6, Mean Discounted Return = -9.2 *****
# ExplainedVarNew: -0.0296
# ExplainedVarOld: -0.0315
# ValFuncLoss: 38
#
#
# ***** Episode 4620, Mean Return = -118.8, Mean Discounted Return = -8.8 *****
# ExplainedVarNew: -0.0447
# ExplainedVarOld: -0.0552
# ValFuncLoss: 18.5
#
#
# ***** Episode 4680, Mean Return = -97.4, Mean Discounted Return = -7.2 *****
# ExplainedVarNew: -0.0679
# ExplainedVarOld: -0.0564
# ValFuncLoss: 23
#
#
# ***** Episode 4740, Mean Return = -107.6, Mean Discounted Return = -8.1 *****
# ExplainedVarNew: -0.0677
# ExplainedVarOld: -0.0602
# ValFuncLoss: 24.4
