# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines.bench import Monitor
from stable_baselines.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines.common.policies import MlpPolicy, FeedForwardPolicy
from stable_baselines import results_plotter
from stable_baselines import *

# %%
import gym
import numpy as np

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Customize value network 
class CustomPolicy(FeedForwardPolicy):
    def __init__(self, *args, **kwargs):
        super(CustomPolicy, self).__init__(*args, **kwargs,
                                           net_arch=[dict(vf=[10, 7, 5])],
                                           feature_extraction="mlp")
        
# Create and wrap the environment
env = gym.make('Taxi-v3')
env = Monitor(env, log_dir, allow_early_resets=True)
env = DummyVecEnv(([lambda: env]))

model = TRPO(CustomPolicy, env, verbose=1)

# Train the agent
time_steps = 1000
model.learn(total_timesteps=time_steps)
# Out:
# ********** Iteration 0 ************
# Optimizing Policy...
# sampling
# done in 0.320 seconds
# computegrad
# done in 0.118 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00276          0
#          1   0.000783      0.383
#          2    1.2e-05       2.13
#          3   4.39e-07       2.18
#          4   1.01e-06       2.18
#          5   8.51e-09       2.18
#          6   1.47e-10       2.18
#          7   6.46e-11       2.18
# done in 0.110 seconds
# Expected: 0.037 Actual: 0.037
# Stepsize OK!
# vf
# done in 0.090 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -783         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 5            |
# | TimeElapsed             | 0.725        |
# | TimestepsSoFar          | 1024         |
# | entloss                 | 0.0          |
# | entropy                 | 1.788643     |
# | explained_variance_t... | -0.000739    |
# | meankl                  | 0.0031295307 |
# | optimgain               | 0.037293963  |
# | surrgain                | 0.037293963  |
# ------------------------------------------
# ********** Iteration 1 ************
# Optimizing Policy...
# sampling
# done in 0.286 seconds
# computegrad
# done in 0.022 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00294          0
#          1   0.000836      0.394
#          2    0.00048       1.98
#          3   2.76e-05        2.1
#          4   2.11e-05       2.18
#          5    1.6e-06       2.19
#          6   8.65e-07        2.2
#          7   5.26e-08        2.2
#          8   7.12e-08        2.2
#          9   1.72e-09        2.2
#         10   1.45e-10        2.2
# done in 0.045 seconds
# Expected: 0.038 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.053 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -747         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 10           |
# | TimeElapsed             | 1.16         |
# | TimestepsSoFar          | 2048         |
# | entloss                 | 0.0          |
# | entropy                 | 1.7840159    |
# | explained_variance_t... | -0.000999    |
# | meankl                  | 0.0032133395 |
# | optimgain               | 0.037715726  |
# | surrgain                | 0.037715726  |
# ------------------------------------------
# ********** Iteration 2 ************
# Optimizing Policy...
# sampling
# done in 0.288 seconds
# computegrad
# done in 0.021 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00414          0
#          1   0.000813       0.45
#          2    0.00196       1.71
#          3   1.55e-05       2.27
#          4   2.26e-05       2.28
#          5   3.88e-06       2.31
#          6   2.89e-07       2.32
#          7   5.11e-07       2.32
#          8   7.33e-09       2.32
#          9   2.77e-10       2.32
#         10   6.33e-12       2.32
# done in 0.044 seconds
# Expected: 0.041 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -739         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 15           |
# | TimeElapsed             | 1.59         |
# | TimestepsSoFar          | 3072         |
# | entloss                 | 0.0          |
# | entropy                 | 1.7763246    |
# | explained_variance_t... | -0.00121     |
# | meankl                  | 0.0035651242 |
# | optimgain               | 0.04070028   |
# | surrgain                | 0.04070028   |
# ------------------------------------------
# ********** Iteration 3 ************
# Optimizing Policy...
# sampling
# done in 0.286 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00432          0
#          1   0.000815      0.498
#          2    0.00109       2.09
#          3    1.6e-05       2.33
#          4   1.94e-05       2.34
#          5   8.19e-06       2.37
#          6   3.02e-07       2.37
#          7   7.01e-07       2.37
#          8   9.11e-09       2.37
#          9   2.42e-10       2.37
#         10   3.73e-12       2.37
# done in 0.038 seconds
# Expected: 0.042 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.050 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -723        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 20          |
# | TimeElapsed             | 2.01        |
# | TimestepsSoFar          | 4096        |
# | entloss                 | 0.0         |
# | entropy                 | 1.7648351   |
# | explained_variance_t... | 0.000496    |
# | meankl                  | 0.003931595 |
# | optimgain               | 0.041455705 |
# | surrgain                | 0.041455705 |
# -----------------------------------------
# ********** Iteration 4 ************
# Optimizing Policy...
# sampling
# done in 0.280 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00345          0
#          1   0.000907      0.435
#          2    0.00188       1.02
#          3   4.23e-05       2.14
#          4   2.21e-05       2.15
#          5   2.34e-05       2.19
#          6   5.02e-07       2.21
#          7   1.68e-08       2.21
#          8   6.52e-09       2.21
#          9   4.15e-10       2.21
#         10   1.34e-11       2.21
# done in 0.044 seconds
# Expected: 0.039 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.051 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -707         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 25           |
# | TimeElapsed             | 2.44         |
# | TimestepsSoFar          | 5120         |
# | entloss                 | 0.0          |
# | entropy                 | 1.7497683    |
# | explained_variance_t... | -0.00171     |
# | meankl                  | 0.0034976923 |
# | optimgain               | 0.038134746  |
# | surrgain                | 0.038134746  |
# ------------------------------------------
# ********** Iteration 5 ************
# Optimizing Policy...
# sampling
# done in 0.285 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00393          0
#          1   0.000971      0.531
#          2    0.00196          1
#          3   0.000368       2.26
#          4   3.09e-05       2.36
#          5   7.93e-06       2.38
#          6   9.14e-07        2.4
#          7   3.83e-07        2.4
#          8    1.3e-08       2.41
#          9   7.85e-10       2.41
#         10   4.03e-11       2.41
# done in 0.041 seconds
# Expected: 0.042 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.048 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -691         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 30           |
# | TimeElapsed             | 2.86         |
# | TimestepsSoFar          | 6144         |
# | entloss                 | 0.0          |
# | entropy                 | 1.733512     |
# | explained_variance_t... | 0.00071      |
# | meankl                  | 0.0035183914 |
# | optimgain               | 0.04122361   |
# | surrgain                | 0.04122361   |
# ------------------------------------------
# ********** Iteration 6 ************
# Optimizing Policy...
# sampling
# done in 0.277 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00324          0
#          1     0.0011      0.475
#          2    0.00184       1.03
#          3   0.000513       2.23
#          4    1.8e-05       2.34
#          5   1.25e-05       2.35
#          6   1.85e-05       2.37
#          7   1.55e-07       2.38
#          8    4.1e-09       2.38
#          9   7.77e-11       2.38
# done in 0.040 seconds
# Expected: 0.041 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -669         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 35           |
# | TimeElapsed             | 3.28         |
# | TimestepsSoFar          | 7168         |
# | entloss                 | 0.0          |
# | entropy                 | 1.7167331    |
# | explained_variance_t... | 0.000777     |
# | meankl                  | 0.0032361513 |
# | optimgain               | 0.040335245  |
# | surrgain                | 0.040335245  |
# ------------------------------------------
# ********** Iteration 7 ************
# Optimizing Policy...
# sampling
# done in 0.286 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00568          0
#          1      0.001      0.494
#          2   0.000896        0.8
#          3    0.00125       1.62
#          4   2.69e-05          2
#          5   1.62e-05       2.02
#          6   2.54e-05       2.04
#          7   1.74e-07       2.06
#          8   5.63e-09       2.06
#          9   1.69e-10       2.06
#         10    3.4e-10       2.06
# done in 0.040 seconds
# Expected: 0.040 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.050 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -643        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 40          |
# | TimeElapsed             | 3.7         |
# | TimestepsSoFar          | 8192        |
# | entloss                 | 0.0         |
# | entropy                 | 1.6925375   |
# | explained_variance_t... | -0.00338    |
# | meankl                  | 0.004892003 |
# | optimgain               | 0.03953871  |
# | surrgain                | 0.03953871  |
# -----------------------------------------
# ********** Iteration 8 ************
# Optimizing Policy...
# sampling
# done in 0.286 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00354          0
#          1    0.00152      0.597
#          2    0.00131      0.943
#          3   0.000689       2.31
#          4   5.61e-05       2.45
#          5   1.38e-05       2.48
#          6   1.41e-05       2.49
#          7   1.75e-07       2.52
#          8   2.85e-09       2.52
#          9   3.65e-10       2.52
#         10   5.32e-11       2.52
# done in 0.041 seconds
# Expected: 0.043 Actual: 0.043
# Stepsize OK!
# vf
# done in 0.050 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -596         |
# | EpThisIter              | 6            |
# | EpisodesSoFar           | 46           |
# | TimeElapsed             | 4.13         |
# | TimestepsSoFar          | 9216         |
# | entloss                 | 0.0          |
# | entropy                 | 1.6696098    |
# | explained_variance_t... | 0.00242      |
# | meankl                  | 0.0033443382 |
# | optimgain               | 0.04253665   |
# | surrgain                | 0.04253665   |
# ------------------------------------------
# ********** Iteration 9 ************
# Optimizing Policy...
# sampling
# done in 0.281 seconds
# computegrad
# done in 0.021 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00354          0
#          1    0.00142       0.63
#          2   0.000973      0.947
#          3   0.000749       1.88
#          4   4.22e-05       2.06
#          5    2.4e-05        2.1
#          6   2.94e-05       2.12
#          7   5.57e-07       2.15
#          8   2.55e-08       2.15
#          9   9.42e-10       2.15
#         10   1.28e-09       2.15
# done in 0.044 seconds
# Expected: 0.041 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.048 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -557         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 51           |
# | TimeElapsed             | 4.55         |
# | TimestepsSoFar          | 10240        |
# | entloss                 | 0.0          |
# | entropy                 | 1.6450396    |
# | explained_variance_t... | 0.00179      |
# | meankl                  | 0.0046851775 |
# | optimgain               | 0.040164493  |
# | surrgain                | 0.040164493  |
# ------------------------------------------
# ********** Iteration 10 ************
# Optimizing Policy...
# sampling
# done in 0.279 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00199          0
#          1    0.00129      0.768
#          2     0.0013       1.15
#          3   0.000609       2.05
#          4   0.000117       2.21
#          5   3.33e-05        2.3
#          6   3.65e-05       2.32
#          7    6.9e-07       2.36
#          8    3.3e-08       2.37
#          9   1.64e-09       2.37
#         10   2.69e-09       2.37
# done in 0.045 seconds
# Expected: 0.040 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.048 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -514         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 56           |
# | TimeElapsed             | 4.98         |
# | TimestepsSoFar          | 11264        |
# | entloss                 | 0.0          |
# | entropy                 | 1.6218486    |
# | explained_variance_t... | -0.000336    |
# | meankl                  | 0.0029866123 |
# | optimgain               | 0.04017649   |
# | surrgain                | 0.04017649   |
# ------------------------------------------
# ********** Iteration 11 ************
# Optimizing Policy...
# sampling
# done in 0.281 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00241          0
#          1    0.00179      0.708
#          2   0.000916       1.09
#          3   0.000722       2.03
#          4   3.19e-05       2.19
#          5   6.34e-05       2.21
#          6   8.28e-06       2.25
#          7   6.16e-07       2.27
#          8   3.27e-08       2.27
#          9   1.67e-09       2.27
#         10    2.2e-09       2.27
# done in 0.042 seconds
# Expected: 0.040 Actual: 0.039
# Stepsize OK!
# vf
# done in 0.052 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -477        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 61          |
# | TimeElapsed             | 5.4         |
# | TimestepsSoFar          | 12288       |
# | entloss                 | 0.0         |
# | entropy                 | 1.5918951   |
# | explained_variance_t... | 0.000189    |
# | meankl                  | 0.003771655 |
# | optimgain               | 0.039276738 |
# | surrgain                | 0.039276738 |
# -----------------------------------------
# ********** Iteration 12 ************
# Optimizing Policy...
# sampling
# done in 0.279 seconds
# computegrad
# done in 0.021 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0026          0
#          1    0.00214       0.46
#          2   0.000751       1.19
#          3    0.00129       1.96
#          4   3.63e-05       2.29
#          5   2.28e-05        2.3
#          6   8.42e-07       2.35
#          7   2.43e-07       2.36
#          8   1.15e-08       2.36
#          9   1.94e-09       2.36
#         10   7.78e-10       2.36
# done in 0.045 seconds
# Expected: 0.041 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.050 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -439         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 66           |
# | TimeElapsed             | 5.83         |
# | TimestepsSoFar          | 13312        |
# | entloss                 | 0.0          |
# | entropy                 | 1.5679319    |
# | explained_variance_t... | -0.00104     |
# | meankl                  | 0.0033451929 |
# | optimgain               | 0.040293768  |
# | surrgain                | 0.040293768  |
# ------------------------------------------
# ********** Iteration 13 ************
# Optimizing Policy...
# sampling
# done in 0.283 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00376          0
#          1    0.00235       0.47
#          2   0.000771       1.28
#          3    0.00119       1.57
#          4   7.13e-05       2.37
#          5   1.35e-05       2.39
#          6   3.35e-06       2.41
#          7   1.27e-07       2.42
#          8   4.66e-09       2.42
#          9   2.53e-09       2.42
#         10   1.45e-10       2.42
# done in 0.041 seconds
# Expected: 0.044 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -402         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 71           |
# | TimeElapsed             | 6.25         |
# | TimestepsSoFar          | 14336        |
# | entloss                 | 0.0          |
# | entropy                 | 1.5397109    |
# | explained_variance_t... | -0.00157     |
# | meankl                  | 0.0038354227 |
# | optimgain               | 0.041110147  |
# | surrgain                | 0.041110147  |
# ------------------------------------------
# ********** Iteration 14 ************
# Optimizing Policy...
# sampling
# done in 0.286 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00283          0
#          1    0.00159      0.338
#          2   0.000479       1.25
#          3   0.000686       1.46
#          4   1.24e-05       1.99
#          5   2.66e-05       2.01
#          6   2.01e-06       2.03
#          7   8.03e-08       2.04
#          8   2.34e-09       2.04
#          9   9.24e-10       2.04
#         10    7.1e-11       2.04
# done in 0.042 seconds
# Expected: 0.037 Actual: 0.036
# Stepsize OK!
# vf
# done in 0.048 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -373         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 76           |
# | TimeElapsed             | 6.67         |
# | TimestepsSoFar          | 15360        |
# | entloss                 | 0.0          |
# | entropy                 | 1.5128312    |
# | explained_variance_t... | 0.00109      |
# | meankl                  | 0.0039293566 |
# | optimgain               | 0.035718065  |
# | surrgain                | 0.035718065  |
# ------------------------------------------
# ********** Iteration 15 ************
# Optimizing Policy...
# sampling
# done in 0.282 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00188          0
#          1    0.00269      0.576
#          2   0.000324       1.44
#          3   0.000656       1.59
#          4   4.41e-05       1.99
#          5   1.26e-05          2
#          6   1.73e-06       2.03
#          7   1.66e-07       2.04
#          8   1.61e-08       2.04
#          9   1.53e-09       2.04
#         10    2.4e-09       2.04
# done in 0.045 seconds
# Expected: 0.038 Actual: 0.035
# Stepsize OK!
# vf
# done in 0.050 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -352         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 81           |
# | TimeElapsed             | 7.1          |
# | TimestepsSoFar          | 16384        |
# | entloss                 | 0.0          |
# | entropy                 | 1.4832933    |
# | explained_variance_t... | -0.000824    |
# | meankl                  | 0.0039560366 |
# | optimgain               | 0.035244834  |
# | surrgain                | 0.035244834  |
# ------------------------------------------
# ********** Iteration 16 ************
# Optimizing Policy...
# sampling
# done in 0.284 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00118          0
#          1    0.00259      0.511
#          2   0.000429       1.75
#          3   0.000251       1.86
#          4   1.17e-05       2.19
#          5   1.36e-05        2.2
#          6   3.77e-07       2.22
#          7   1.66e-08       2.22
#          8   1.89e-09       2.22
#          9    1.4e-09       2.22
#         10   6.12e-11       2.22
# done in 0.043 seconds
# Expected: 0.036 Actual: 0.035
# Stepsize OK!
# vf
# done in 0.051 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -321         |
# | EpThisIter              | 6            |
# | EpisodesSoFar           | 87           |
# | TimeElapsed             | 7.53         |
# | TimestepsSoFar          | 17408        |
# | entloss                 | 0.0          |
# | entropy                 | 1.4660623    |
# | explained_variance_t... | 0.0017       |
# | meankl                  | 0.0024061971 |
# | optimgain               | 0.035415843  |
# | surrgain                | 0.035415843  |
# ------------------------------------------
# ********** Iteration 17 ************
# Optimizing Policy...
# sampling
# done in 0.282 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00258          0
#          1    0.00127       0.32
#          2    0.00114       1.88
#          3   0.000109       2.05
#          4    0.00023       2.19
#          5   4.18e-06       2.27
#          6   2.26e-07       2.29
#          7   1.11e-08       2.29
#          8   9.39e-10       2.29
#          9   5.46e-10       2.29
#         10   3.47e-10       2.29
# done in 0.044 seconds
# Expected: 0.039 Actual: 0.039
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -299         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 92           |
# | TimeElapsed             | 7.95         |
# | TimestepsSoFar          | 18432        |
# | entloss                 | 0.0          |
# | entropy                 | 1.451798     |
# | explained_variance_t... | 0.000196     |
# | meankl                  | 0.0034040627 |
# | optimgain               | 0.038912416  |
# | surrgain                | 0.038912416  |
# ------------------------------------------
# ********** Iteration 18 ************
# Optimizing Policy...
# sampling
# done in 0.272 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00185          0
#          1    0.00321      0.469
#          2   0.000128       2.08
#          3    0.00039       2.23
#          4   4.78e-06       2.38
#          5   9.64e-06        2.4
#          6   1.71e-07        2.4
#          7   5.23e-09        2.4
#          8   4.27e-09        2.4
#          9   1.47e-10        2.4
#         10   5.63e-12        2.4
# done in 0.046 seconds
# Expected: 0.041 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.051 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -281         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 97           |
# | TimeElapsed             | 8.37         |
# | TimestepsSoFar          | 19456        |
# | entloss                 | 0.0          |
# | entropy                 | 1.4328268    |
# | explained_variance_t... | 3.52e-05     |
# | meankl                  | 0.0031021032 |
# | optimgain               | 0.03826352   |
# | surrgain                | 0.03826352   |
# ------------------------------------------
# ********** Iteration 19 ************
# Optimizing Policy...
# sampling
# done in 0.278 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00143          0
#          1    0.00133        0.3
#          2    0.00164       1.86
#          3   3.31e-05       2.15
#          4   9.64e-05        2.2
#          5   1.23e-06       2.24
#          6   9.54e-08       2.25
#          7   7.58e-09       2.25
#          8   3.02e-09       2.25
#          9   2.87e-10       2.25
#         10   1.97e-10       2.25
# done in 0.039 seconds
# Expected: 0.036 Actual: 0.036
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -264         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 102          |
# | TimeElapsed             | 8.78         |
# | TimestepsSoFar          | 20480        |
# | entloss                 | 0.0          |
# | entropy                 | 1.4278858    |
# | explained_variance_t... | -0.000165    |
# | meankl                  | 0.0024794373 |
# | optimgain               | 0.03582892   |
# | surrgain                | 0.03582892   |
# ------------------------------------------
# ********** Iteration 20 ************
# Optimizing Policy...
# sampling
# done in 0.290 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00153          0
#          1    0.00148      0.297
#          2    0.00039       1.68
#          3   0.000112       1.76
#          4   1.52e-05       1.98
#          5   9.24e-06       1.99
#          6   2.81e-07       2.02
#          7   1.17e-08       2.02
#          8   1.38e-09       2.02
#          9   1.18e-09       2.02
#         10   3.26e-11       2.02
# done in 0.045 seconds
# Expected: 0.034 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -254         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 107          |
# | TimeElapsed             | 9.22         |
# | TimestepsSoFar          | 21504        |
# | entloss                 | 0.0          |
# | entropy                 | 1.4131956    |
# | explained_variance_t... | 0.0011       |
# | meankl                  | 0.0032928681 |
# | optimgain               | 0.033924088  |
# | surrgain                | 0.033924088  |
# ------------------------------------------
# ********** Iteration 21 ************
# Optimizing Policy...
# sampling
# done in 0.287 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000886          0
#          1    0.00208      0.431
#          2   0.000423       1.61
#          3   6.13e-05       1.69
#          4    2.1e-05       1.87
#          5   2.53e-06       1.88
#          6    1.6e-07       1.89
#          7   1.65e-08       1.89
#          8   1.32e-08       1.89
#          9   9.07e-10       1.89
#         10   5.77e-11       1.89
# done in 0.043 seconds
# Expected: 0.031 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.048 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -243         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 112          |
# | TimeElapsed             | 9.65         |
# | TimestepsSoFar          | 22528        |
# | entloss                 | 0.0          |
# | entropy                 | 1.407279     |
# | explained_variance_t... | -0.000383    |
# | meankl                  | 0.0026875432 |
# | optimgain               | 0.030482758  |
# | surrgain                | 0.030482758  |
# ------------------------------------------
# ********** Iteration 22 ************
# Optimizing Policy...
# sampling
# done in 0.286 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000899          0
#          1    0.00389      0.766
#          2   9.03e-05       2.18
#          3   5.32e-05       2.21
#          4   1.38e-05       2.27
#          5   4.35e-06       2.28
#          6   2.22e-07       2.29
#          7   2.17e-08       2.29
#          8   1.63e-09       2.29
#          9    3.4e-09       2.29
#         10   5.98e-11       2.29
# done in 0.042 seconds
# Expected: 0.036 Actual: 0.037
# Stepsize OK!
# vf
# done in 0.048 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -232         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 117          |
# | TimeElapsed             | 10.1         |
# | TimestepsSoFar          | 23552        |
# | entloss                 | 0.0          |
# | entropy                 | 1.4023798    |
# | explained_variance_t... | 0.000556     |
# | meankl                  | 0.0019637395 |
# | optimgain               | 0.0366344    |
# | surrgain                | 0.0366344    |
# ------------------------------------------
# ********** Iteration 23 ************
# Optimizing Policy...
# sampling
# done in 0.288 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00288          0
#          1    0.00105      0.295
#          2    0.00308       1.52
#          3   4.28e-05       2.15
#          4    5.4e-05       2.17
#          5    1.2e-06       2.24
#          6   2.64e-08       2.25
#          7   1.22e-09       2.25
#          8   1.62e-09       2.25
#          9   5.45e-11       2.25
# done in 0.040 seconds
# Expected: 0.038 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.048 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -224         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 122          |
# | TimeElapsed             | 10.5         |
# | TimestepsSoFar          | 24576        |
# | entloss                 | 0.0          |
# | entropy                 | 1.4019101    |
# | explained_variance_t... | 0.00226      |
# | meankl                  | 0.0030819261 |
# | optimgain               | 0.038041852  |
# | surrgain                | 0.038041852  |
# ------------------------------------------
# ********** Iteration 24 ************
# Optimizing Policy...
# sampling
# done in 0.293 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00111          0
#          1    0.00239      0.458
#          2    0.00052       2.24
#          3    1.4e-05       2.32
#          4   5.08e-06       2.37
#          5   7.93e-07       2.37
#          6   3.87e-08       2.37
#          7   1.43e-09       2.37
#          8   1.83e-10       2.37
#          9   4.81e-11       2.37
# done in 0.041 seconds
# Expected: 0.037 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.047 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -220        |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 128         |
# | TimeElapsed             | 10.9        |
# | TimestepsSoFar          | 25600       |
# | entloss                 | 0.0         |
# | entropy                 | 1.4001728   |
# | explained_variance_t... | -0.000937   |
# | meankl                  | 0.002162051 |
# | optimgain               | 0.038343504 |
# | surrgain                | 0.038343504 |
# -----------------------------------------
# ********** Iteration 25 ************
# Optimizing Policy...
# sampling
# done in 0.285 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0016          0
#          1    0.00154      0.316
#          2     0.0013       2.04
#          3   3.06e-05       2.24
#          4   2.89e-05       2.33
#          5   2.72e-06       2.34
#          6   1.37e-07       2.35
#          7   1.03e-08       2.35
#          8   3.45e-09       2.35
#          9   7.79e-10       2.35
#         10    1.3e-10       2.35
# done in 0.046 seconds
# Expected: 0.038 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.048 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -215        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 133         |
# | TimeElapsed             | 11.4        |
# | TimestepsSoFar          | 26624       |
# | entloss                 | 0.0         |
# | entropy                 | 1.3943807   |
# | explained_variance_t... | -0.000699   |
# | meankl                  | 0.002389499 |
# | optimgain               | 0.0375117   |
# | surrgain                | 0.0375117   |
# -----------------------------------------
# ********** Iteration 26 ************
# Optimizing Policy...
# sampling
# done in 0.292 seconds
# computegrad
# done in 0.022 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00142          0
#          1   0.000858      0.241
#          2   0.000367        1.5
#          3    2.2e-05       1.57
#          4   7.12e-05        1.6
#          5   9.15e-07       1.64
#          6   6.65e-08       1.65
#          7   6.56e-09       1.65
#          8   6.51e-10       1.65
#          9   1.73e-09       1.65
#         10      4e-11       1.65
# done in 0.048 seconds
# Expected: 0.029 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.043 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -213         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 138          |
# | TimeElapsed             | 11.8         |
# | TimestepsSoFar          | 27648        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3858682    |
# | explained_variance_t... | 0.00124      |
# | meankl                  | 0.0040247682 |
# | optimgain               | 0.029642895  |
# | surrgain                | 0.029642895  |
# ------------------------------------------
# ********** Iteration 27 ************
# Optimizing Policy...
# sampling
# done in 0.287 seconds
# computegrad
# done in 0.021 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00154          0
#          1    0.00084      0.227
#          2   0.000166        1.8
#          3   2.48e-05       1.83
#          4   2.42e-05       1.91
#          5   1.23e-06       1.92
#          6   6.12e-08       1.93
#          7   3.82e-09       1.93
#          8   2.29e-10       1.93
#          9    3.5e-10       1.93
#         10   1.66e-11       1.93
# done in 0.045 seconds
# Expected: 0.032 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.047 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -211         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 143          |
# | TimeElapsed             | 12.2         |
# | TimestepsSoFar          | 28672        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3823687    |
# | explained_variance_t... | -0.00211     |
# | meankl                  | 0.0030059053 |
# | optimgain               | 0.032116994  |
# | surrgain                | 0.032116994  |
# ------------------------------------------
# ********** Iteration 28 ************
# Optimizing Policy...
# sampling
# done in 0.265 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000807          0
#          1    0.00252      0.717
#          2   0.000127        1.7
#          3   9.05e-05       1.74
#          4   3.43e-05       1.89
#          5    2.8e-06        1.9
#          6    1.8e-07       1.91
#          7   1.02e-08       1.91
#          8   7.87e-10       1.91
#          9   2.32e-09       1.91
#         10   8.62e-11       1.91
# done in 0.038 seconds
# Expected: 0.032 Actual: 0.031
# Stepsize OK!
# vf
# done in 0.042 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -210         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 148          |
# | TimeElapsed             | 12.6         |
# | TimestepsSoFar          | 29696        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3796422    |
# | explained_variance_t... | -0.000377    |
# | meankl                  | 0.0031319114 |
# | optimgain               | 0.031393506  |
# | surrgain                | 0.031393506  |
# ------------------------------------------
# ********** Iteration 29 ************
# Optimizing Policy...
# sampling
# done in 0.260 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00226          0
#          1   0.000627      0.216
#          2    0.00137       1.23
#          3   5.86e-05       1.55
#          4   8.65e-05       1.66
#          5   6.09e-06       1.69
#          6   4.28e-07       1.72
#          7    7.2e-08       1.72
#          8   4.41e-09       1.72
#          9    3.4e-09       1.72
#         10   4.48e-10       1.72
# done in 0.038 seconds
# Expected: 0.030 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.042 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -207        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 153         |
# | TimeElapsed             | 13          |
# | TimestepsSoFar          | 30720       |
# | entloss                 | 0.0         |
# | entropy                 | 1.388027    |
# | explained_variance_t... | -0.000264   |
# | meankl                  | 0.003689057 |
# | optimgain               | 0.030202106 |
# | surrgain                | 0.030202106 |
# -----------------------------------------
# ********** Iteration 30 ************
# Optimizing Policy...
# sampling
# done in 0.258 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00131          0
#          1    0.00108      0.281
#          2   0.000304       1.78
#          3   4.16e-05       1.84
#          4   1.25e-05       1.94
#          5   4.68e-06       1.94
#          6    2.3e-07       1.96
#          7   1.36e-08       1.96
#          8    1.1e-09       1.96
#          9   2.58e-09       1.96
#         10   5.89e-11       1.96
# done in 0.038 seconds
# Expected: 0.032 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.043 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -207         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 158          |
# | TimeElapsed             | 13.4         |
# | TimestepsSoFar          | 31744        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3743578    |
# | explained_variance_t... | 0.000468     |
# | meankl                  | 0.0031751906 |
# | optimgain               | 0.032415956  |
# | surrgain                | 0.032415956  |
# ------------------------------------------
# ********** Iteration 31 ************
# Optimizing Policy...
# sampling
# done in 0.256 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00119          0
#          1    0.00146      0.294
#          2   0.000193       1.82
#          3   4.49e-05       1.86
#          4    1.2e-05       1.98
#          5   2.92e-06       1.98
#          6   2.14e-07          2
#          7   1.06e-08          2
#          8   1.57e-09          2
#          9   7.32e-10          2
#         10   9.14e-11          2
# done in 0.044 seconds
# Expected: 0.033 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.042 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -206         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 163          |
# | TimeElapsed             | 13.8         |
# | TimestepsSoFar          | 32768        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3801054    |
# | explained_variance_t... | 0.000535     |
# | meankl                  | 0.0029695327 |
# | optimgain               | 0.033017192  |
# | surrgain                | 0.033017192  |
# ------------------------------------------
# ********** Iteration 32 ************
# Optimizing Policy...
# sampling
# done in 0.255 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00192          0
#          1    0.00123      0.272
#          2   0.000719        2.1
#          3   2.17e-05       2.21
#          4   4.93e-05       2.26
#          5   8.53e-07       2.28
#          6   2.51e-08       2.28
#          7   9.15e-10       2.28
#          8   2.24e-10       2.28
#          9   3.47e-11       2.28
# done in 0.035 seconds
# Expected: 0.037 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.041 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -206         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 168          |
# | TimeElapsed             | 14.2         |
# | TimestepsSoFar          | 33792        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3779075    |
# | explained_variance_t... | 0.00132      |
# | meankl                  | 0.0025091176 |
# | optimgain               | 0.03838063   |
# | surrgain                | 0.03838063   |
# ------------------------------------------
# ********** Iteration 33 ************
# Optimizing Policy...
# sampling
# done in 0.266 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0008          0
#          1    0.00148      0.359
#          2   0.000583       1.67
#          3   1.47e-05       1.78
#          4   3.45e-05       1.83
#          5   5.92e-07       1.84
#          6   3.25e-08       1.85
#          7   2.76e-09       1.85
#          8   1.13e-10       1.85
#          9   2.77e-10       1.85
#         10   3.26e-11       1.85
# done in 0.038 seconds
# Expected: 0.030 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.042 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -205         |
# | EpThisIter              | 6            |
# | EpisodesSoFar           | 174          |
# | TimeElapsed             | 14.5         |
# | TimestepsSoFar          | 34816        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3719267    |
# | explained_variance_t... | 0.000351     |
# | meankl                  | 0.0025311117 |
# | optimgain               | 0.03043965   |
# | surrgain                | 0.03043965   |
# ------------------------------------------
# ********** Iteration 34 ************
# Optimizing Policy...
# sampling
# done in 0.264 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00217          0
#          1   0.000822      0.261
#          2    0.00248       1.33
#          3   1.81e-05       1.94
#          4   5.44e-05       1.96
#          5   7.59e-07          2
#          6   3.88e-08       2.01
#          7   2.25e-09       2.01
#          8   6.07e-09       2.01
#          9   8.72e-10       2.01
#         10      7e-11       2.01
# done in 0.041 seconds
# Expected: 0.034 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.045 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -204         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 179          |
# | TimeElapsed             | 14.9         |
# | TimestepsSoFar          | 35840        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3723018    |
# | explained_variance_t... | -0.00021     |
# | meankl                  | 0.0029661136 |
# | optimgain               | 0.033754565  |
# | surrgain                | 0.033754565  |
# ------------------------------------------
# ********** Iteration 35 ************
# Optimizing Policy...
# sampling
# done in 0.285 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00161          0
#          1    0.00081      0.261
#          2    0.00156       1.29
#          3   6.18e-05       1.66
#          4      2e-05        1.8
#          5   6.35e-06       1.81
#          6   2.92e-07       1.83
#          7   1.45e-08       1.83
#          8   8.62e-10       1.84
#          9   1.24e-09       1.84
#         10   4.27e-11       1.84
# done in 0.039 seconds
# Expected: 0.031 Actual: 0.031
# Stepsize OK!
# vf
# done in 0.042 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -204         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 184          |
# | TimeElapsed             | 15.4         |
# | TimestepsSoFar          | 36864        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3566599    |
# | explained_variance_t... | -0.000247    |
# | meankl                  | 0.0032024763 |
# | optimgain               | 0.030786987  |
# | surrgain                | 0.030786987  |
# ------------------------------------------
# ********** Iteration 36 ************
# Optimizing Policy...
# sampling
# done in 0.264 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000874          0
#          1    0.00117      0.353
#          2   0.000693       1.47
#          3    4.1e-05       1.61
#          4   4.53e-05       1.74
#          5   1.92e-06       1.75
#          6    9.3e-08       1.76
#          7   5.22e-09       1.76
#          8    4.1e-10       1.76
#          9    5.7e-10       1.76
#         10   4.45e-10       1.76
# done in 0.041 seconds
# Expected: 0.029 Actual: 0.029
# Stepsize OK!
# vf
# done in 0.045 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -203        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 189         |
# | TimeElapsed             | 15.8        |
# | TimestepsSoFar          | 37888       |
# | entloss                 | 0.0         |
# | entropy                 | 1.356061    |
# | explained_variance_t... | 0.000659    |
# | meankl                  | 0.002961801 |
# | optimgain               | 0.02903692  |
# | surrgain                | 0.02903692  |
# -----------------------------------------
# ********** Iteration 37 ************
# Optimizing Policy...
# sampling
# done in 0.269 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00191          0
#          1    0.00113      0.274
#          2    0.00242       1.08
#          3   5.69e-05       2.01
#          4    5.9e-05       2.03
#          5   3.58e-06        2.1
#          6   2.29e-07       2.11
#          7   1.63e-08       2.11
#          8   2.63e-08       2.11
#          9   3.81e-09       2.11
#         10   3.91e-09       2.11
# done in 0.038 seconds
# Expected: 0.035 Actual: 0.036
# Stepsize OK!
# vf
# done in 0.051 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -202         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 194          |
# | TimeElapsed             | 16.2         |
# | TimestepsSoFar          | 38912        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3514054    |
# | explained_variance_t... | 0.000823     |
# | meankl                  | 0.0029396485 |
# | optimgain               | 0.03614252   |
# | surrgain                | 0.03614252   |
# ------------------------------------------
# ********** Iteration 38 ************
# Optimizing Policy...
# sampling
# done in 0.293 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00101          0
#          1    0.00178       0.35
#          2   0.000204       1.88
#          3   4.25e-05       1.92
#          4   8.54e-05       1.95
#          5   9.71e-07       2.03
#          6   6.64e-08       2.03
#          7   2.03e-09       2.04
#          8   6.71e-09       2.04
#          9   1.26e-10       2.04
#         10   4.31e-10       2.04
# done in 0.045 seconds
# Expected: 0.033 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.045 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -202         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 199          |
# | TimeElapsed             | 16.6         |
# | TimestepsSoFar          | 39936        |
# | entloss                 | 0.0          |
# | entropy                 | 1.3501666    |
# | explained_variance_t... | -0.00102     |
# | meankl                  | 0.0024866292 |
# | optimgain               | 0.033906266  |
# | surrgain                | 0.033906266  |
# ------------------------------------------
# ********** Iteration 39 ************
# Optimizing Policy...
# sampling
# done in 0.288 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000905          0
#          1    0.00199      0.512
# ...
#          3   1.83e-05        0.9
#          4   3.24e-06      0.964
#          5   7.89e-07      0.977
#          6   9.73e-08      0.982
#          7   1.55e-08      0.983
#          8   2.22e-08      0.983
#          9   2.33e-09      0.983
#         10   4.75e-10      0.983
# done in 0.040 seconds
# Expected: 0.017 Actual: 0.018
# Stepsize OK!
# vf
# done in 0.053 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -200        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 3573        |
# | TimeElapsed             | 288         |
# | TimestepsSoFar          | 714752      |
# | entloss                 | 0.0         |
# | entropy                 | 0.74189174  |
# | explained_variance_t... | 0           |
# | meankl                  | 0.003868502 |
# | optimgain               | 0.017856888 |
# | surrgain                | 0.017856888 |
# -----------------------------------------
# ********** Iteration 698 ************
# Optimizing Policy...
# sampling
# done in 0.277 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000566          0
#          1   0.000811      0.528
#          2   0.000105       0.96
#          3   2.24e-05       1.14
#          4   1.23e-05       1.16
#          5   1.19e-06       1.19
#          6   1.85e-07       1.19
#          7   4.72e-08       1.19
#          8   2.56e-09       1.19
#          9   6.44e-10       1.19
#         10   1.31e-10       1.19
# done in 0.038 seconds
# Expected: 0.022 Actual: 0.024
# Stepsize OK!
# vf
# done in 0.048 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -200        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 3578        |
# | TimeElapsed             | 288         |
# | TimestepsSoFar          | 715776      |
# | entloss                 | 0.0         |
# | entropy                 | 0.73259187  |
# | explained_variance_t... | 0           |
# | meankl                  | 0.004847098 |
# | optimgain               | 0.023848625 |
# | surrgain                | 0.023848625 |
# -----------------------------------------
# ********** Iteration 699 ************
# Optimizing Policy...
# sampling
# done in 0.273 seconds
# computegrad
# done in 0.019 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000537          0
#          1   0.000261      0.132
#          2   6.36e-05      0.553
#          3   4.28e-05      0.621
#          4   6.04e-06       0.71
#          5   6.64e-07      0.743
#          6   1.25e-07      0.748
#          7   1.91e-08       0.75
#          8   1.46e-08       0.75
#          9    2.2e-09       0.75
#         10   2.09e-10       0.75
# done in 0.045 seconds
# Expected: 0.015 Actual: 0.016
# Stepsize OK!
# vf
# done in 0.048 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -200        |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 3584        |
# | TimeElapsed             | 288         |
# | TimestepsSoFar          | 716800      |
# | entloss                 | 0.0         |
# | entropy                 | 0.757651    |
# | explained_variance_t... | 0           |
# | meankl                  | 0.005482172 |
# | optimgain               | 0.016378205 |
# | surrgain                | 0.016378205 |
# -----------------------------------------
# ********** Iteration 700 ************
# Optimizing Policy...
# sampling
# done in 0.282 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000774          0
#          1   0.000464      0.239
#          2   0.000391      0.434
#          3   3.17e-05      0.685
#          4   5.75e-06      0.788
#          5   2.61e-06      0.813
#          6   2.16e-07      0.826
#          7   5.42e-08      0.828
#          8   1.31e-07      0.828
#          9   7.03e-09      0.828
#         10    6.5e-10      0.828
# done in 0.045 seconds
# Expected: 0.018 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.050 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -200         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 3589         |
# | TimeElapsed             | 289          |
# | TimestepsSoFar          | 717824       |
# | entloss                 | 0.0          |
# | entropy                 | 0.6836871    |
# | explained_variance_t... | 0            |
# | meankl                  | 0.0064951284 |
# | optimgain               | 0.019811423  |
# | surrgain                | 0.019811423  |
# ------------------------------------------
# ********** Iteration 701 ************
# Optimizing Policy...
# sampling
# done in 0.276 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   9.09e-05          0
#          1   8.99e-05       0.32
#          2   2.14e-05      0.396
#          3   7.76e-06      0.485
#          4   2.95e-06      0.495
#          5   2.96e-07      0.515
#          6   4.26e-08      0.519
#          7   6.38e-09       0.52
#          8   2.89e-10       0.52
#          9   3.75e-10       0.52
#         10   4.17e-11       0.52
# done in 0.045 seconds
# Expected: 0.009 Actual: 0.009
# Stepsize OK!
# vf
# done in 0.050 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -200        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 3594        |
# | TimeElapsed             | 289         |
# | TimestepsSoFar          | 718848      |
# | entloss                 | 0.0         |
# | entropy                 | 0.6331603   |
# | explained_variance_t... | 0           |
# | meankl                  | 0.003885009 |
# | optimgain               | 0.009254349 |
# | surrgain                | 0.009254349 |
# -----------------------------------------
# ********** Iteration 702 ************
# Optimizing Policy...
# sampling
# done in 0.279 seconds
# computegrad
# done in 0.021 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000273          0
#          1   0.000414      0.187
#          2   3.31e-05      0.702
#          3   2.71e-05      0.729
#          4   2.13e-06      0.821
#          5   4.34e-07      0.829
#          6   4.81e-08      0.833
#          7   3.65e-09      0.834
#          8   5.07e-09      0.834
#          9   4.61e-10      0.834
#         10   1.81e-10      0.834
# done in 0.045 seconds
# Expected: 0.015 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.049 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -200        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 3599        |
# | TimeElapsed             | 290         |
# | TimestepsSoFar          | 719872      |
# | entloss                 | 0.0         |
# | entropy                 | 0.715235    |
# | explained_variance_t... | 0           |
# | meankl                  | 0.003886019 |
# | optimgain               | 0.015149759 |
# | surrgain                | 0.015149759 |
# -----------------------------------------
# ********** Iteration 703 ************
# Optimizing Policy...
# sampling
# done in 0.277 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000302          0
#          1   0.000169      0.126
#          2   0.000179      0.401
#          3    2.6e-05       0.47
#          4   1.07e-05      0.551
#          5   9.95e-07      0.596
#          6   4.12e-07      0.607
#          7   6.25e-08       0.61
#          8   1.08e-08      0.611
#          9   2.35e-08      0.611
#         10   1.06e-08      0.611
# done in 0.041 seconds
# Expected: 0.012 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.051 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -200        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 3604        |
# | TimeElapsed             | 290         |
# | TimestepsSoFar          | 720896      |
# | entloss                 | 0.0         |
# | entropy                 | 0.84317744  |
# | explained_variance_t... | 0           |
# | meankl                  | 0.005151447 |
# | optimgain               | 0.011720488 |
# | surrgain                | 0.011720488 |
# -----------------------------------------
# ********** Iteration 704 ************
# Optimizing Policy...
# sampling
# done in 0.295 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000391          0
#          1   0.000708      0.299
#          2   4.52e-05      0.749
#          3   4.73e-05       0.84
#          4   5.97e-06      0.872
#          5   1.05e-06      0.898
#          6    1.3e-07      0.904
#          7   1.66e-08      0.905
#          8   2.15e-09      0.905
#          9   4.77e-09      0.905
#         10   2.63e-10      0.905
# done in 0.047 seconds
# Expected: 0.018 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.049 seconds
# -----------------------------------------
# | EpLenMean               | 200         |
# | EpRewMean               | -200        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 3609        |
# | TimeElapsed             | 291         |
# | TimestepsSoFar          | 721920      |
# | entloss                 | 0.0         |
# | entropy                 | 0.74361634  |
# | explained_variance_t... | 0           |
# | meankl                  | 0.004911095 |
# | optimgain               | 0.020287829 |
# | surrgain                | 0.020287829 |
# -----------------------------------------
# ********** Iteration 705 ************
# Optimizing Policy...
# sampling
# done in 0.290 seconds
# computegrad
# done in 0.020 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000742          0
#          1   0.000286      0.147
#          2   7.86e-05      0.438
#          3   0.000118      0.547
#          4    1.5e-05      0.625
#          5    2.8e-06      0.675
#          6   2.87e-07      0.695
#          7    5.6e-08      0.698
#          8   1.66e-08      0.698
#          9   3.04e-08      0.699
#         10    1.6e-09      0.699
# done in 0.042 seconds
# Expected: 0.015 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -200         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 3614         |
# | TimeElapsed             | 291          |
# | TimestepsSoFar          | 722944       |
# | entloss                 | 0.0          |
# | entropy                 | 0.79353124   |
# | explained_variance_t... | -1.19e-07    |
# | meankl                  | 0.0056596864 |
# | optimgain               | 0.015065556  |
# | surrgain                | 0.015065556  |
# ------------------------------------------
# ********** Iteration 706 ************
# Optimizing Policy...
# sampling
# done in 0.284 seconds
# computegrad
# done in 0.018 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0   0.000821          0
#          1   0.000729      0.209
#          2   0.000117      0.464
#          3   0.000114      0.625
#          4   1.57e-05      0.729
#          5   3.14e-06       0.79
#          6   5.41e-07      0.811
#          7   8.03e-08      0.815
#          8   3.95e-08      0.816
#          9   1.44e-08      0.816
#         10   1.43e-09      0.816
# done in 0.039 seconds
# Expected: 0.018 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.049 seconds
# ------------------------------------------
# | EpLenMean               | 200          |
# | EpRewMean               | -200         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 3619         |
# | TimeElapsed             | 291          |
# | TimestepsSoFar          | 723968       |
# | entloss                 | 0.0          |
# | entropy                 | 0.7618388    |
# | explained_variance_t... | -1.19e-07    |
# | meankl                  | 0.0058974447 |
# | optimgain               | 0.020009963  |
# | surrgain                | 0.020009963  |
# ------------------------------------------
# ********** Iteration 707 ************
# Optimizing Policy...
# sampling
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d52a80276745> in <module>
#      22 # Train the agent
#      23 time_steps = 1000000
# ---> 24 model.learn(total_timesteps=time_steps)
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/trpo_mpi/trpo_mpi.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     329                     for k in range(self.g_step):
#     330                         with self.timed("sampling"):
# --> 331                             seg = seg_gen.__next__()
#     332                         add_vtarg_and_adv(seg, self.gamma, self.lam)
#     333                         # ob, ac, atarg, ret, td1ret = map(np.concatenate, (obs, acs, atargs, rets, td1rets))
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/trpo_mpi/utils.py in traj_segment_generator(policy, env, horizon, reward_giver, gail)
#      58
#      59     while True:
# ---> 60         action, vpred, states, _ = policy.step(observation.reshape(-1, *observation.shape), states, done)
#      61         # Slight weirdness here because we need value function at time T
#      62         # before returning segment [0, T-1] so we get the correct
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/common/policies.py in step(self, obs, state, mask, deterministic)
#     573         else:
#     574             action, value, neglogp = self.sess.run([self.action, self.value_flat, self.neglogp],
# --> 575                                                    {self.obs_ph: obs})
#     576         return action, value, self.initial_state, neglogp
#     577
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_EPISODES, "TRPO")
plt.show()
