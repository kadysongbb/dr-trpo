# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines.bench import Monitor
from stable_baselines.common.policies import MlpPolicy
from stable_baselines import results_plotter
from stable_baselines import *

# %%
import gym
import numpy as np

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make('CartPole-v1')
env = Monitor(env, log_dir, allow_early_resets=True)

model = TRPO(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 50000
model.learn(total_timesteps=time_steps)
# Out:
# ********** Iteration 0 ************
# Optimizing Policy...
# sampling
# done in 0.322 seconds
# computegrad
# done in 0.114 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0333          0
#          1   0.000339      0.135
#          2   0.000554      0.186
#          3   3.73e-05      0.432
#          4   8.25e-07      0.594
#          5   2.61e-06      0.606
#          6   2.02e-09      0.606
#          7   1.83e-08      0.606
#          8   4.97e-12      0.606
# done in 0.172 seconds
# Expected: 0.026 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.055 seconds
# -----------------------------------------
# | EpLenMean               | 22.2        |
# | EpRewMean               | 22.2        |
# | EpThisIter              | 46          |
# | EpisodesSoFar           | 46          |
# | TimeElapsed             | 0.741       |
# | TimestepsSoFar          | 1024        |
# | entloss                 | 0.0         |
# | entropy                 | 0.6848309   |
# | explained_variance_t... | 0.00105     |
# | meankl                  | 0.008500225 |
# | optimgain               | 0.025260478 |
# | surrgain                | 0.025260478 |
# -----------------------------------------
# ********** Iteration 1 ************
# Optimizing Policy...
# sampling
# done in 0.233 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0131          0
#          1    0.00194      0.149
#          2   0.000322      0.293
#          3   0.000275      0.313
#          4   2.18e-06      0.527
#          5   1.22e-08      0.556
#          6   1.76e-07      0.556
#          7   1.69e-11      0.556
# done in 0.010 seconds
# Expected: 0.025 Actual: 0.028
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 32.9        |
# | EpRewMean               | 32.9        |
# | EpThisIter              | 29          |
# | EpisodesSoFar           | 75          |
# | TimeElapsed             | 1.02        |
# | TimestepsSoFar          | 2048        |
# | entloss                 | 0.0         |
# | entropy                 | 0.6619166   |
# | explained_variance_t... | -0.000434   |
# | meankl                  | 0.011836816 |
# | optimgain               | 0.027721705 |
# | surrgain                | 0.027721705 |
# -----------------------------------------
# ********** Iteration 2 ************
# Optimizing Policy...
# sampling
# done in 0.231 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0142          0
#          1    0.00369      0.107
#          2   4.71e-05      0.449
#          3   0.000127      0.451
#          4   2.67e-05      0.556
#          5   3.79e-07      0.644
#          6   1.68e-08       0.65
#          7   2.64e-08       0.65
#          8   5.76e-10      0.651
#          9   6.37e-11      0.651
# done in 0.012 seconds
# Expected: 0.027 Actual: 0.028
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 40.4        |
# | EpRewMean               | 40.4        |
# | EpThisIter              | 23          |
# | EpisodesSoFar           | 98          |
# | TimeElapsed             | 1.29        |
# | TimestepsSoFar          | 3072        |
# | entloss                 | 0.0         |
# | entropy                 | 0.62241685  |
# | explained_variance_t... | -0.000491   |
# | meankl                  | 0.011005441 |
# | optimgain               | 0.028447524 |
# | surrgain                | 0.028447524 |
# -----------------------------------------
# ********** Iteration 3 ************
# Optimizing Policy...
# sampling
# done in 0.225 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0862          0
#          1    0.00263      0.135
#          2   0.000756      0.173
#          3   0.000107       0.18
#          4   2.12e-05      0.344
#          5    1.7e-05      0.432
#          6   1.82e-06      0.511
#          7   1.85e-06      0.511
#          8   1.24e-05      0.518
#          9   1.19e-07       0.52
#         10   5.15e-07      0.522
# done in 0.013 seconds
# Expected: 0.031 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 51.9        |
# | EpRewMean               | 51.9        |
# | EpThisIter              | 15          |
# | EpisodesSoFar           | 113         |
# | TimeElapsed             | 1.56        |
# | TimestepsSoFar          | 4096        |
# | entloss                 | 0.0         |
# | entropy                 | 0.6138669   |
# | explained_variance_t... | 0.0167      |
# | meankl                  | 0.009721239 |
# | optimgain               | 0.02991445  |
# | surrgain                | 0.02991445  |
# -----------------------------------------
# ********** Iteration 4 ************
# Optimizing Policy...
# sampling
# done in 0.241 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00957          0
#          1    0.00246     0.0685
#          2    0.00602      0.179
#          3   0.000327      0.359
#          4   9.48e-05      0.372
#          5   1.05e-05       0.57
#          6    1.1e-06      0.642
#          7   6.12e-06      0.653
#          8   3.73e-08      0.653
#          9    6.3e-08      0.653
#         10   4.25e-07      0.654
# done in 0.018 seconds
# Expected: 0.022 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 65.6        |
# | EpRewMean               | 65.6        |
# | EpThisIter              | 11          |
# | EpisodesSoFar           | 124         |
# | TimeElapsed             | 1.86        |
# | TimestepsSoFar          | 5120        |
# | entloss                 | 0.0         |
# | entropy                 | 0.57003814  |
# | explained_variance_t... | 0.0116      |
# | meankl                  | 0.00970021  |
# | optimgain               | 0.020471223 |
# | surrgain                | 0.020471223 |
# -----------------------------------------
# ********** Iteration 5 ************
# Optimizing Policy...
# sampling
# done in 0.265 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00504          0
#          1   0.000892     0.0207
#          2   0.000362     0.0365
#          3   0.000841     0.0774
#          4   6.86e-05      0.265
#          5   1.46e-05      0.423
#          6   1.13e-05      0.493
#          7      1e-05      0.494
#          8   1.63e-06      0.535
#          9   4.53e-07      0.535
#         10   4.03e-06      0.537
# done in 0.014 seconds
# Expected: 0.013 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.022 seconds
# ------------------------------------------
# | EpLenMean               | 84.8         |
# | EpRewMean               | 84.8         |
# | EpThisIter              | 7            |
# | EpisodesSoFar           | 131          |
# | TimeElapsed             | 2.18         |
# | TimestepsSoFar          | 6144         |
# | entloss                 | 0.0          |
# | entropy                 | 0.58980095   |
# | explained_variance_t... | 0.133        |
# | meankl                  | 0.010217473  |
# | optimgain               | 0.0138514275 |
# | surrgain                | 0.0138514275 |
# ------------------------------------------
# ********** Iteration 6 ************
# Optimizing Policy...
# sampling
# done in 0.253 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0255          0
#          1    0.00539     0.0584
#          2    0.00245     0.0924
#          3    0.00588      0.122
#          4   0.000664      0.601
#          5    0.00017      0.953
#          6   6.02e-05       1.05
#          7    0.00198       1.12
#          8    0.00011       1.17
#          9   3.02e-05       1.18
#         10   0.000126       1.21
# done in 0.015 seconds
# Expected: 0.031 Actual: 0.023
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 101          |
# | EpRewMean               | 101          |
# | EpThisIter              | 4            |
# | EpisodesSoFar           | 135          |
# | TimeElapsed             | 2.48         |
# | TimestepsSoFar          | 7168         |
# | entloss                 | 0.0          |
# | entropy                 | 0.6004611    |
# | explained_variance_t... | 0.0377       |
# | meankl                  | 0.0046441643 |
# | optimgain               | 0.022661943  |
# | surrgain                | 0.022661943  |
# ------------------------------------------
# ********** Iteration 7 ************
# Optimizing Policy...
# sampling
# done in 0.229 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00261          0
#          1     0.0008     0.0161
#          2   0.000584     0.0367
#          3    0.00322      0.137
#          4   0.000146      0.295
#          5   4.65e-05      0.562
#          6   1.27e-05      0.624
#          7   5.58e-05      0.662
#          8   4.27e-06      0.664
#          9   6.05e-05      0.675
#         10   2.68e-05      0.686
# done in 0.014 seconds
# Expected: 0.014 Actual: 0.009
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 125         |
# | EpRewMean               | 125         |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 141         |
# | TimeElapsed             | 2.75        |
# | TimestepsSoFar          | 8192        |
# | entloss                 | 0.0         |
# | entropy                 | 0.6253303   |
# | explained_variance_t... | 0.0972      |
# | meankl                  | 0.004850272 |
# | optimgain               | 0.008775379 |
# | surrgain                | 0.008775379 |
# -----------------------------------------
# ********** Iteration 8 ************
# Optimizing Policy...
# sampling
# done in 0.230 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00637          0
#          1    0.00152     0.0272
#          2    0.00306     0.0626
#          3    0.00248      0.174
#          4   0.000357      0.393
#          5   6.88e-05      0.862
#          6   8.12e-06      0.925
#          7   0.000256      0.932
#          8   0.000179      0.972
#          9   1.66e-06      0.981
#         10   2.94e-06      0.985
# done in 0.015 seconds
# Expected: 0.022 Actual: 0.019
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 139          |
# | EpRewMean               | 139          |
# | EpThisIter              | 6            |
# | EpisodesSoFar           | 147          |
# | TimeElapsed             | 3.03         |
# | TimestepsSoFar          | 9216         |
# | entloss                 | 0.0          |
# | entropy                 | 0.59693253   |
# | explained_variance_t... | 0.0285       |
# | meankl                  | 0.0075649414 |
# | optimgain               | 0.01870418   |
# | surrgain                | 0.01870418   |
# ------------------------------------------
# ********** Iteration 9 ************
# Optimizing Policy...
# sampling
# done in 0.234 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0189          0
#          1     0.0111     0.0756
#          2    0.00963      0.109
#          3    0.00415      0.249
#          4   0.000213      0.568
#          5   5.96e-05      0.639
#          6   0.000123       0.73
#          7   1.01e-05      0.732
#          8   0.000129      0.778
#          9   1.27e-06      0.787
#         10   2.12e-06      0.799
# done in 0.012 seconds
# Expected: 0.030 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.018 seconds
# ------------------------------------------
# | EpLenMean               | 154          |
# | EpRewMean               | 154          |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 152          |
# | TimeElapsed             | 3.31         |
# | TimestepsSoFar          | 10240        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5873796    |
# | explained_variance_t... | 0.0195       |
# | meankl                  | 0.0058774645 |
# | optimgain               | 0.02045285   |
# | surrgain                | 0.02045285   |
# ------------------------------------------
# ********** Iteration 10 ************
# Optimizing Policy...
# sampling
# done in 0.236 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0177          0
#          1      0.005     0.0199
#          2    0.00141     0.0569
#          3    0.00473      0.175
#          4   0.000198      0.374
#          5   7.07e-05      0.514
#          6    0.00288       0.54
#          7   1.59e-05      0.719
#          8   3.68e-06       0.76
#          9   7.74e-06      0.761
#         10   5.88e-05      0.771
# done in 0.016 seconds
# Expected: 0.021 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 167         |
# | EpRewMean               | 167         |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 158         |
# | TimeElapsed             | 3.6         |
# | TimestepsSoFar          | 11264       |
# | entloss                 | 0.0         |
# | entropy                 | 0.58447635  |
# | explained_variance_t... | -0.0287     |
# | meankl                  | 0.007781611 |
# | optimgain               | 0.016617462 |
# | surrgain                | 0.016617462 |
# -----------------------------------------
# ********** Iteration 11 ************
# Optimizing Policy...
# sampling
# done in 0.253 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00428          0
#          1     0.0034     0.0281
#          2   0.000349     0.0378
#          3   0.000586      0.052
#          4    0.00012      0.414
#          5   2.76e-05      0.554
#          6   0.000599      0.621
#          7   1.25e-05      0.631
#          8   4.08e-06      0.666
#          9   2.26e-05      0.668
#         10   6.69e-07      0.682
# done in 0.015 seconds
# Expected: 0.015 Actual: 0.005
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 182          |
# | EpRewMean               | 182          |
# | EpThisIter              | 4            |
# | EpisodesSoFar           | 162          |
# | TimeElapsed             | 3.91         |
# | TimestepsSoFar          | 12288        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5773407    |
# | explained_variance_t... | -0.0844      |
# | meankl                  | 0.003324001  |
# | optimgain               | 0.0049805567 |
# | surrgain                | 0.0049805567 |
# ------------------------------------------
# ********** Iteration 12 ************
# Optimizing Policy...
# sampling
# done in 0.244 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00883          0
#          1    0.00367     0.0266
#          2    0.00221     0.0479
#          3     0.0014     0.0763
#          4   0.000229      0.203
#          5   5.76e-05      0.492
#          6   4.48e-05      0.699
#          7    2.6e-05      0.701
#          8   2.12e-05      0.752
#          9   6.11e-06      0.753
#         10   3.26e-05      0.759
# done in 0.015 seconds
# Expected: 0.018 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 199         |
# | EpRewMean               | 199         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 166         |
# | TimeElapsed             | 4.2         |
# | TimestepsSoFar          | 13312       |
# | entloss                 | 0.0         |
# | entropy                 | 0.569358    |
# | explained_variance_t... | 0.12        |
# | meankl                  | 0.006147188 |
# | optimgain               | 0.013784636 |
# | surrgain                | 0.013784636 |
# -----------------------------------------
# ********** Iteration 13 ************
# Optimizing Policy...
# sampling
# done in 0.239 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00768          0
#          1    0.00428     0.0219
#          2    0.00222     0.0481
#          3    0.00141     0.0695
#          4   0.000277       0.49
#          5   0.000105      0.659
#          6   8.47e-05      0.781
#          7   6.24e-05      0.782
#          8   0.000638      0.855
#          9   6.45e-06      0.875
#         10    4.4e-05      0.894
# done in 0.013 seconds
# Expected: 0.021 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.017 seconds
# -----------------------------------------
# | EpLenMean               | 202         |
# | EpRewMean               | 202         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 170         |
# | TimeElapsed             | 4.48        |
# | TimestepsSoFar          | 14336       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5813731   |
# | explained_variance_t... | 0.135       |
# | meankl                  | 0.008875122 |
# | optimgain               | 0.014847271 |
# | surrgain                | 0.014847271 |
# -----------------------------------------
# ********** Iteration 14 ************
# Optimizing Policy...
# sampling
# done in 0.227 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0101          0
#          1    0.00501     0.0369
#          2     0.0048     0.0532
#          3    0.00319      0.226
#          4   0.000263      0.283
#          5   0.000103      0.435
#          6   5.86e-05      0.677
#          7   0.000484      0.684
#          8   2.34e-05      0.781
#          9   9.94e-06      0.782
#         10   1.69e-06      0.818
# done in 0.013 seconds
# Expected: 0.022 Actual: 0.016
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 215          |
# | EpRewMean               | 215          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 173          |
# | TimeElapsed             | 4.76         |
# | TimestepsSoFar          | 15360        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5910988    |
# | explained_variance_t... | 0.163        |
# | meankl                  | 0.0048285024 |
# | optimgain               | 0.015551233  |
# | surrgain                | 0.015551233  |
# ------------------------------------------
# ********** Iteration 15 ************
# Optimizing Policy...
# sampling
# done in 0.236 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0134          0
#          1    0.00155     0.0166
#          2    0.00127     0.0292
#          3    0.00299      0.161
#          4   0.000441      0.349
#          5   0.000103      0.579
#          6     0.0024        0.7
#          7   3.62e-05       0.73
#          8   0.000148      0.812
#          9   1.62e-05      0.817
#         10   5.19e-06      0.862
# done in 0.015 seconds
# Expected: 0.019 Actual: 0.013
# Stepsize OK!
# vf
# done in 0.018 seconds
# ------------------------------------------
# | EpLenMean               | 225          |
# | EpRewMean               | 225          |
# | EpThisIter              | 4            |
# | EpisodesSoFar           | 177          |
# | TimeElapsed             | 5.04         |
# | TimestepsSoFar          | 16384        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5861211    |
# | explained_variance_t... | 0.137        |
# | meankl                  | 0.0049875346 |
# | optimgain               | 0.013051381  |
# | surrgain                | 0.013051381  |
# ------------------------------------------
# ********** Iteration 16 ************
# Optimizing Policy...
# sampling
# done in 0.232 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00977          0
#          1    0.00197     0.0378
#          2    0.00229     0.0482
#          3    0.00466      0.111
#          4    0.00024      0.555
#          5    0.00011      0.836
#          6   2.68e-05      0.886
#          7   0.000288       0.89
#          8   2.84e-05      0.953
#          9   1.54e-05      0.955
#         10   7.19e-05      0.966
# done in 0.013 seconds
# Expected: 0.023 Actual: 0.017
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 228          |
# | EpRewMean               | 228          |
# | EpThisIter              | 4            |
# | EpisodesSoFar           | 181          |
# | TimeElapsed             | 5.32         |
# | TimestepsSoFar          | 17408        |
# | entloss                 | 0.0          |
# | entropy                 | 0.58987504   |
# | explained_variance_t... | 0.0995       |
# | meankl                  | 0.0065363003 |
# | optimgain               | 0.01717468   |
# | surrgain                | 0.01717468   |
# ------------------------------------------
# ********** Iteration 17 ************
# Optimizing Policy...
# sampling
# done in 0.235 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0129          0
#          1    0.00136     0.0269
#          2    0.00497     0.0474
#          3    0.00271      0.329
#          4    0.00013      0.423
#          5   0.000123       0.56
#          6   0.000203      0.785
#          7   9.54e-05       0.79
#          8   1.82e-05      0.855
#          9   0.000227      0.868
#         10   3.17e-06      0.882
# done in 0.015 seconds
# Expected: 0.021 Actual: 0.021
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 238         |
# | EpRewMean               | 238         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 185         |
# | TimeElapsed             | 5.6         |
# | TimestepsSoFar          | 18432       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5841738   |
# | explained_variance_t... | 0.0907      |
# | meankl                  | 0.012072188 |
# | optimgain               | 0.021100903 |
# | surrgain                | 0.021100903 |
# -----------------------------------------
# ********** Iteration 18 ************
# Optimizing Policy...
# sampling
# done in 0.244 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0354          0
#          1      0.023     0.0468
#          2    0.00319      0.103
#          3    0.00317      0.452
#          4    0.00267      0.488
#          5    0.00032      0.705
#          6   0.000124      0.909
#          7   0.000367      0.912
#          8   2.74e-05      0.983
#          9   0.000168       1.05
#         10   3.44e-05       1.06
# done in 0.015 seconds
# Expected: 0.033 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 244         |
# | EpRewMean               | 244         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 189         |
# | TimeElapsed             | 5.9         |
# | TimestepsSoFar          | 19456       |
# | entloss                 | 0.0         |
# | entropy                 | 0.570839    |
# | explained_variance_t... | 0.0912      |
# | meankl                  | 0.006001699 |
# | optimgain               | 0.024598334 |
# | surrgain                | 0.024598334 |
# -----------------------------------------
# ********** Iteration 19 ************
# Optimizing Policy...
# sampling
# done in 0.228 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.053          0
#          1     0.0157      0.042
#          2    0.00575      0.153
#          3     0.0264      0.284
#          4      0.001      0.428
#          5    0.00032      0.549
#          6    9.9e-05      0.764
#          7   0.000318      0.767
#          8   4.13e-05      0.868
#          9   0.000361      0.896
#         10    3.4e-05      0.904
# done in 0.014 seconds
# Expected: 0.034 Actual: 0.028
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 247         |
# | EpRewMean               | 247         |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 194         |
# | TimeElapsed             | 6.17        |
# | TimestepsSoFar          | 20480       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5771513   |
# | explained_variance_t... | 0.0815      |
# | meankl                  | 0.008307494 |
# | optimgain               | 0.028090477 |
# | surrgain                | 0.028090477 |
# -----------------------------------------
# ********** Iteration 20 ************
# Optimizing Policy...
# sampling
# done in 0.233 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00683          0
#          1    0.00228       0.03
#          2    0.00794      0.126
#          3     0.0109      0.179
#          4   0.000588      0.687
#          5   0.000195      0.841
#          6   0.000504      0.979
#          7    0.00748        1.1
#          8   2.47e-05       1.18
#          9   5.98e-05       1.19
#         10   5.08e-06       1.24
# done in 0.015 seconds
# Expected: 0.028 Actual: 0.018
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 252         |
# | EpRewMean               | 252         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 198         |
# | TimeElapsed             | 6.45        |
# | TimestepsSoFar          | 21504       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5810371   |
# | explained_variance_t... | 0.04        |
# | meankl                  | 0.008229295 |
# | optimgain               | 0.017843205 |
# | surrgain                | 0.017843205 |
# -----------------------------------------
# ********** Iteration 21 ************
# Optimizing Policy...
# sampling
# done in 0.256 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.168          0
#          1     0.0107     0.0489
#          2     0.0125      0.179
#          3    0.00198      0.195
#          4    0.00126      0.416
#          5    0.00132      0.453
#          6   0.000155      0.777
#          7    0.00502      0.836
#          8   0.000108      0.893
#          9    0.00286      0.925
#         10   1.48e-05      0.974
# done in 0.015 seconds
# Expected: 0.036 Actual: 0.028
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 235          |
# | EpRewMean               | 235          |
# | EpThisIter              | 7            |
# | EpisodesSoFar           | 205          |
# | TimeElapsed             | 6.76         |
# | TimestepsSoFar          | 22528        |
# | entloss                 | 0.0          |
# | entropy                 | 0.57672936   |
# | explained_variance_t... | 0.0142       |
# | meankl                  | 0.0074632857 |
# | optimgain               | 0.028165285  |
# | surrgain                | 0.028165285  |
# ------------------------------------------
# ********** Iteration 22 ************
# Optimizing Policy...
# sampling
# done in 0.227 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0678          0
#          1    0.00785     0.0195
#          2    0.00211     0.0702
#          3   0.000576      0.164
#          4    0.00113      0.387
#          5   0.000301        0.4
#          6    0.00407      0.415
#          7   0.000111      0.628
#          8    3.1e-05       0.76
#          9   1.76e-05       0.84
#         10   3.06e-05       0.84
# done in 0.012 seconds
# Expected: 0.023 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 236         |
# | EpRewMean               | 236         |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 210         |
# | TimeElapsed             | 7.03        |
# | TimestepsSoFar          | 23552       |
# | entloss                 | 0.0         |
# | entropy                 | 0.6061042   |
# | explained_variance_t... | 0.00395     |
# | meankl                  | 0.009521417 |
# | optimgain               | 0.019775607 |
# | surrgain                | 0.019775607 |
# -----------------------------------------
# ********** Iteration 23 ************
# Optimizing Policy...
# sampling
# done in 0.238 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0303          0
#          1     0.0019     0.0128
#          2    0.00444     0.0448
#          3   0.000242        0.2
#          4   0.000484      0.208
#          5   0.000239      0.273
#          6    0.00493      0.347
#          7   6.34e-05       0.39
#          8   2.94e-05      0.468
#          9   0.000151      0.542
#         10   2.08e-05      0.549
# done in 0.016 seconds
# Expected: 0.017 Actual: 0.016
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 233         |
# | EpRewMean               | 233         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 213         |
# | TimeElapsed             | 7.32        |
# | TimestepsSoFar          | 24576       |
# | entloss                 | 0.0         |
# | entropy                 | 0.58344257  |
# | explained_variance_t... | -0.00692    |
# | meankl                  | 0.00847142  |
# | optimgain               | 0.015986443 |
# | surrgain                | 0.015986443 |
# -----------------------------------------
# ********** Iteration 24 ************
# Optimizing Policy...
# sampling
# done in 0.250 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0984          0
#          1     0.0684     0.0512
#          2     0.0116      0.129
#          3     0.0153      0.208
#          4   0.000742      0.609
#          5   0.000207      0.868
#          6    0.00768       0.92
#          7   0.000118      0.963
#          8   4.23e-05       1.06
#          9   0.000166       1.06
#         10   0.000174       1.12
# done in 0.013 seconds
# Expected: 0.044 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 229         |
# | EpRewMean               | 229         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 217         |
# | TimeElapsed             | 7.62        |
# | TimestepsSoFar          | 25600       |
# | entloss                 | 0.0         |
# | entropy                 | 0.57059556  |
# | explained_variance_t... | 0.0145      |
# | meankl                  | 0.007548715 |
# | optimgain               | 0.033934824 |
# | surrgain                | 0.033934824 |
# -----------------------------------------
# ********** Iteration 25 ************
# Optimizing Policy...
# sampling
# done in 0.221 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0178          0
#          1      0.041     0.0621
#          2    0.00776        0.1
#          3    0.00352      0.331
#          4    0.00199      0.366
#          5    0.00024      0.602
#          6   8.53e-05      0.785
#          7   0.000132      0.786
#          8   8.61e-06      0.936
#          9   0.000214       0.96
#         10   9.93e-06      0.982
# done in 0.015 seconds
# Expected: 0.032 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.017 seconds
# -----------------------------------------
# | EpLenMean               | 240         |
# | EpRewMean               | 240         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 219         |
# | TimeElapsed             | 7.88        |
# | TimestepsSoFar          | 26624       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5613762   |
# | explained_variance_t... | 0.00315     |
# | meankl                  | 0.006615202 |
# | optimgain               | 0.025116928 |
# | surrgain                | 0.025116928 |
# -----------------------------------------
# ********** Iteration 26 ************
# Optimizing Policy...
# sampling
# done in 0.232 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0101          0
#          1    0.00908     0.0159
#          2   0.000409     0.0305
#          3     0.0027      0.138
#          4   0.000761      0.247
#          5   0.000155      0.344
#          6    0.00741      0.441
#          7   4.43e-05      0.496
#          8   1.29e-05       0.64
#          9   6.05e-05      0.673
#         10   3.79e-05      0.676
# done in 0.015 seconds
# Expected: 0.016 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 254          |
# | EpRewMean               | 254          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 221          |
# | TimeElapsed             | 8.17         |
# | TimestepsSoFar          | 27648        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5829592    |
# | explained_variance_t... | -0.00615     |
# | meankl                  | 0.0056930664 |
# | optimgain               | 0.012318306  |
# | surrgain                | 0.012318306  |
# ------------------------------------------
# ********** Iteration 27 ************
# Optimizing Policy...
# sampling
# done in 0.230 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0293          0
#          1     0.0246     0.0204
#          2    0.00327     0.0471
#          3    0.00302      0.072
#          4    0.00162      0.394
#          5   0.000915      0.574
#          6     0.0183      0.736
#          7   0.000122      0.784
#          8   0.000226      0.972
#          9   0.000268       0.98
#         10   0.000174        1.1
# done in 0.013 seconds
# Expected: 0.028 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 264         |
# | EpRewMean               | 264         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 224         |
# | TimeElapsed             | 8.44        |
# | TimestepsSoFar          | 28672       |
# | entloss                 | 0.0         |
# | entropy                 | 0.58639187  |
# | explained_variance_t... | -0.00315    |
# | meankl                  | 0.005130499 |
# | optimgain               | 0.013882805 |
# | surrgain                | 0.013882805 |
# -----------------------------------------
# ********** Iteration 28 ************
# Optimizing Policy...
# sampling
# done in 0.312 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0563          0
#          1     0.0538     0.0351
#          2     0.0173     0.0864
#          3    0.00963      0.598
#          4   0.000916      0.648
#          5   0.000712      0.799
#          6     0.0118      0.849
#          7   0.000116      0.881
#          8   0.000258      0.981
#          9   7.83e-05      0.986
#         10   7.14e-05       1.06
# done in 0.025 seconds
# Expected: 0.043 Actual: 0.018
# Stepsize OK!
# vf
# done in 0.027 seconds
# -----------------------------------------
# | EpLenMean               | 271         |
# | EpRewMean               | 271         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 226         |
# | TimeElapsed             | 8.83        |
# | TimestepsSoFar          | 29696       |
# | entloss                 | 0.0         |
# | entropy                 | 0.57985866  |
# | explained_variance_t... | -0.00611    |
# | meankl                  | 0.004371935 |
# | optimgain               | 0.018354265 |
# | surrgain                | 0.018354265 |
# -----------------------------------------
# ********** Iteration 29 ************
# Optimizing Policy...
# sampling
# done in 0.295 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0791          0
#          1     0.0807      0.056
#          2    0.00728     0.0967
#          3    0.00601      0.126
#          4    0.00713      0.409
#          5   0.000904      0.736
#          6    0.00585       1.21
#          7   0.000186       1.22
#          8   3.22e-05       1.39
#          9   0.000196        1.4
#         10    3.9e-05       1.44
# done in 0.015 seconds
# Expected: 0.042 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 281         |
# | EpRewMean               | 281         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 228         |
# | TimeElapsed             | 9.17        |
# | TimestepsSoFar          | 30720       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5757092   |
# | explained_variance_t... | 0.0083      |
# | meankl                  | 0.006339607 |
# | optimgain               | 0.025027309 |
# | surrgain                | 0.025027309 |
# -----------------------------------------
# ********** Iteration 30 ************
# Optimizing Policy...
# sampling
# done in 0.252 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0609          0
#          1     0.0223     0.0499
#          2    0.00281     0.0592
#          3    0.00904      0.256
#          4    0.00083      0.439
#          5   0.000719      0.517
#          6   7.63e-05      0.662
#          7   0.000294      0.663
#          8   0.000367      0.768
#          9   3.35e-05      0.776
#         10   2.28e-06      0.875
# done in 0.015 seconds
# Expected: 0.030 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 290         |
# | EpRewMean               | 290         |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 232         |
# | TimeElapsed             | 9.47        |
# | TimestepsSoFar          | 31744       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5692489   |
# | explained_variance_t... | 0.00544     |
# | meankl                  | 0.003141405 |
# | optimgain               | 0.01360793  |
# | surrgain                | 0.01360793  |
# -----------------------------------------
# ********** Iteration 31 ************
# Optimizing Policy...
# sampling
# done in 0.243 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0493          0
#          1    0.00557     0.0145
#          2    0.00187     0.0352
#          3   0.000482     0.0947
#          4    0.00122        0.2
#          5   1.78e-05      0.265
#          6    0.00133       0.27
#          7    7.4e-06      0.329
#          8   2.18e-05      0.372
#          9   2.16e-06      0.374
#         10    0.00011      0.389
# done in 0.017 seconds
# Expected: 0.016 Actual: 0.011
# Stepsize OK!
# vf
# done in 0.021 seconds
# -----------------------------------------
# | EpLenMean               | 307         |
# | EpRewMean               | 307         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 235         |
# | TimeElapsed             | 9.77        |
# | TimestepsSoFar          | 32768       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5750992   |
# | explained_variance_t... | -0.000778   |
# | meankl                  | 0.005651271 |
# | optimgain               | 0.011153496 |
# | surrgain                | 0.011153496 |
# -----------------------------------------
# ********** Iteration 32 ************
# Optimizing Policy...
# sampling
# done in 0.251 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0281          0
#          1    0.00725     0.0132
#          2   8.03e-05     0.0308
#          3   6.31e-05     0.0523
#          4    0.00024     0.0896
#          5   1.25e-05      0.191
#          6   0.000141      0.193
#          7   1.72e-06      0.245
#          8   7.83e-06      0.245
#          9   5.59e-07       0.26
#         10   6.56e-05      0.266
# done in 0.014 seconds
# Expected: 0.010 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 325          |
# | EpRewMean               | 325          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 237          |
# | TimeElapsed             | 10.1         |
# | TimestepsSoFar          | 33792        |
# | entloss                 | 0.0          |
# | entropy                 | 0.59843516   |
# | explained_variance_t... | 0.000946     |
# | meankl                  | 0.0112473285 |
# | optimgain               | 0.01197963   |
# | surrgain                | 0.01197963   |
# ------------------------------------------
# ********** Iteration 33 ************
# Optimizing Policy...
# sampling
# done in 0.245 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.014          0
#          1    0.00948      0.017
#          2    0.00043     0.0294
#          3   0.000282      0.102
#          4   0.000176      0.159
#          5   4.55e-05      0.197
#          6   0.000507        0.2
#          7   1.46e-05      0.408
#          8   0.000146      0.416
#          9   1.47e-06       0.47
#         10   0.000205      0.475
# done in 0.014 seconds
# Expected: 0.013 Actual: 0.013
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 331         |
# | EpRewMean               | 331         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 239         |
# | TimeElapsed             | 10.4        |
# | TimestepsSoFar          | 34816       |
# | entloss                 | 0.0         |
# | entropy                 | 0.6002346   |
# | explained_variance_t... | 0.00159     |
# | meankl                  | 0.008333556 |
# | optimgain               | 0.013020519 |
# | surrgain                | 0.013020519 |
# -----------------------------------------
# ********** Iteration 34 ************
# Optimizing Policy...
# sampling
# done in 0.240 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0572          0
#          1     0.0128      0.019
#          2    0.00105     0.0341
#          3    0.00421      0.212
#          4    0.00105      0.365
#          5    0.00029      0.575
#          6   0.000412      0.767
#          7    0.00013      0.769
#          8    0.00194      0.825
#          9   2.68e-05      0.885
#         10   1.33e-05      0.959
# done in 0.016 seconds
# Expected: 0.024 Actual: 0.019
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 341          |
# | EpRewMean               | 341          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 242          |
# | TimeElapsed             | 10.7         |
# | TimestepsSoFar          | 35840        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5654339    |
# | explained_variance_t... | -0.00181     |
# | meankl                  | 0.0070039704 |
# | optimgain               | 0.01895542   |
# | surrgain                | 0.01895542   |
# ------------------------------------------
# ********** Iteration 35 ************
# Optimizing Policy...
# sampling
# done in 0.240 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0294          0
#          1     0.0121      0.016
#          2    0.00116     0.0351
#          3    0.00235     0.0844
#          4   0.000225      0.312
#          5     0.0002      0.345
#          6     0.0135      0.416
#          7   6.83e-05      0.605
#          8    0.00024      0.716
#          9   5.76e-06      0.724
#         10    0.00131      0.741
# done in 0.019 seconds
# Expected: 0.020 Actual: 0.013
# Stepsize OK!
# vf
# done in 0.023 seconds
# -----------------------------------------
# | EpLenMean               | 352         |
# | EpRewMean               | 352         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 244         |
# | TimeElapsed             | 11          |
# | TimestepsSoFar          | 36864       |
# | entloss                 | 0.0         |
# | entropy                 | 0.55519855  |
# | explained_variance_t... | 0.00223     |
# | meankl                  | 0.008932352 |
# | optimgain               | 0.013034284 |
# | surrgain                | 0.013034284 |
# -----------------------------------------
# ********** Iteration 36 ************
# Optimizing Policy...
# sampling
# done in 0.247 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0108          0
#          1    0.00125    0.00633
#          2   0.000282     0.0258
#          3    0.00144     0.0806
#          4   6.88e-05      0.133
#          5   0.000292      0.298
#          6    2.3e-05        0.3
#          7   5.84e-06      0.417
#          8   4.73e-06       0.44
#          9   3.49e-06      0.441
#         10   1.15e-05      0.442
# done in 0.014 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 368         |
# | EpRewMean               | 368         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 246         |
# | TimeElapsed             | 11.2        |
# | TimestepsSoFar          | 37888       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5627837   |
# | explained_variance_t... | 0.00348     |
# | meankl                  | 0.008483471 |
# | optimgain               | 0.010475407 |
# | surrgain                | 0.010475407 |
# -----------------------------------------
# ********** Iteration 37 ************
# Optimizing Policy...
# sampling
# done in 0.251 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0493          0
#          1    0.00561     0.0648
#          2      0.106      0.154
#          3      0.029      0.381
#          4    0.00033      0.546
#          5   0.000144      0.858
#          6    0.00307          1
#          7   0.000215       1.02
#          8   0.000106       1.11
#          9   0.000135       1.11
#         10   0.000128       1.17
# done in 0.013 seconds
# Expected: 0.036 Actual: 0.022
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 392         |
# | EpRewMean               | 392         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 249         |
# | TimeElapsed             | 11.5        |
# | TimestepsSoFar          | 38912       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5561597   |
# | explained_variance_t... | 0.000374    |
# | meankl                  | 0.007816014 |
# | optimgain               | 0.021615122 |
# | surrgain                | 0.021615122 |
# -----------------------------------------
# ********** Iteration 38 ************
# Optimizing Policy...
# sampling
# done in 0.248 seconds
# computegrad
# done in 0.005 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0521          0
#          1     0.0448     0.0224
#          2    0.00235     0.0613
#          3   0.000429     0.0702
#          4   0.000175      0.265
#          5   0.000137      0.317
#          6   0.000339      0.319
#          7   2.57e-05       0.47
#          8   0.000878      0.538
#          9   4.74e-06      0.604
#         10   3.28e-05      0.605
# done in 0.014 seconds
# Expected: 0.020 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 397         |
# | EpRewMean               | 397         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 251         |
# | TimeElapsed             | 11.8        |
# | TimestepsSoFar          | 39936       |
# | entloss                 | 0.0         |
# | entropy                 | 0.57262325  |
# | explained_variance_t... | -0.00324    |
# | meankl                  | 0.004971208 |
# | optimgain               | 0.012239402 |
# | surrgain                | 0.012239402 |
# -----------------------------------------
# ********** Iteration 39 ************
# Optimizing Policy...
# sampling
# done in 0.242 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00389          0
#          1     0.0025     0.0188
#          2     0.0128     0.0477
#          3    0.00776        0.1
#          4    0.00107      0.333
#          5   0.000718      0.433
#          6   0.000205      0.551
#          7    0.00206      0.663
#          8   4.83e-05       0.67
#          9    0.00218      0.721
#         10    1.3e-05      0.798
# done in 0.015 seconds
# Expected: 0.021 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.022 seconds
# ------------------------------------------
# | EpLenMean               | 402          |
# | EpRewMean               | 402          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 253          |
# | TimeElapsed             | 12.1         |
# | TimestepsSoFar          | 40960        |
# | entloss                 | 0.0          |
# | entropy                 | 0.552276     |
# | explained_variance_t... | 0.0438       |
# | meankl                  | 0.0042610965 |
# | optimgain               | 0.012369629  |
# | surrgain                | 0.012369629  |
# ------------------------------------------
# ********** Iteration 40 ************
# Optimizing Policy...
# sampling
# done in 0.238 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0615          0
#          1      0.024     0.0256
#          2     0.0193     0.0477
#          3    0.00936      0.232
#          4    0.00166      0.308
#          5   0.000826      0.549
#          6   0.000318      0.769
#          7    0.00073      0.771
#          8   0.000357      0.896
#          9   0.000178      0.899
#         10   6.59e-05       1.06
# done in 0.014 seconds
# Expected: 0.035 Actual: 0.025
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 413         |
# | EpRewMean               | 413         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 256         |
# | TimeElapsed             | 12.4        |
# | TimestepsSoFar          | 41984       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5718972   |
# | explained_variance_t... | 0.241       |
# | meankl                  | 0.008718029 |
# | optimgain               | 0.025429813 |
# | surrgain                | 0.025429813 |
# -----------------------------------------
# ********** Iteration 41 ************
# Optimizing Policy...
# sampling
# done in 0.249 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00531          0
#          1    0.00397     0.0102
#          2    0.00188     0.0156
#          3    0.00365      0.096
#          4    0.00182      0.216
#          5    0.00131      0.425
#          6   0.000574      0.776
#          7    0.00012      0.778
#          8   7.98e-05      0.907
#          9   0.000158      0.909
#         10   2.11e-05      0.957
# done in 0.016 seconds
# Expected: 0.022 Actual: 0.015
# violated KL constraint. shrinking step.
# Expected: 0.022 Actual: 0.009
# Stepsize OK!
# vf
# done in 0.019 seconds
# ------------------------------------------
# | EpLenMean               | 413          |
# | EpRewMean               | 413          |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 259          |
# | TimeElapsed             | 12.7         |
# | TimestepsSoFar          | 43008        |
# | entloss                 | 0.0          |
# | entropy                 | 0.56985235   |
# | explained_variance_t... | 0.229        |
# | meankl                  | 0.0038825187 |
# | optimgain               | 0.008587413  |
# | surrgain                | 0.008587413  |
# ------------------------------------------
# ********** Iteration 42 ************
# Optimizing Policy...
# sampling
# done in 0.246 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0441          0
#          1    0.00471     0.0207
#          2    0.00749     0.0276
#          3    0.00511      0.112
#          4    0.00186      0.195
#          5    0.00113      0.531
#          6   0.000898      0.898
#          7    0.00954      0.955
#          8   0.000213          1
#          9    0.00157       1.01
#         10   3.94e-05        1.2
# done in 0.014 seconds
# Expected: 0.029 Actual: 0.011
# Stepsize OK!
# vf
# done in 0.021 seconds
# ------------------------------------------
# | EpLenMean               | 409          |
# | EpRewMean               | 409          |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 261          |
# | TimeElapsed             | 13           |
# | TimestepsSoFar          | 44032        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5763185    |
# | explained_variance_t... | 0.562        |
# | meankl                  | 0.0051414296 |
# | optimgain               | 0.011155359  |
# | surrgain                | 0.011155359  |
# ------------------------------------------
# ********** Iteration 43 ************
# Optimizing Policy...
# sampling
# done in 0.278 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0258          0
#          1    0.00424    0.00764
#          2   0.000664     0.0159
#          3    0.00126     0.0422
#          4   0.000551      0.095
#          5   0.000323       0.18
#          6     0.0209      0.315
#          7   8.02e-05      0.435
#          8   4.71e-05       0.55
#          9   0.000238      0.556
#         10   0.000522      0.588
# done in 0.014 seconds
# Expected: 0.014 Actual: 0.011
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 407         |
# | EpRewMean               | 407         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 264         |
# | TimeElapsed             | 13.3        |
# | TimestepsSoFar          | 45056       |
# | entloss                 | 0.0         |
# | entropy                 | 0.58074075  |
# | explained_variance_t... | 0.441       |
# | meankl                  | 0.007244858 |
# | optimgain               | 0.010859856 |
# | surrgain                | 0.010859856 |
# -----------------------------------------
# ********** Iteration 44 ************
# Optimizing Policy...
# sampling
# done in 0.242 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0       0.15          0
#          1     0.0646     0.0286
#          2     0.0281     0.0716
#          3     0.0194      0.244
#          4    0.00201      0.381
#          5    0.00116      0.512
#          6     0.0552      0.756
#          7   0.000932      0.867
#          8   0.000353       1.29
#          9   0.000135       1.29
#         10   5.64e-05       1.48
# done in 0.014 seconds
# Expected: 0.045 Actual: 0.032
# violated KL constraint. shrinking step.
# Expected: 0.045 Actual: 0.019
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 399         |
# | EpRewMean               | 399         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 267         |
# | TimeElapsed             | 13.6        |
# | TimestepsSoFar          | 46080       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5681427   |
# | explained_variance_t... | 0.116       |
# | meankl                  | 0.002888788 |
# | optimgain               | 0.018787775 |
# | surrgain                | 0.018787775 |
# -----------------------------------------
# ********** Iteration 45 ************
# Optimizing Policy...
# sampling
# done in 0.255 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0       0.13          0
#          1     0.0192     0.0206
#          2    0.00546     0.0405
#          3    0.00525     0.0886
#          4    0.00112      0.196
#          5    0.00037      0.328
#          6    0.00483      0.336
#          7   0.000359        0.5
#          8    0.00215      0.792
#          9   3.34e-05      0.819
#         10   0.000407      0.868
# done in 0.014 seconds
# Expected: 0.027 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.020 seconds
# ------------------------------------------
# | EpLenMean               | 391          |
# | EpRewMean               | 391          |
# | EpThisIter              | 4            |
# | EpisodesSoFar           | 271          |
# | TimeElapsed             | 13.9         |
# | TimestepsSoFar          | 47104        |
# | entloss                 | 0.0          |
# | entropy                 | 0.5793145    |
# | explained_variance_t... | 0.0637       |
# | meankl                  | 0.0046215327 |
# | optimgain               | 0.015151808  |
# | surrgain                | 0.015151808  |
# ------------------------------------------
# ********** Iteration 46 ************
# Optimizing Policy...
# sampling
# done in 0.248 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0813          0
#          1      0.037     0.0233
#          2    0.00656     0.0727
#          3     0.0112      0.113
#          4   0.000868      0.446
#          5   0.000325      0.578
#          6    0.00554      0.718
#          7   0.000106      0.732
#          8   0.000385      0.938
#          9   4.19e-05      0.946
#         10   0.000397      0.982
# done in 0.013 seconds
# Expected: 0.033 Actual: 0.016
# Stepsize OK!
# vf
# done in 0.020 seconds
# -----------------------------------------
# | EpLenMean               | 395         |
# | EpRewMean               | 395         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 274         |
# | TimeElapsed             | 14.2        |
# | TimestepsSoFar          | 48128       |
# | entloss                 | 0.0         |
# | entropy                 | 0.56504655  |
# | explained_variance_t... | 0.0286      |
# | meankl                  | 0.004324589 |
# | optimgain               | 0.016437221 |
# | surrgain                | 0.016437221 |
# -----------------------------------------
# ********** Iteration 47 ************
# Optimizing Policy...
# sampling
# done in 0.240 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0145          0
#          1     0.0133     0.0114
#          2    0.00154     0.0356
#          3   0.000501     0.0903
#          4    0.00276      0.109
#          5   0.000259      0.259
#          6   0.000783       0.35
#          7   0.000158      0.353
#          8   5.58e-05       0.49
#          9   5.55e-05      0.583
#         10   2.43e-05      0.584
# done in 0.017 seconds
# Expected: 0.017 Actual: 0.014
# Stepsize OK!
# vf
# done in 0.019 seconds
# -----------------------------------------
# | EpLenMean               | 389         |
# | EpRewMean               | 389         |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 276         |
# | TimeElapsed             | 14.5        |
# | TimestepsSoFar          | 49152       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5724518   |
# | explained_variance_t... | 0.107       |
# | meankl                  | 0.005687394 |
# | optimgain               | 0.014017645 |
# | surrgain                | 0.014017645 |
# -----------------------------------------
# ********** Iteration 48 ************
# Optimizing Policy...
# sampling
# done in 0.242 seconds
# computegrad
# done in 0.004 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0595          0
#          1     0.0438     0.0255
#          2    0.00437     0.0508
#          3    0.00223      0.157
#          4    0.00836      0.254
#          5    0.00113      0.397
#          6   0.000449      0.523
#          7    0.00201      0.526
#          8   0.000133      0.636
#          9   0.000609      0.767
#         10   7.68e-05      0.778
# done in 0.013 seconds
# Expected: 0.028 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.018 seconds
# -----------------------------------------
# | EpLenMean               | 378         |
# | EpRewMean               | 378         |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 279         |
# | TimeElapsed             | 14.8        |
# | TimestepsSoFar          | 50176       |
# | entloss                 | 0.0         |
# | entropy                 | 0.5513066   |
# | explained_variance_t... | 0.0721      |
# | meankl                  | 0.006734716 |
# | optimgain               | 0.020361196 |
# | surrgain                | 0.020361196 |
# -----------------------------------------

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_EPISODES, "TRPO CartPole-v1")
plt.show()
