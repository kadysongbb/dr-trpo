# %%
import gym
import pybullet
import pybullet_envs
from gym import wrappers
from datetime import datetime

# DR TRPO related files
from train_helper import *
from value import NNValueFunction
from utils import Logger
from dr_policy import DRPolicyKL, DRPolicyWass

# %%
#########################     Discrete State Space - KL DR Policy     ######################### 
# 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

env_name = 'Taxi-v3'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyKL(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 5000
batch_eps = 100
logger = Logger(logname=env_name + '_DR-KL_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()

# %%
####################   Discrete State Space - Wasserstein DR Policy     ##################### 
#'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

env_name = 'Taxi-v3'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyWass(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.8
lam = 1
total_eps = 5000
batch_eps = 100
logger = Logger(logname=env_name + '_DR-Wass_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 100, Mean Return = -768.4, Mean Discounted Return = -20.3 *****
# ExplainedVarNew: -1.21e-08
# ExplainedVarOld: -0.000306
# ValFuncLoss: 66.3
#
#
# ***** Episode 200, Mean Return = -694.8, Mean Discounted Return = -17.7 *****
# ExplainedVarNew: -0.00397
# ExplainedVarOld: -1.17e-08
# ValFuncLoss: 57.7
#
#
# ***** Episode 300, Mean Return = -675.2, Mean Discounted Return = -17.8 *****
# ExplainedVarNew: -0.00417
# ExplainedVarOld: -0.00485
# ValFuncLoss: 58.8
#
#
# ***** Episode 400, Mean Return = -589.5, Mean Discounted Return = -15.7 *****
# ExplainedVarNew: -0.00311
# ExplainedVarOld: -0.00334
# ValFuncLoss: 64.9
#
#
# ***** Episode 500, Mean Return = -518.5, Mean Discounted Return = -15.7 *****
# ExplainedVarNew: -0.0013
# ExplainedVarOld: -0.00119
# ValFuncLoss: 59.8
#
#
# ***** Episode 600, Mean Return = -441.9, Mean Discounted Return = -13.5 *****
# ExplainedVarNew: -0.00471
# ExplainedVarOld: -0.0067
# ValFuncLoss: 59.9
#
#
# ***** Episode 700, Mean Return = -417.4, Mean Discounted Return = -13.5 *****
# ExplainedVarNew: -0.00695
# ExplainedVarOld: -0.00367
# ValFuncLoss: 56.5
#
#
# ***** Episode 800, Mean Return = -355.3, Mean Discounted Return = -11.9 *****
# ExplainedVarNew: -0.00571
# ExplainedVarOld: -0.0118
# ValFuncLoss: 53.2
#
#
# ***** Episode 900, Mean Return = -319.9, Mean Discounted Return = -10.1 *****
# ExplainedVarNew: -0.00263
# ExplainedVarOld: -0.00324
# ValFuncLoss: 49.1
#
#
# ***** Episode 1000, Mean Return = -334.2, Mean Discounted Return = -9.5 *****
# ExplainedVarNew: -0.00548
# ExplainedVarOld: -0.0055
# ValFuncLoss: 32.7
#
#
# ***** Episode 1100, Mean Return = -272.3, Mean Discounted Return = -8.0 *****
# ExplainedVarNew: -0.00206
# ExplainedVarOld: -0.00415
# ValFuncLoss: 32.5
#
#
# ***** Episode 1200, Mean Return = -233.8, Mean Discounted Return = -7.2 *****
# ExplainedVarNew: -0.00439
# ExplainedVarOld: -0.00783
# ValFuncLoss: 28.5
#
#
# ***** Episode 1300, Mean Return = -215.0, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.0106
# ExplainedVarOld: -0.00524
# ValFuncLoss: 23.7
#
#
# ***** Episode 1400, Mean Return = -165.1, Mean Discounted Return = -6.0 *****
# ExplainedVarNew: -0.00643
# ExplainedVarOld: -0.011
# ValFuncLoss: 21.7
#
#
# ***** Episode 1500, Mean Return = -164.3, Mean Discounted Return = -6.2 *****
# ExplainedVarNew: -0.013
# ExplainedVarOld: -0.00874
# ValFuncLoss: 15.6
#
#
# ***** Episode 1600, Mean Return = -147.9, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0308
# ExplainedVarOld: -0.0134
# ValFuncLoss: 13.7
#
#
# ***** Episode 1700, Mean Return = -135.2, Mean Discounted Return = -5.2 *****
# ExplainedVarNew: -0.024
# ExplainedVarOld: -0.039
# ValFuncLoss: 14.1
#
#
# ***** Episode 1800, Mean Return = -143.8, Mean Discounted Return = -4.9 *****
# ExplainedVarNew: -0.162
# ExplainedVarOld: -0.0143
# ValFuncLoss: 51.9
#
#
# ***** Episode 1900, Mean Return = -109.5, Mean Discounted Return = -5.3 *****
# ExplainedVarNew: -0.158
# ExplainedVarOld: -0.0387
# ValFuncLoss: 20.2
#
#
# ***** Episode 2000, Mean Return = -100.3, Mean Discounted Return = -4.9 *****
# ExplainedVarNew: -0.073
# ExplainedVarOld: -0.138
# ValFuncLoss: 12.4
#
#
# ***** Episode 2100, Mean Return = -124.8, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0297
# ExplainedVarOld: -0.0356
# ValFuncLoss: 16.3
#
#
# ***** Episode 2200, Mean Return = -83.7, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0333
# ExplainedVarOld: -0.243
# ValFuncLoss: 28
#
#
# ***** Episode 2300, Mean Return = -142.9, Mean Discounted Return = -4.9 *****
# ExplainedVarNew: -0.0399
# ExplainedVarOld: -0.0254
# ValFuncLoss: 16.1
#
#
# ***** Episode 2400, Mean Return = -112.3, Mean Discounted Return = -4.5 *****
# ExplainedVarNew: -0.179
# ExplainedVarOld: -0.176
# ValFuncLoss: 9.14
#
#
# ***** Episode 2500, Mean Return = -120.1, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0825
# ExplainedVarOld: -0.0846
# ValFuncLoss: 18.1
#
#
# ***** Episode 2600, Mean Return = -101.5, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0769
# ExplainedVarOld: -0.0688
# ValFuncLoss: 22.9
#
#
# ***** Episode 2700, Mean Return = -137.7, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0227
# ExplainedVarOld: -0.0209
# ValFuncLoss: 62.9
#
#
# ***** Episode 2800, Mean Return = -86.9, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.56
# ExplainedVarOld: -0.129
# ValFuncLoss: 17.9
#
#
# ***** Episode 2900, Mean Return = -95.7, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.0968
# ExplainedVarOld: -0.948
# ValFuncLoss: 9.96
#
#
# ***** Episode 3000, Mean Return = -61.7, Mean Discounted Return = -4.2 *****
# ExplainedVarNew: -0.131
# ExplainedVarOld: -0.137
# ValFuncLoss: 17.3
#
#
# ***** Episode 3100, Mean Return = -51.7, Mean Discounted Return = -4.0 *****
# ExplainedVarNew: -0.165
# ExplainedVarOld: -0.16
# ValFuncLoss: 21.2
#
#
# ***** Episode 3200, Mean Return = -49.5, Mean Discounted Return = -3.8 *****
# ExplainedVarNew: -0.136
# ExplainedVarOld: -0.135
# ValFuncLoss: 21
#
#
# ***** Episode 3300, Mean Return = -63.5, Mean Discounted Return = -4.1 *****
# ExplainedVarNew: -0.111
# ExplainedVarOld: -0.114
# ValFuncLoss: 16.3
#
#
# ***** Episode 3400, Mean Return = -56.5, Mean Discounted Return = -3.8 *****
# ExplainedVarNew: -0.143
# ExplainedVarOld: -0.134
# ValFuncLoss: 18.7
#
#
# ***** Episode 3500, Mean Return = -62.3, Mean Discounted Return = -4.0 *****
# ExplainedVarNew: -0.152
# ExplainedVarOld: -0.154
# ValFuncLoss: 16.9
#
#
# ***** Episode 3600, Mean Return = -63.7, Mean Discounted Return = -3.8 *****
# ExplainedVarNew: -0.114
# ExplainedVarOld: -0.122
# ValFuncLoss: 15.8
#
#
# ***** Episode 3700, Mean Return = -42.1, Mean Discounted Return = -3.6 *****
# ExplainedVarNew: -0.124
# ExplainedVarOld: -0.122
# ValFuncLoss: 23.1
#
#
# ***** Episode 3800, Mean Return = -33.7, Mean Discounted Return = -3.7 *****
# ExplainedVarNew: -0.116
# ExplainedVarOld: -0.115
# ValFuncLoss: 27.4
#
#
# ***** Episode 3900, Mean Return = -51.3, Mean Discounted Return = -3.7 *****
# ExplainedVarNew: -0.131
# ExplainedVarOld: -0.127
# ValFuncLoss: 20.4
#
#
# ***** Episode 4000, Mean Return = -58.0, Mean Discounted Return = -3.6 *****
# ExplainedVarNew: -0.124
# ExplainedVarOld: -0.123
# ValFuncLoss: 17.9
#
#
# ***** Episode 4100, Mean Return = -59.7, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.114
# ExplainedVarOld: -0.113
# ValFuncLoss: 17.2
#
#
# ***** Episode 4200, Mean Return = -49.8, Mean Discounted Return = -3.7 *****
# ExplainedVarNew: -0.123
# ExplainedVarOld: -0.118
# ValFuncLoss: 20.1
#
#
# ***** Episode 4300, Mean Return = -61.3, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0949
# ExplainedVarOld: -0.0996
# ValFuncLoss: 16.1
#
#
# ***** Episode 4400, Mean Return = -44.3, Mean Discounted Return = -3.3 *****
# ExplainedVarNew: -0.117
# ExplainedVarOld: -0.118
# ValFuncLoss: 22.2
#
#
# ***** Episode 4500, Mean Return = -55.5, Mean Discounted Return = -3.6 *****
# ExplainedVarNew: -0.0901
# ExplainedVarOld: -0.0873
# ValFuncLoss: 17.8
#
#
# ***** Episode 4600, Mean Return = -44.2, Mean Discounted Return = -3.7 *****
# ExplainedVarNew: -0.099
# ExplainedVarOld: -0.0983
# ValFuncLoss: 21.9
#
#
# ***** Episode 4700, Mean Return = -34.3, Mean Discounted Return = -3.5 *****
# ExplainedVarNew: -0.123
# ExplainedVarOld: -0.125
# ValFuncLoss: 27.6
#
#
# ***** Episode 4800, Mean Return = -62.5, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0742
# ExplainedVarOld: -0.0773
# ValFuncLoss: 15.8
#
#
# ***** Episode 4900, Mean Return = -52.2, Mean Discounted Return = -3.6 *****
# ExplainedVarNew: -0.0927
# ExplainedVarOld: -0.0907
# ValFuncLoss: 18.9
#
#
# ***** Episode 5000, Mean Return = -33.0, Mean Discounted Return = -3.6 *****
# ExplainedVarNew: -0.108
# ExplainedVarOld: -0.104
# ValFuncLoss: 27.5
