# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines.bench import Monitor
from stable_baselines.common.policies import MlpPolicy
from stable_baselines import results_plotter
from stable_baselines import *

# %%
import gym
import numpy as np

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make('Acrobot-v1')
env = Monitor(env, log_dir, allow_early_resets=True)

model = TRPO(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 150000
model.learn(total_timesteps=time_steps)
# Out:
# ********** Iteration 0 ************
# Optimizing Policy...
# sampling
# done in 0.491 seconds
# computegrad
# done in 0.113 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00691          0
#          1    0.00178      0.063
#          2     0.0022      0.162
#          3   0.000699      0.242
#          4   8.57e-05      0.436
#          5   0.000196      0.473
#          6   6.18e-05      0.488
#          7   0.000449      0.522
#          8   1.72e-05      0.596
#          9   1.93e-06      0.677
#         10   4.05e-06      0.682
# done in 0.159 seconds
# Expected: 0.020 Actual: 0.020
# Stepsize OK!
# vf
# done in 0.067 seconds
# -----------------------------------------
# | EpLenMean               | 500         |
# | EpRewMean               | -500        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 2           |
# | TimeElapsed             | 0.905       |
# | TimestepsSoFar          | 1024        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0907922   |
# | explained_variance_t... | 0.00451     |
# | meankl                  | 0.008040317 |
# | optimgain               | 0.019653894 |
# | surrgain                | 0.019653894 |
# -----------------------------------------
# ********** Iteration 1 ************
# Optimizing Policy...
# sampling
# done in 0.441 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00707          0
#          1    0.00132     0.0499
#          2    0.00207      0.141
#          3   0.000862      0.193
#          4    0.00296      0.329
#          5   0.000208      0.445
#          6   0.000436      0.472
#          7    0.00013      0.521
#          8   0.000118      0.612
#          9   2.43e-05      0.749
#         10   1.44e-05      0.795
# done in 0.015 seconds
# Expected: 0.020 Actual: 0.019
# Stepsize OK!
# vf
# done in 0.027 seconds
# -----------------------------------------
# | EpLenMean               | 500         |
# | EpRewMean               | -500        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 4           |
# | TimeElapsed             | 1.4         |
# | TimestepsSoFar          | 2048        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0780151   |
# | explained_variance_t... | 0.00624     |
# | meankl                  | 0.008098278 |
# | optimgain               | 0.019374311 |
# | surrgain                | 0.019374311 |
# -----------------------------------------
# ********** Iteration 2 ************
# Optimizing Policy...
# sampling
# done in 0.447 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00707          0
#          1    0.00444     0.0382
#          2    0.00514      0.145
#          3    0.00299       0.19
#          4    0.00133      0.258
#          5    0.00111      0.352
#          6     0.0012      0.428
#          7   0.000262      0.513
#          8   0.000627       0.62
#          9   0.000282      0.736
#         10    0.00131      0.833
# done in 0.014 seconds
# Expected: 0.023 Actual: 0.024
# Stepsize OK!
# vf
# done in 0.033 seconds
# -----------------------------------------
# | EpLenMean               | 500         |
# | EpRewMean               | -500        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 6           |
# | TimeElapsed             | 1.91        |
# | TimestepsSoFar          | 3072        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0745456   |
# | explained_variance_t... | -0.0366     |
# | meankl                  | 0.010912392 |
# | optimgain               | 0.024129093 |
# | surrgain                | 0.024129093 |
# -----------------------------------------
# ********** Iteration 3 ************
# Optimizing Policy...
# sampling
# done in 0.454 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0135          0
#          1      0.012      0.052
#          2    0.00182      0.126
#          3    0.00174      0.168
#          4    0.00301      0.228
#          5     0.0031      0.339
#          6    0.00117      0.506
#          7   0.000614      0.663
#          8   0.000754      0.865
#          9    0.00139          1
#         10   0.000488       1.03
# done in 0.014 seconds
# Expected: 0.027 Actual: 0.024
# Stepsize OK!
# vf
# done in 0.025 seconds
# ------------------------------------------
# | EpLenMean               | 500          |
# | EpRewMean               | -500         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 8            |
# | TimeElapsed             | 2.41         |
# | TimestepsSoFar          | 4096         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0551207    |
# | explained_variance_t... | 0.017        |
# | meankl                  | 0.0061319936 |
# | optimgain               | 0.023606747  |
# | surrgain                | 0.023606747  |
# ------------------------------------------
# ********** Iteration 4 ************
# Optimizing Policy...
# sampling
# done in 0.454 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0297          0
#          1     0.0185     0.0534
#          2     0.0359      0.139
#          3    0.00712      0.339
#          4     0.0028      0.451
#          5    0.00306      0.526
#          6    0.00329      0.688
#          7    0.00123      0.937
#          8    0.00416       1.13
#          9    0.00671       1.19
#         10   0.000399       1.39
# done in 0.016 seconds
# Expected: 0.041 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.026 seconds
# -----------------------------------------
# | EpLenMean               | 500         |
# | EpRewMean               | -500        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 10          |
# | TimeElapsed             | 2.92        |
# | TimestepsSoFar          | 5120        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0651684   |
# | explained_variance_t... | 0.0586      |
# | meankl                  | 0.010073622 |
# | optimgain               | 0.040551152 |
# | surrgain                | 0.040551152 |
# -----------------------------------------
# ********** Iteration 5 ************
# Optimizing Policy...
# sampling
# done in 0.442 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0203          0
#          1      0.015      0.056
#          2     0.0201      0.165
#          3    0.00861       0.27
#          4    0.00611      0.455
#          5    0.00304      0.707
#          6     0.0041      0.826
#          7     0.0026       1.07
#          8    0.00271       1.31
#          9    0.00199       1.53
#         10    0.00298       1.56
# done in 0.014 seconds
# Expected: 0.042 Actual: 0.034
# Stepsize OK!
# vf
# done in 0.024 seconds
# ------------------------------------------
# | EpLenMean               | 468          |
# | EpRewMean               | -468         |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 13           |
# | TimeElapsed             | 3.42         |
# | TimestepsSoFar          | 6144         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0322237    |
# | explained_variance_t... | 0.111        |
# | meankl                  | 0.0066867983 |
# | optimgain               | 0.033745468  |
# | surrgain                | 0.033745468  |
# ------------------------------------------
# ********** Iteration 6 ************
# Optimizing Policy...
# sampling
# done in 0.440 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00384          0
#          1    0.00499     0.0329
#          2    0.00583      0.202
#          3      0.011      0.292
#          4    0.00617      0.434
#          5    0.00255      0.723
#          6    0.00244       1.08
#          7   0.000973       1.34
#          8    0.00183       1.51
#          9   0.000986       1.62
#         10    0.00211       1.67
# done in 0.014 seconds
# Expected: 0.034 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.025 seconds
# -----------------------------------------
# | EpLenMean               | 462         |
# | EpRewMean               | -461        |
# | EpThisIter              | 2           |
# | EpisodesSoFar           | 15          |
# | TimeElapsed             | 3.91        |
# | TimestepsSoFar          | 7168        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0603664   |
# | explained_variance_t... | 0.109       |
# | meankl                  | 0.008295592 |
# | optimgain               | 0.030082192 |
# | surrgain                | 0.030082192 |
# -----------------------------------------
# ********** Iteration 7 ************
# Optimizing Policy...
# sampling
# done in 0.440 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0209          0
#          1     0.0119     0.0596
#          2    0.00844      0.126
#          3    0.00654      0.228
#          4    0.00949      0.331
#          5    0.00203        0.5
#          6     0.0039      0.586
#          7    0.00263      0.788
#          8    0.00146       1.07
#          9   0.000681       1.32
#         10   0.000416       1.46
# done in 0.016 seconds
# Expected: 0.037 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.025 seconds
# ------------------------------------------
# | EpLenMean               | 455          |
# | EpRewMean               | -455         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 17           |
# | TimeElapsed             | 4.4          |
# | TimestepsSoFar          | 8192         |
# | entloss                 | 0.0          |
# | entropy                 | 1.0550234    |
# | explained_variance_t... | 0.163        |
# | meankl                  | 0.0062806653 |
# | optimgain               | 0.029802615  |
# | surrgain                | 0.029802615  |
# ------------------------------------------
# ********** Iteration 8 ************
# Optimizing Policy...
# sampling
# done in 0.440 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.016          0
#          1     0.0058     0.0554
#          2     0.0107      0.188
#          3    0.00321      0.292
#          4    0.00457      0.338
#          5    0.00262      0.553
#          6     0.0031      0.623
#          7    0.00153       0.82
#          8   0.000628       1.21
#          9   0.000386       1.41
#         10   5.37e-05       1.53
# done in 0.014 seconds
# Expected: 0.035 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 458         |
# | EpRewMean               | -458        |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 20          |
# | TimeElapsed             | 4.89        |
# | TimestepsSoFar          | 9216        |
# | entloss                 | 0.0         |
# | entropy                 | 1.0512468   |
# | explained_variance_t... | 0.179       |
# | meankl                  | 0.008071747 |
# | optimgain               | 0.033093162 |
# | surrgain                | 0.033093162 |
# -----------------------------------------
# ********** Iteration 9 ************
# Optimizing Policy...
# sampling
# done in 0.457 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0739          0
#          1    0.00632     0.0833
#          2     0.0141      0.141
#          3     0.0095      0.396
#          4    0.00289      0.489
#          5    0.00424      0.578
#          6    0.00463      0.691
#          7    0.00211      0.973
#          8    0.00138        1.1
#          9   0.000518       1.34
#         10   0.000339       1.52
# done in 0.016 seconds
# Expected: 0.042 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.030 seconds
# ------------------------------------------
# | EpLenMean               | 443          |
# | EpRewMean               | -442         |
# | EpThisIter              | 3            |
# | EpisodesSoFar           | 23           |
# | TimeElapsed             | 5.41         |
# | TimestepsSoFar          | 10240        |
# | entloss                 | 0.0          |
# | entropy                 | 1.030371     |
# | explained_variance_t... | 0.315        |
# | meankl                  | 0.0054997606 |
# | optimgain               | 0.033246316  |
# | surrgain                | 0.033246316  |
# ------------------------------------------
# ********** Iteration 10 ************
# Optimizing Policy...
# sampling
# done in 0.441 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0214          0
#          1    0.00791     0.0336
#          2     0.0156      0.139
#          3     0.0048      0.206
#          4    0.00405      0.331
#          5    0.00198      0.447
#          6    0.00223      0.728
#          7    0.00261        1.1
#          8    0.00179       1.24
#          9     0.0056       1.37
#         10   0.000584       1.42
# done in 0.014 seconds
# Expected: 0.035 Actual: 0.028
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 416         |
# | EpRewMean               | -416        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 27          |
# | TimeElapsed             | 5.9         |
# | TimestepsSoFar          | 11264       |
# | entloss                 | 0.0         |
# | entropy                 | 1.009417    |
# | explained_variance_t... | 0.334       |
# | meankl                  | 0.00726855  |
# | optimgain               | 0.028418653 |
# | surrgain                | 0.028418653 |
# -----------------------------------------
# ********** Iteration 11 ************
# Optimizing Policy...
# sampling
# done in 0.447 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0203          0
#          1     0.0162     0.0583
#          2    0.00653      0.155
#          3    0.00533      0.208
#          4     0.0045      0.241
#          5    0.00477       0.45
#          6    0.00388      0.608
#          7    0.00252       0.86
#          8    0.00104       1.28
#          9   0.000555       1.56
#         10    0.00058       1.67
# done in 0.015 seconds
# Expected: 0.038 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.025 seconds
# -----------------------------------------
# | EpLenMean               | 401         |
# | EpRewMean               | -400        |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 30          |
# | TimeElapsed             | 6.4         |
# | TimestepsSoFar          | 12288       |
# | entloss                 | 0.0         |
# | entropy                 | 1.0079002   |
# | explained_variance_t... | 0.262       |
# | meankl                  | 0.008333482 |
# | optimgain               | 0.032369446 |
# | surrgain                | 0.032369446 |
# -----------------------------------------
# ********** Iteration 12 ************
# Optimizing Policy...
# sampling
# done in 0.442 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0143          0
#          1      0.022      0.066
#          2       0.02      0.149
#          3    0.00767      0.219
#          4    0.00485      0.322
#          5    0.00517      0.466
#          6    0.00179      0.663
#          7    0.00241      0.743
#          8    0.00201       0.91
#          9    0.00259       1.07
#         10    0.00125       1.09
# done in 0.014 seconds
# Expected: 0.035 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 399         |
# | EpRewMean               | -398        |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 33          |
# | TimeElapsed             | 6.89        |
# | TimestepsSoFar          | 13312       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9897717   |
# | explained_variance_t... | 0.291       |
# | meankl                  | 0.008960253 |
# | optimgain               | 0.03238879  |
# | surrgain                | 0.03238879  |
# -----------------------------------------
# ********** Iteration 13 ************
# Optimizing Policy...
# sampling
# done in 0.441 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0547          0
#          1    0.00757     0.0479
#          2    0.00305      0.197
#          3     0.0169      0.258
#          4    0.00572      0.397
#          5    0.00903      0.737
#          6    0.00265      0.981
#          7    0.00454       1.25
#          8   0.000749       1.39
#          9    0.00243       1.54
#         10   0.000952       1.57
# done in 0.015 seconds
# Expected: 0.040 Actual: 0.031
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 385         |
# | EpRewMean               | -384        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 37          |
# | TimeElapsed             | 7.39        |
# | TimestepsSoFar          | 14336       |
# | entloss                 | 0.0         |
# | entropy                 | 0.95697975  |
# | explained_variance_t... | 0.224       |
# | meankl                  | 0.007114931 |
# | optimgain               | 0.031376816 |
# | surrgain                | 0.031376816 |
# -----------------------------------------
# ********** Iteration 14 ************
# Optimizing Policy...
# sampling
# done in 0.436 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0459          0
#          1     0.0188     0.0496
#          2     0.0178      0.125
#          3     0.0196      0.188
#          4    0.00704      0.372
#          5    0.00615      0.482
#          6     0.0105      0.762
#          7    0.00589       1.19
#          8    0.00176        1.5
#          9    0.00242        1.7
#         10    0.00568       1.73
# done in 0.016 seconds
# Expected: 0.047 Actual: 0.040
# Stepsize OK!
# vf
# done in 0.026 seconds
# -----------------------------------------
# | EpLenMean               | 366         |
# | EpRewMean               | -366        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 41          |
# | TimeElapsed             | 7.88        |
# | TimestepsSoFar          | 15360       |
# | entloss                 | 0.0         |
# | entropy                 | 0.96342224  |
# | explained_variance_t... | 0.262       |
# | meankl                  | 0.01123197  |
# | optimgain               | 0.040195853 |
# | surrgain                | 0.040195853 |
# -----------------------------------------
# ********** Iteration 15 ************
# Optimizing Policy...
# sampling
# done in 0.474 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0148          0
#          1     0.0157     0.0418
#          2    0.00839     0.0793
#          3     0.0094      0.143
#          4    0.00593      0.204
#          5    0.00339      0.644
#          6    0.00575      0.796
#          7    0.00172       1.12
#          8    0.00221       1.32
#          9    0.00877       1.36
#         10   0.000878       1.59
# done in 0.016 seconds
# Expected: 0.038 Actual: 0.027
# Stepsize OK!
# vf
# done in 0.027 seconds
# ------------------------------------------
# | EpLenMean               | 334          |
# | EpRewMean               | -333         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 46           |
# | TimeElapsed             | 8.41         |
# | TimestepsSoFar          | 16384        |
# | entloss                 | 0.0          |
# | entropy                 | 0.94814026   |
# | explained_variance_t... | 0.222        |
# | meankl                  | 0.0083379075 |
# | optimgain               | 0.026699731  |
# | surrgain                | 0.026699731  |
# ------------------------------------------
# ********** Iteration 16 ************
# Optimizing Policy...
# sampling
# done in 0.510 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0334          0
#          1     0.0266     0.0474
#          2     0.0215      0.121
#          3     0.0119       0.18
#          4     0.0129       0.29
#          5     0.0052      0.501
#          6     0.0113      0.731
#          7    0.00482       1.14
#          8    0.00286       1.46
#          9     0.0235       1.69
#         10    0.00101       1.79
# done in 0.016 seconds
# Expected: 0.047 Actual: 0.052
# Stepsize OK!
# vf
# done in 0.026 seconds
# ------------------------------------------
# | EpLenMean               | 306          |
# | EpRewMean               | -305         |
# | EpThisIter              | 4            |
# | EpisodesSoFar           | 50           |
# | TimeElapsed             | 8.97         |
# | TimestepsSoFar          | 17408        |
# | entloss                 | 0.0          |
# | entropy                 | 0.94789875   |
# | explained_variance_t... | 0.149        |
# | meankl                  | 0.0087172715 |
# | optimgain               | 0.052039705  |
# | surrgain                | 0.052039705  |
# ------------------------------------------
# ********** Iteration 17 ************
# Optimizing Policy...
# sampling
# done in 0.444 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0322          0
#          1    0.00696     0.0307
#          2     0.0137     0.0565
#          3    0.00907      0.129
#          4     0.0102       0.31
#          5    0.00572      0.654
#          6    0.00245      0.963
#          7    0.00409       1.15
#          8    0.00229        1.3
#          9     0.0146        1.5
#         10     0.0016       1.57
# done in 0.014 seconds
# Expected: 0.039 Actual: 0.027
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 285         |
# | EpRewMean               | -284        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 55          |
# | TimeElapsed             | 9.46        |
# | TimestepsSoFar          | 18432       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9435819   |
# | explained_variance_t... | 0.29        |
# | meankl                  | 0.008869121 |
# | optimgain               | 0.027009225 |
# | surrgain                | 0.027009225 |
# -----------------------------------------
# ********** Iteration 18 ************
# Optimizing Policy...
# sampling
# done in 0.428 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00767          0
#          1     0.0236      0.153
#          2     0.0109       0.22
#          3     0.0118      0.289
#          4    0.00448      0.331
#          5    0.00631      0.435
#          6    0.00195      0.707
#          7    0.00138      0.956
#          8   0.000696       1.06
#          9    0.00101       1.23
#         10    0.00135       1.24
# done in 0.014 seconds
# Expected: 0.035 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 255         |
# | EpRewMean               | -254        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 60          |
# | TimeElapsed             | 9.94        |
# | TimestepsSoFar          | 19456       |
# | entloss                 | 0.0         |
# | entropy                 | 0.950471    |
# | explained_variance_t... | 0.214       |
# | meankl                  | 0.010199116 |
# | optimgain               | 0.031914867 |
# | surrgain                | 0.031914867 |
# -----------------------------------------
# ********** Iteration 19 ************
# Optimizing Policy...
# sampling
# done in 0.426 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.033          0
#          1    0.00485     0.0322
#          2      0.019     0.0647
#          3    0.00608       0.26
#          4    0.00569      0.341
#          5    0.00426      0.686
#          6    0.00348      0.847
#          7    0.00195       1.06
#          8    0.00134       1.18
#          9    0.00397        1.2
#         10   0.000916       1.32
# done in 0.015 seconds
# Expected: 0.036 Actual: 0.026
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 246         |
# | EpRewMean               | -245        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 64          |
# | TimeElapsed             | 10.4        |
# | TimestepsSoFar          | 20480       |
# | entloss                 | 0.0         |
# | entropy                 | 0.92191637  |
# | explained_variance_t... | 0.134       |
# | meankl                  | 0.008543413 |
# | optimgain               | 0.025771946 |
# | surrgain                | 0.025771946 |
# -----------------------------------------
# ********** Iteration 20 ************
# Optimizing Policy...
# sampling
# done in 0.459 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0935          0
#          1     0.0139     0.0294
#          2     0.0191      0.257
#          3    0.00687      0.293
#          4     0.0118      0.402
#          5    0.00684      0.705
#          6    0.00237      0.849
#          7    0.00468       1.15
#          8    0.00311       1.16
#          9    0.00148        1.4
#         10    0.00204       1.63
# done in 0.014 seconds
# Expected: 0.046 Actual: 0.023
# Stepsize OK!
# vf
# done in 0.023 seconds
# -----------------------------------------
# | EpLenMean               | 245         |
# | EpRewMean               | -244        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 68          |
# | TimeElapsed             | 10.9        |
# | TimestepsSoFar          | 21504       |
# | entloss                 | 0.0         |
# | entropy                 | 0.93476474  |
# | explained_variance_t... | 0.312       |
# | meankl                  | 0.007279739 |
# | optimgain               | 0.023107925 |
# | surrgain                | 0.023107925 |
# -----------------------------------------
# ********** Iteration 21 ************
# Optimizing Policy...
# sampling
# done in 0.451 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.018          0
#          1     0.0075     0.0231
#          2     0.0168      0.138
#          3     0.0096      0.244
#          4    0.00917      0.557
#          5     0.0045      0.629
#          6    0.00896      0.756
#          7    0.00168      0.987
#          8    0.00169       1.21
#          9    0.00857       1.25
#         10   0.000828       1.47
# done in 0.015 seconds
# Expected: 0.038 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 234         |
# | EpRewMean               | -233        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 73          |
# | TimeElapsed             | 11.4        |
# | TimestepsSoFar          | 22528       |
# | entloss                 | 0.0         |
# | entropy                 | 0.91299164  |
# | explained_variance_t... | 0.185       |
# | meankl                  | 0.010450574 |
# | optimgain               | 0.02988947  |
# | surrgain                | 0.02988947  |
# -----------------------------------------
# ********** Iteration 22 ************
# Optimizing Policy...
# sampling
# done in 0.438 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0272          0
#          1    0.00584     0.0278
#          2      0.011     0.0604
#          3     0.0112      0.213
#          4    0.00468      0.333
#          5    0.00462      0.407
#          6    0.00155      0.825
#          7   0.000808          1
#          8    0.00179       1.21
#          9    0.00152       1.22
#         10   0.000414        1.5
# done in 0.016 seconds
# Expected: 0.035 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 229         |
# | EpRewMean               | -228        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 77          |
# | TimeElapsed             | 11.9        |
# | TimestepsSoFar          | 23552       |
# | entloss                 | 0.0         |
# | entropy                 | 0.9405143   |
# | explained_variance_t... | 0.229       |
# | meankl                  | 0.006953424 |
# | optimgain               | 0.033355948 |
# | surrgain                | 0.033355948 |
# -----------------------------------------
# ********** Iteration 23 ************
# Optimizing Policy...
# sampling
# done in 0.441 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00625          0
#          1     0.0239     0.0432
#          2     0.0238      0.185
#          3    0.00961      0.307
#          4     0.0052      0.444
#          5     0.0128      0.596
#          6    0.00458      0.839
#          7    0.00264      0.938
#          8    0.00164       1.17
#          9    0.00337       1.18
#         10    0.00146       1.29
# done in 0.015 seconds
# Expected: 0.037 Actual: 0.022
# Stepsize OK!
# vf
# done in 0.023 seconds
# -----------------------------------------
# | EpLenMean               | 227         |
# | EpRewMean               | -226        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 82          |
# | TimeElapsed             | 12.4        |
# | TimestepsSoFar          | 24576       |
# | entloss                 | 0.0         |
# | entropy                 | 0.8985245   |
# | explained_variance_t... | 0.138       |
# | meankl                  | 0.007028087 |
# | optimgain               | 0.02236681  |
# | surrgain                | 0.02236681  |
# -----------------------------------------
# ********** Iteration 24 ************
# Optimizing Policy...
# sampling
# done in 0.438 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0159          0
#          1     0.0287     0.0358
#          2      0.033      0.154
#          3    0.00621      0.269
#          4     0.0069      0.328
#          5    0.00767      0.448
#          6    0.00321      0.744
#          7    0.00326      0.836
#          8     0.0039       1.09
#          9    0.00207       1.11
#         10    0.00109       1.29
# done in 0.016 seconds
# Expected: 0.039 Actual: 0.041
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 217         |
# | EpRewMean               | -216        |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 88          |
# | TimeElapsed             | 12.9        |
# | TimestepsSoFar          | 25600       |
# | entloss                 | 0.0         |
# | entropy                 | 0.91309476  |
# | explained_variance_t... | 0.168       |
# | meankl                  | 0.011415819 |
# | optimgain               | 0.04121252  |
# | surrgain                | 0.04121252  |
# -----------------------------------------
# ********** Iteration 25 ************
# Optimizing Policy...
# sampling
# done in 0.437 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0292          0
#          1     0.0416     0.0584
#          2     0.0174     0.0815
#          3     0.0059      0.228
#          4      0.011      0.306
#          5    0.00667      0.397
#          6    0.00414      0.625
#          7     0.0096      0.869
#          8     0.0148      0.901
#          9      0.003       1.07
#         10    0.00204       1.13
# done in 0.014 seconds
# Expected: 0.039 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 222         |
# | EpRewMean               | -221        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 92          |
# | TimeElapsed             | 13.4        |
# | TimestepsSoFar          | 26624       |
# | entloss                 | 0.0         |
# | entropy                 | 0.83399713  |
# | explained_variance_t... | 0.0448      |
# | meankl                  | 0.011032357 |
# | optimgain               | 0.037590157 |
# | surrgain                | 0.037590157 |
# -----------------------------------------
# ********** Iteration 26 ************
# Optimizing Policy...
# sampling
# done in 0.442 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00938          0
#          1    0.00999     0.0113
#          2    0.00285     0.0195
#          3   0.000861     0.0634
#          4    0.00111      0.101
#          5   0.000858      0.148
#          6   0.000569      0.217
#          7    0.00567      0.231
#          8   0.000281      0.288
#          9   0.000249      0.331
#         10    0.00184      0.361
# done in 0.014 seconds
# Expected: 0.014 Actual: 0.010
# Stepsize OK!
# vf
# done in 0.023 seconds
# ------------------------------------------
# | EpLenMean               | 235          |
# | EpRewMean               | -234         |
# | EpThisIter              | 2            |
# | EpisodesSoFar           | 94           |
# | TimeElapsed             | 13.9         |
# | TimestepsSoFar          | 27648        |
# | entloss                 | 0.0          |
# | entropy                 | 0.77503216   |
# | explained_variance_t... | -0.000414    |
# | meankl                  | 0.011806575  |
# | optimgain               | 0.0095563745 |
# | surrgain                | 0.0095563745 |
# ------------------------------------------
# ********** Iteration 27 ************
# Optimizing Policy...
# sampling
# done in 0.429 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0111          0
#          1     0.0118      0.072
#          2     0.0086     0.0955
#          3     0.0182      0.143
#          4    0.00785       0.32
#          5    0.00687       0.45
#          6    0.00361      0.671
#          7    0.00198      0.811
#          8   0.000647       1.22
#          9     0.0202        1.3
#         10   0.000579       1.51
# done in 0.014 seconds
# Expected: 0.037 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.023 seconds
# -----------------------------------------
# | EpLenMean               | 241         |
# | EpRewMean               | -240        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 98          |
# | TimeElapsed             | 14.4        |
# | TimestepsSoFar          | 28672       |
# | entloss                 | 0.0         |
# | entropy                 | 0.89973426  |
# | explained_variance_t... | 0.133       |
# | meankl                  | 0.009819019 |
# | optimgain               | 0.032542642 |
# | surrgain                | 0.032542642 |
# -----------------------------------------
# ********** Iteration 28 ************
# Optimizing Policy...
# sampling
# done in 0.444 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0473          0
#          1     0.0171     0.0306
#          2     0.0225      0.128
#          3      0.029      0.221
#          4    0.00388      0.339
#          5    0.00654       0.48
#          6    0.00627      0.739
#          7    0.00265      0.867
#          8    0.00296        1.1
#          9    0.00373       1.11
#         10    0.00153       1.33
# done in 0.015 seconds
# Expected: 0.041 Actual: 0.046
# Stepsize OK!
# vf
# done in 0.026 seconds
# -----------------------------------------
# | EpLenMean               | 239         |
# | EpRewMean               | -238        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 103         |
# | TimeElapsed             | 14.9        |
# | TimestepsSoFar          | 29696       |
# | entloss                 | 0.0         |
# | entropy                 | 0.86546147  |
# | explained_variance_t... | 0.205       |
# | meankl                  | 0.012597533 |
# | optimgain               | 0.045941263 |
# | surrgain                | 0.045941263 |
# -----------------------------------------
# ********** Iteration 29 ************
# Optimizing Policy...
# sampling
# done in 0.458 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0339          0
#          1     0.0118     0.0313
#          2     0.0288      0.206
#          3      0.021      0.308
#          4     0.0125      0.516
#          5     0.0138      0.644
#          6     0.0115      0.987
#          7    0.00883       1.29
#          8    0.00875       1.46
#          9    0.00524       2.05
#         10     0.0197       2.27
# done in 0.016 seconds
# Expected: 0.053 Actual: 0.038
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 239         |
# | EpRewMean               | -238        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 107         |
# | TimeElapsed             | 15.4        |
# | TimestepsSoFar          | 30720       |
# | entloss                 | 0.0         |
# | entropy                 | 0.8511541   |
# | explained_variance_t... | 0.206       |
# | meankl                  | 0.012414917 |
# | optimgain               | 0.038125638 |
# | surrgain                | 0.038125638 |
# -----------------------------------------
# ********** Iteration 30 ************
# Optimizing Policy...
# sampling
# done in 0.452 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0246          0
#          1     0.0228     0.0401
#          2     0.0195      0.144
#          3      0.027      0.223
#          4      0.008      0.355
#          5    0.00717      0.437
#          6    0.00379      0.596
#          7    0.00543      0.901
#          8     0.0027       1.23
#          9    0.00166       1.41
#         10     0.0118       1.47
# done in 0.016 seconds
# Expected: 0.042 Actual: 0.054
# Stepsize OK!
# vf
# done in 0.023 seconds
# -----------------------------------------
# | EpLenMean               | 236         |
# | EpRewMean               | -235        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 112         |
# | TimeElapsed             | 15.9        |
# | TimestepsSoFar          | 31744       |
# | entloss                 | 0.0         |
# | entropy                 | 0.88555765  |
# | explained_variance_t... | 0.0801      |
# | meankl                  | 0.009863457 |
# | optimgain               | 0.054008808 |
# | surrgain                | 0.054008808 |
# -----------------------------------------
# ********** Iteration 31 ************
# Optimizing Policy...
# sampling
# done in 0.441 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0369          0
#          1     0.0177     0.0402
#          2     0.0205      0.101
#          3     0.0061      0.158
#          4     0.0051      0.291
#          5     0.0152      0.527
#          6    0.00734      0.686
#          7    0.00341       1.06
#          8    0.00362       1.28
#          9    0.00221       1.37
#         10     0.0123       1.49
# done in 0.015 seconds
# Expected: 0.041 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.025 seconds
# -----------------------------------------
# | EpLenMean               | 239         |
# | EpRewMean               | -238        |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 115         |
# | TimeElapsed             | 16.4        |
# | TimestepsSoFar          | 32768       |
# | entloss                 | 0.0         |
# | entropy                 | 0.86722887  |
# | explained_variance_t... | 0.184       |
# | meankl                  | 0.007781127 |
# | optimgain               | 0.029586233 |
# | surrgain                | 0.029586233 |
# -----------------------------------------
# ********** Iteration 32 ************
# Optimizing Policy...
# sampling
# done in 0.443 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0662          0
#          1     0.0108      0.041
#          2     0.0382      0.133
#          3     0.0138      0.233
#          4     0.0128      0.393
#          5    0.00888       0.54
#          6    0.00592      0.782
#          7    0.00524      0.967
#          8    0.00463       1.36
#          9    0.00718       1.68
#         10    0.00325       1.72
# done in 0.015 seconds
# Expected: 0.047 Actual: 0.042
# Stepsize OK!
# vf
# done in 0.023 seconds
# -----------------------------------------
# | EpLenMean               | 246         |
# | EpRewMean               | -246        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 119         |
# | TimeElapsed             | 16.9        |
# | TimestepsSoFar          | 33792       |
# | entloss                 | 0.0         |
# | entropy                 | 0.850043    |
# | explained_variance_t... | 0.122       |
# | meankl                  | 0.013378357 |
# | optimgain               | 0.042471044 |
# | surrgain                | 0.042471044 |
# -----------------------------------------
# ********** Iteration 33 ************
# Optimizing Policy...
# sampling
# done in 0.442 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0106          0
#          1    0.00789     0.0174
#          2    0.00571      0.129
#          3    0.00459      0.148
#          4    0.00473      0.328
#          5     0.0134      0.573
#          6    0.00378       0.96
#          7    0.00273       1.09
#          8    0.00192       1.33
#          9    0.00413       1.35
#         10    0.00119       1.55
# done in 0.014 seconds
# Expected: 0.035 Actual: 0.044
# Stepsize OK!
# vf
# done in 0.023 seconds
# -----------------------------------------
# | EpLenMean               | 249         |
# | EpRewMean               | -248        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 123         |
# | TimeElapsed             | 17.4        |
# | TimestepsSoFar          | 34816       |
# | entloss                 | 0.0         |
# | entropy                 | 0.91272664  |
# | explained_variance_t... | 0.175       |
# | meankl                  | 0.010009129 |
# | optimgain               | 0.04405245  |
# | surrgain                | 0.04405245  |
# -----------------------------------------
# ********** Iteration 34 ************
# Optimizing Policy...
# sampling
# done in 0.447 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0847          0
#          1     0.0111      0.036
#          2     0.0313      0.188
#          3     0.0151      0.359
#          4     0.0124      0.417
#          5     0.0112      0.583
#          6    0.00574      0.725
#          7    0.00657       1.33
#          8    0.00534       1.62
#          9      0.014       1.68
#         10    0.00217       1.86
# done in 0.015 seconds
# Expected: 0.050 Actual: 0.055
# Stepsize OK!
# vf
# done in 0.024 seconds
# ------------------------------------------
# | EpLenMean               | 254          |
# | EpRewMean               | -253         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 128          |
# | TimeElapsed             | 17.9         |
# | TimestepsSoFar          | 35840        |
# | entloss                 | 0.0          |
# | entropy                 | 0.9090824    |
# | explained_variance_t... | 0.063        |
# | meankl                  | 0.0077819573 |
# | optimgain               | 0.055311322  |
# | surrgain                | 0.055311322  |
# ------------------------------------------
# ********** Iteration 35 ************
# Optimizing Policy...
# sampling
# done in 0.438 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0      0.063          0
#          1     0.0199     0.0402
#          2     0.0389      0.122
#          3     0.0145      0.207
#          4    0.00713       0.27
#          5     0.0113      0.517
#          6    0.00596      0.742
#          7    0.00382      0.936
#          8    0.00193       1.17
#          9     0.0109       1.61
#         10    0.00186       1.65
# done in 0.015 seconds
# Expected: 0.046 Actual: 0.058
# Stepsize OK!
# vf
# done in 0.025 seconds
# -----------------------------------------
# | EpLenMean               | 253         |
# | EpRewMean               | -252        |
# | EpThisIter              | 3           |
# | EpisodesSoFar           | 131         |
# | TimeElapsed             | 18.4        |
# | TimestepsSoFar          | 36864       |
# | entloss                 | 0.0         |
# | entropy                 | 0.91083694  |
# | explained_variance_t... | 0.123       |
# | meankl                  | 0.010661127 |
# | optimgain               | 0.0575234   |
# | surrgain                | 0.0575234   |
# -----------------------------------------
# ********** Iteration 36 ************
# Optimizing Policy...
# sampling
# done in 0.455 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0175          0
#          1     0.0174     0.0308
#          2     0.0106      0.232
#          3      0.021      0.438
#          4     0.0141      0.538
#          5     0.0122      0.741
#          6     0.0139      0.929
#          7    0.00576        1.1
#          8    0.00258       1.35
#          9    0.00579       1.83
#         10     0.0115       1.89
# done in 0.015 seconds
# Expected: 0.048 Actual: 0.033
# Stepsize OK!
# vf
# done in 0.026 seconds
# -----------------------------------------
# | EpLenMean               | 249         |
# | EpRewMean               | -248        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 135         |
# | TimeElapsed             | 18.9        |
# | TimestepsSoFar          | 37888       |
# | entloss                 | 0.0         |
# | entropy                 | 0.8473356   |
# | explained_variance_t... | 0.092       |
# | meankl                  | 0.013052583 |
# | optimgain               | 0.03250129  |
# | surrgain                | 0.03250129  |
# -----------------------------------------
# ********** Iteration 37 ************
# Optimizing Policy...
# sampling
# done in 0.452 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0246          0
#          1     0.0101      0.028
#          2     0.0349      0.231
#          3     0.0194      0.313
#          4     0.0124      0.424
#          5    0.00972      0.588
#          6    0.00229      0.777
#          7    0.00303      0.944
#          8    0.00262       1.17
#          9      0.005       1.52
#         10    0.00282       1.54
# done in 0.016 seconds
# Expected: 0.042 Actual: 0.035
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 252         |
# | EpRewMean               | -250        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 139         |
# | TimeElapsed             | 19.4        |
# | TimestepsSoFar          | 38912       |
# | entloss                 | 0.0         |
# | entropy                 | 0.91220284  |
# | explained_variance_t... | 0.11        |
# | meankl                  | 0.009575728 |
# | optimgain               | 0.034604598 |
# | surrgain                | 0.034604598 |
# -----------------------------------------
# ********** Iteration 38 ************
# Optimizing Policy...
# sampling
# done in 0.447 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0137          0
#          1    0.00889     0.0537
#          2     0.0244     0.0968
#          3    0.00618      0.218
#          4     0.0157       0.28
#          5    0.00704      0.392
#          6    0.00319      0.648
#          7    0.00247      0.889
#          8    0.00257       1.07
#          9    0.00413       1.28
#         10    0.00264        1.3
# done in 0.014 seconds
# Expected: 0.036 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.022 seconds
# -----------------------------------------
# | EpLenMean               | 254         |
# | EpRewMean               | -254        |
# | EpThisIter              | 4           |
# | EpisodesSoFar           | 143         |
# | TimeElapsed             | 19.9        |
# | TimestepsSoFar          | 39936       |
# | entloss                 | 0.0         |
# | entropy                 | 0.90095776  |
# | explained_variance_t... | 0.228       |
# | meankl                  | 0.007460161 |
# | optimgain               | 0.030173238 |
# | surrgain                | 0.030173238 |
# -----------------------------------------
# ********** Iteration 39 ************
# Optimizing Policy...
# sampling
# done in 0.441 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0579          0
#          1    0.00411     0.0276
#          2    0.00831      0.141
#          3     0.0115      0.261
#          4     0.0104      0.384
# ...
#       iter residual norm  soln norm
#          0    0.00928          0
#          1      0.007     0.0194
#          2     0.0112      0.107
#          3    0.00271      0.185
#          4    0.00782      0.272
#          5    0.00315      0.359
#          6    0.00271      0.489
#          7    0.00175      0.665
#          8    0.00114      0.892
#          9    0.00954      0.993
#         10   0.000619       1.07
# done in 0.013 seconds
# Expected: 0.028 Actual: 0.024
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 169         |
# | EpRewMean               | -168        |
# | EpThisIter              | 7           |
# | EpisodesSoFar           | 548         |
# | TimeElapsed             | 67.6        |
# | TimestepsSoFar          | 138240      |
# | entloss                 | 0.0         |
# | entropy                 | 0.53456765  |
# | explained_variance_t... | 0.66        |
# | meankl                  | 0.010134497 |
# | optimgain               | 0.024427364 |
# | surrgain                | 0.024427364 |
# -----------------------------------------
# ********** Iteration 135 ************
# Optimizing Policy...
# sampling
# done in 0.445 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0114          0
#          1    0.00335     0.0196
#          2    0.00311      0.167
#          3    0.00187      0.197
#          4     0.0072      0.326
#          5     0.0041      0.403
#          6    0.00106      0.506
#          7    0.00132      0.766
#          8    0.00112      0.968
#          9   0.000647       1.15
#         10    0.00196       1.17
# done in 0.014 seconds
# Expected: 0.027 Actual: 0.022
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 168         |
# | EpRewMean               | -167        |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 554         |
# | TimeElapsed             | 68.1        |
# | TimestepsSoFar          | 139264      |
# | entloss                 | 0.0         |
# | entropy                 | 0.48120543  |
# | explained_variance_t... | 0.642       |
# | meankl                  | 0.012683624 |
# | optimgain               | 0.021900542 |
# | surrgain                | 0.021900542 |
# -----------------------------------------
# ********** Iteration 136 ************
# Optimizing Policy...
# sampling
# done in 0.442 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0117          0
#          1    0.00632     0.0206
#          2     0.0031     0.0418
#          3    0.00296      0.135
#          4    0.00159      0.233
#          5    0.00359      0.331
#          6    0.00136      0.544
#          7    0.00144      0.762
#          8    0.00584       0.96
#          9    0.00129      0.999
#         10   0.000504        1.3
# done in 0.014 seconds
# Expected: 0.027 Actual: 0.026
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 177         |
# | EpRewMean               | -176        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 559         |
# | TimeElapsed             | 68.6        |
# | TimestepsSoFar          | 140288      |
# | entloss                 | 0.0         |
# | entropy                 | 0.48293617  |
# | explained_variance_t... | 0.474       |
# | meankl                  | 0.013897512 |
# | optimgain               | 0.02560899  |
# | surrgain                | 0.02560899  |
# -----------------------------------------
# ********** Iteration 137 ************
# Optimizing Policy...
# sampling
# done in 0.440 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0358          0
#          1    0.00488     0.0523
#          2    0.00749     0.0919
#          3    0.00467      0.155
#          4    0.00272      0.194
#          5    0.00343      0.246
#          6    0.00122      0.295
#          7    0.00104      0.476
#          8   0.000958      0.636
#          9   0.000611      0.838
#         10   0.000272       1.03
# done in 0.014 seconds
# Expected: 0.028 Actual: 0.022
# Stepsize OK!
# vf
# done in 0.025 seconds
# ------------------------------------------
# | EpLenMean               | 176          |
# | EpRewMean               | -175         |
# | EpThisIter              | 6            |
# | EpisodesSoFar           | 565          |
# | TimeElapsed             | 69.1         |
# | TimestepsSoFar          | 141312       |
# | entloss                 | 0.0          |
# | entropy                 | 0.40063006   |
# | explained_variance_t... | 0.738        |
# | meankl                  | 0.0073203202 |
# | optimgain               | 0.02222564   |
# | surrgain                | 0.02222564   |
# ------------------------------------------
# ********** Iteration 138 ************
# Optimizing Policy...
# sampling
# done in 0.445 seconds
# computegrad
# done in 0.002 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00774          0
#          1    0.00496     0.0232
#          2    0.00403     0.0885
#          3    0.00142      0.129
#          4    0.00285      0.244
#          5     0.0044      0.402
#          6    0.00136      0.536
#          7   0.000574      0.752
#          8   0.000413      0.969
#          9    0.00095      0.981
#         10   0.000149       1.13
# done in 0.014 seconds
# Expected: 0.025 Actual: 0.027
# Stepsize OK!
# vf
# done in 0.025 seconds
# -----------------------------------------
# | EpLenMean               | 171         |
# | EpRewMean               | -170        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 570         |
# | TimeElapsed             | 69.6        |
# | TimestepsSoFar          | 142336      |
# | entloss                 | 0.0         |
# | entropy                 | 0.35808432  |
# | explained_variance_t... | 0.317       |
# | meankl                  | 0.007516231 |
# | optimgain               | 0.026631683 |
# | surrgain                | 0.026631683 |
# -----------------------------------------
# ********** Iteration 139 ************
# Optimizing Policy...
# sampling
# done in 0.444 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0141          0
#          1     0.0142     0.0368
#          2     0.0184      0.173
#          3    0.00696      0.314
#          4    0.00333      0.397
#          5    0.00692      0.555
#          6    0.00421      0.638
#          7    0.00152      0.844
#          8   0.000928        1.1
#          9    0.00806       1.21
#         10   0.000767       1.28
# done in 0.014 seconds
# Expected: 0.037 Actual: 0.027
# Stepsize OK!
# vf
# done in 0.024 seconds
# ------------------------------------------
# | EpLenMean               | 179          |
# | EpRewMean               | -178         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 575          |
# | TimeElapsed             | 70.1         |
# | TimestepsSoFar          | 143360       |
# | entloss                 | 0.0          |
# | entropy                 | 0.42181152   |
# | explained_variance_t... | 0.414        |
# | meankl                  | 0.0066526034 |
# | optimgain               | 0.026938928  |
# | surrgain                | 0.026938928  |
# ------------------------------------------
# ********** Iteration 140 ************
# Optimizing Policy...
# sampling
# done in 0.443 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00679          0
#          1    0.00221       0.02
#          2    0.00543     0.0986
#          3    0.00138      0.145
#          4    0.00272      0.216
#          5    0.00237      0.293
#          6    0.00162      0.433
#          7   0.000698      0.673
#          8   0.000522      0.853
#          9   0.000464      0.959
#         10    0.00312        1.1
# done in 0.015 seconds
# Expected: 0.023 Actual: 0.018
# violated KL constraint. shrinking step.
# Expected: 0.023 Actual: 0.010
# Stepsize OK!
# vf
# done in 0.026 seconds
# ------------------------------------------
# | EpLenMean               | 182          |
# | EpRewMean               | -181         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 580          |
# | TimeElapsed             | 70.6         |
# | TimestepsSoFar          | 144384       |
# | entloss                 | 0.0          |
# | entropy                 | 0.3777519    |
# | explained_variance_t... | 0.653        |
# | meankl                  | 0.0040706173 |
# | optimgain               | 0.010227732  |
# | surrgain                | 0.010227732  |
# ------------------------------------------
# ********** Iteration 141 ************
# Optimizing Policy...
# sampling
# done in 0.442 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00518          0
#          1     0.0111     0.0572
#          2     0.0105      0.117
#          3    0.00438      0.178
#          4     0.0056      0.269
#          5      0.013      0.423
#          6    0.00253      0.673
#          7    0.00324      0.919
#          8    0.00152       1.27
#          9     0.0017       1.48
#         10    0.00323        1.5
# done in 0.014 seconds
# Expected: 0.034 Actual: 0.044
# Stepsize OK!
# vf
# done in 0.025 seconds
# -----------------------------------------
# | EpLenMean               | 183         |
# | EpRewMean               | -182        |
# | EpThisIter              | 6           |
# | EpisodesSoFar           | 586         |
# | TimeElapsed             | 71.1        |
# | TimestepsSoFar          | 145408      |
# | entloss                 | 0.0         |
# | entropy                 | 0.45627004  |
# | explained_variance_t... | 0.625       |
# | meankl                  | 0.014411425 |
# | optimgain               | 0.043909196 |
# | surrgain                | 0.043909196 |
# -----------------------------------------
# ********** Iteration 142 ************
# Optimizing Policy...
# sampling
# done in 0.444 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0559          0
#          1    0.00321     0.0213
#          2    0.00341     0.0594
#          3    0.00345      0.105
#          4     0.0026      0.208
#          5    0.00185      0.467
#          6    0.00407       0.57
#          7    0.00297      0.709
#          8    0.00543      0.741
#          9   0.000848      0.952
#         10   0.000526       1.16
# done in 0.014 seconds
# Expected: 0.028 Actual: 0.030
# Stepsize OK!
# vf
# done in 0.025 seconds
# ----------------------------------------
# | EpLenMean               | 188        |
# | EpRewMean               | -187       |
# | EpThisIter              | 6          |
# | EpisodesSoFar           | 592        |
# | TimeElapsed             | 71.6       |
# | TimestepsSoFar          | 146432     |
# | entloss                 | 0.0        |
# | entropy                 | 0.45950738 |
# | explained_variance_t... | 0.41       |
# | meankl                  | 0.01279074 |
# | optimgain               | 0.0301369  |
# | surrgain                | 0.0301369  |
# ----------------------------------------
# ********** Iteration 143 ************
# Optimizing Policy...
# sampling
# done in 0.439 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00581          0
#          1     0.0105     0.0522
#          2     0.0165      0.138
#          3    0.00741      0.211
#          4    0.00332      0.352
#          5    0.00519      0.526
#          6    0.00377      0.742
#          7    0.00259       1.08
#          8   0.000978       1.58
#          9     0.0045       1.85
#         10   0.000761       1.88
# done in 0.014 seconds
# Expected: 0.038 Actual: 0.020
# violated KL constraint. shrinking step.
# Expected: 0.038 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.025 seconds
# ------------------------------------------
# | EpLenMean               | 197          |
# | EpRewMean               | -196         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 597          |
# | TimeElapsed             | 72.1         |
# | TimestepsSoFar          | 147456       |
# | entloss                 | 0.0          |
# | entropy                 | 0.38652492   |
# | explained_variance_t... | 0.541        |
# | meankl                  | 0.0067605553 |
# | optimgain               | 0.012225769  |
# | surrgain                | 0.012225769  |
# ------------------------------------------
# ********** Iteration 144 ************
# Optimizing Policy...
# sampling
# done in 0.454 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00873          0
#          1    0.00298     0.0423
#          2     0.0141      0.106
#          3    0.00432      0.186
#          4    0.00427      0.281
#          5    0.00142      0.369
#          6     0.0032      0.486
#          7    0.00114      0.715
#          8   0.000887      0.856
#          9    0.00536      0.969
#         10   0.000493       1.01
# done in 0.014 seconds
# Expected: 0.026 Actual: 0.018
# Stepsize OK!
# vf
# done in 0.024 seconds
# ------------------------------------------
# | EpLenMean               | 187          |
# | EpRewMean               | -186         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 602          |
# | TimeElapsed             | 72.6         |
# | TimestepsSoFar          | 148480       |
# | entloss                 | 0.0          |
# | entropy                 | 0.37904805   |
# | explained_variance_t... | 0.462        |
# | meankl                  | 0.0075789774 |
# | optimgain               | 0.018339599  |
# | surrgain                | 0.018339599  |
# ------------------------------------------
# ********** Iteration 145 ************
# Optimizing Policy...
# sampling
# done in 0.448 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0    0.00628          0
#          1    0.00516     0.0788
#          2     0.0148      0.119
#          3    0.00224      0.327
#          4     0.0029      0.465
#          5    0.00217      0.718
#          6    0.00239      0.834
#          7     0.0021       1.01
#          8    0.00058        1.3
#          9    0.00868       1.46
#         10   0.000416       1.53
# done in 0.014 seconds
# Expected: 0.033 Actual: 0.015
# violated KL constraint. shrinking step.
# Expected: 0.033 Actual: 0.011
# Stepsize OK!
# vf
# done in 0.024 seconds
# ------------------------------------------
# | EpLenMean               | 198          |
# | EpRewMean               | -197         |
# | EpThisIter              | 5            |
# | EpisodesSoFar           | 607          |
# | TimeElapsed             | 73.1         |
# | TimestepsSoFar          | 149504       |
# | entloss                 | 0.0          |
# | entropy                 | 0.2987485    |
# | explained_variance_t... | 0.454        |
# | meankl                  | 0.0065338654 |
# | optimgain               | 0.011201997  |
# | surrgain                | 0.011201997  |
# ------------------------------------------
# ********** Iteration 146 ************
# Optimizing Policy...
# sampling
# done in 0.441 seconds
# computegrad
# done in 0.003 seconds
# conjugate_gradient
#       iter residual norm  soln norm
#          0     0.0297          0
#          1    0.00487     0.0397
#          2    0.00527      0.134
#          3    0.00473      0.209
#          4    0.00406      0.271
#          5    0.00406      0.379
#          6    0.00262      0.572
#          7     0.0014      0.873
#          8     0.0009        1.2
#          9   0.000479        1.4
#         10    0.00165       1.42
# done in 0.014 seconds
# Expected: 0.033 Actual: 0.032
# Stepsize OK!
# vf
# done in 0.024 seconds
# -----------------------------------------
# | EpLenMean               | 195         |
# | EpRewMean               | -194        |
# | EpThisIter              | 5           |
# | EpisodesSoFar           | 612         |
# | TimeElapsed             | 73.6        |
# | TimestepsSoFar          | 150528      |
# | entloss                 | 0.0         |
# | entropy                 | 0.29321998  |
# | explained_variance_t... | 0.466       |
# | meankl                  | 0.013506384 |
# | optimgain               | 0.031752184 |
# | surrgain                | 0.031752184 |
# -----------------------------------------

# %%
results_plotter.plot_results([log_dir], time_steps, results_plotter.X_EPISODES, "TRPO")
plt.show()
