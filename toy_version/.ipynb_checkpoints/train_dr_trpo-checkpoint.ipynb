# %%
import gym
import pybullet
import pybullet_envs
from gym import wrappers
from datetime import datetime

# DR TRPO related files
from train_helper import *
from value import NNValueFunction
from utils import Logger
from dr_policy import DRPolicyKL, DRPolicyWass

# %%
#########################     Discrete State Space - KL DR Policy     ######################### 
# 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

env_name = 'NChain-v0'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyKL(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 2000
batch_eps = 20
logger = Logger(logname=env_name + '_DR-KL_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 20, Mean Return = 1311.1, Mean Discounted Return = 13.3 *****
# ExplainedVarNew: -7.37e-07
# ExplainedVarOld: -0.000309
# ValFuncLoss: 28.8
#
#
# ***** Episode 40, Mean Return = 1619.2, Mean Discounted Return = 14.7 *****
# ExplainedVarNew: -0.0605
# ExplainedVarOld: -2.53e-07
# ValFuncLoss: 93.2
#
#
# ***** Episode 60, Mean Return = 2023.8, Mean Discounted Return = 14.5 *****
# ExplainedVarNew: -0.212
# ExplainedVarOld: -0.0395
# ValFuncLoss: 210
#
#
# ***** Episode 80, Mean Return = 2543.3, Mean Discounted Return = 18.8 *****
# ExplainedVarNew: -0.28
# ExplainedVarOld: -0.176
# ValFuncLoss: 344
#
#
# ***** Episode 100, Mean Return = 2997.3, Mean Discounted Return = 21.3 *****
# ExplainedVarNew: -0.293
# ExplainedVarOld: -0.265
# ValFuncLoss: 419
#
#
# ***** Episode 120, Mean Return = 3205.1, Mean Discounted Return = 20.3 *****
# ExplainedVarNew: -0.271
# ExplainedVarOld: -0.287
# ValFuncLoss: 435
#
#
# ***** Episode 140, Mean Return = 3298.6, Mean Discounted Return = 20.6 *****
# ExplainedVarNew: -0.262
# ExplainedVarOld: -0.284
# ValFuncLoss: 416
#
#
# ***** Episode 160, Mean Return = 3389.2, Mean Discounted Return = 25.9 *****
# ExplainedVarNew: -0.258
# ExplainedVarOld: -0.249
# ValFuncLoss: 438
#
#
# ***** Episode 180, Mean Return = 3403.4, Mean Discounted Return = 18.7 *****
# ExplainedVarNew: -0.234
# ExplainedVarOld: -0.276
# ValFuncLoss: 396
#
#
# ***** Episode 200, Mean Return = 3511.2, Mean Discounted Return = 21.8 *****
# ExplainedVarNew: -0.221
# ExplainedVarOld: -0.224
# ValFuncLoss: 412
#
#
# ***** Episode 220, Mean Return = 3531.3, Mean Discounted Return = 23.6 *****
# ExplainedVarNew: -0.218
# ExplainedVarOld: -0.205
# ValFuncLoss: 440
#
#
# ***** Episode 240, Mean Return = 3498.1, Mean Discounted Return = 23.0 *****
# ExplainedVarNew: -0.225
# ExplainedVarOld: -0.225
# ValFuncLoss: 423
#
#
# ***** Episode 260, Mean Return = 3518.5, Mean Discounted Return = 21.2 *****
# ExplainedVarNew: -0.234
# ExplainedVarOld: -0.217
# ValFuncLoss: 439
#
#
# ***** Episode 280, Mean Return = 3678.1, Mean Discounted Return = 27.1 *****
# ExplainedVarNew: -0.215
# ExplainedVarOld: -0.224
# ValFuncLoss: 451
#
#
# ***** Episode 300, Mean Return = 3673.9, Mean Discounted Return = 25.0 *****
# ExplainedVarNew: -0.223
# ExplainedVarOld: -0.216
# ValFuncLoss: 447
#
#
# ***** Episode 320, Mean Return = 3690.2, Mean Discounted Return = 24.7 *****
# ExplainedVarNew: -0.2
# ExplainedVarOld: -0.22
# ValFuncLoss: 443
#
#
# ***** Episode 340, Mean Return = 3689.2, Mean Discounted Return = 27.5 *****
# ExplainedVarNew: -0.208
# ExplainedVarOld: -0.203
# ValFuncLoss: 437
#
#
# ***** Episode 360, Mean Return = 3708.9, Mean Discounted Return = 28.0 *****
# ExplainedVarNew: -0.21
# ExplainedVarOld: -0.203
# ValFuncLoss: 447
#
#
# ***** Episode 380, Mean Return = 3720.9, Mean Discounted Return = 30.7 *****
# ExplainedVarNew: -0.211
# ExplainedVarOld: -0.213
# ValFuncLoss: 439
#
#
# ***** Episode 400, Mean Return = 3669.8, Mean Discounted Return = 25.6 *****
# ExplainedVarNew: -0.199
# ExplainedVarOld: -0.212
# ValFuncLoss: 433
#
#
# ***** Episode 420, Mean Return = 3621.8, Mean Discounted Return = 20.4 *****
# ExplainedVarNew: -0.214
# ExplainedVarOld: -0.199
# ValFuncLoss: 435
#
#
# ***** Episode 440, Mean Return = 3603.6, Mean Discounted Return = 25.9 *****
# ExplainedVarNew: -0.217
# ExplainedVarOld: -0.221
# ValFuncLoss: 424
#
#
# ***** Episode 460, Mean Return = 3668.3, Mean Discounted Return = 26.4 *****
# ExplainedVarNew: -0.207
# ExplainedVarOld: -0.21
# ValFuncLoss: 435
#
#
# ***** Episode 480, Mean Return = 3653.7, Mean Discounted Return = 23.9 *****
# ExplainedVarNew: -0.218
# ExplainedVarOld: -0.208
# ValFuncLoss: 436
#
#
# ***** Episode 500, Mean Return = 3746.1, Mean Discounted Return = 30.5 *****
# ExplainedVarNew: -0.203
# ExplainedVarOld: -0.203
# ValFuncLoss: 463
#
#
# ***** Episode 520, Mean Return = 3618.5, Mean Discounted Return = 23.2 *****
# ExplainedVarNew: -0.219
# ExplainedVarOld: -0.215
# ValFuncLoss: 441
#
#
# ***** Episode 540, Mean Return = 3679.6, Mean Discounted Return = 26.0 *****
# ExplainedVarNew: -0.197
# ExplainedVarOld: -0.207
# ValFuncLoss: 458
#
#
# ***** Episode 560, Mean Return = 3665.7, Mean Discounted Return = 27.1 *****
# ExplainedVarNew: -0.211
# ExplainedVarOld: -0.207
# ValFuncLoss: 441
#
#
# ***** Episode 580, Mean Return = 3698.9, Mean Discounted Return = 26.0 *****
# ExplainedVarNew: -0.204
# ExplainedVarOld: -0.206
# ValFuncLoss: 448
#
#
# ***** Episode 600, Mean Return = 3618.8, Mean Discounted Return = 26.1 *****
# ExplainedVarNew: -0.223
# ExplainedVarOld: -0.222
# ValFuncLoss: 419
#
#
# ***** Episode 620, Mean Return = 3776.3, Mean Discounted Return = 26.5 *****
# ExplainedVarNew: -0.214
# ExplainedVarOld: -0.208
# ValFuncLoss: 446
#
#
# ***** Episode 640, Mean Return = 3537.6, Mean Discounted Return = 22.8 *****
# ExplainedVarNew: -0.206
# ExplainedVarOld: -0.229
# ValFuncLoss: 413
#
#
# ***** Episode 660, Mean Return = 3829.3, Mean Discounted Return = 30.9 *****
# ExplainedVarNew: -0.21
# ExplainedVarOld: -0.188
# ValFuncLoss: 461
#
#
# ***** Episode 680, Mean Return = 3594.1, Mean Discounted Return = 25.0 *****
# ExplainedVarNew: -0.219
# ExplainedVarOld: -0.216
# ValFuncLoss: 447
#
#
# ***** Episode 700, Mean Return = 3687.1, Mean Discounted Return = 27.1 *****
# ExplainedVarNew: -0.2
# ExplainedVarOld: -0.213
# ValFuncLoss: 453
#
#
# ***** Episode 720, Mean Return = 3726.4, Mean Discounted Return = 26.5 *****
# ExplainedVarNew: -0.227
# ExplainedVarOld: -0.2
# ValFuncLoss: 465
#
#
# ***** Episode 740, Mean Return = 3708.2, Mean Discounted Return = 29.3 *****
# ExplainedVarNew: -0.239
# ExplainedVarOld: -0.241
# ValFuncLoss: 444
#
#
# ***** Episode 760, Mean Return = 3724.6, Mean Discounted Return = 33.0 *****
# ExplainedVarNew: -0.199
# ExplainedVarOld: -0.226
# ValFuncLoss: 453
#
#
# ***** Episode 780, Mean Return = 3617.2, Mean Discounted Return = 24.4 *****
# ExplainedVarNew: -0.199
# ExplainedVarOld: -0.211
# ValFuncLoss: 425
#
#
# ***** Episode 800, Mean Return = 3595.1, Mean Discounted Return = 26.3 *****
# ExplainedVarNew: -0.213
# ExplainedVarOld: -0.203
# ValFuncLoss: 419
#
#
# ***** Episode 820, Mean Return = 3711.9, Mean Discounted Return = 28.0 *****
# ExplainedVarNew: -0.203
# ExplainedVarOld: -0.203
# ValFuncLoss: 437
#
#
# ***** Episode 840, Mean Return = 3718.3, Mean Discounted Return = 25.7 *****
# ExplainedVarNew: -0.209
# ExplainedVarOld: -0.195
# ValFuncLoss: 457
#
#
# ***** Episode 860, Mean Return = 3633.3, Mean Discounted Return = 24.9 *****
# ExplainedVarNew: -0.222
# ExplainedVarOld: -0.224
# ValFuncLoss: 429
#
#
# ***** Episode 880, Mean Return = 3624.8, Mean Discounted Return = 21.4 *****
# ExplainedVarNew: -0.196
# ExplainedVarOld: -0.211
# ValFuncLoss: 441
#
#
# ***** Episode 900, Mean Return = 3689.9, Mean Discounted Return = 25.3 *****
# ExplainedVarNew: -0.205
# ExplainedVarOld: -0.197
# ValFuncLoss: 444
#
#
# ***** Episode 920, Mean Return = 3663.0, Mean Discounted Return = 21.1 *****
# ExplainedVarNew: -0.224
# ExplainedVarOld: -0.204
# ValFuncLoss: 452
#
#
# ***** Episode 940, Mean Return = 3612.9, Mean Discounted Return = 28.6 *****
# ExplainedVarNew: -0.211
# ExplainedVarOld: -0.236
# ValFuncLoss: 424
#
#
# ***** Episode 960, Mean Return = 3613.4, Mean Discounted Return = 24.8 *****
# ExplainedVarNew: -0.207
# ExplainedVarOld: -0.202
# ValFuncLoss: 440
#
#
# ***** Episode 980, Mean Return = 3584.9, Mean Discounted Return = 31.8 *****
# ExplainedVarNew: -0.202
# ExplainedVarOld: -0.215
# ValFuncLoss: 424
#
#
# ***** Episode 1000, Mean Return = 3556.2, Mean Discounted Return = 24.4 *****
# ExplainedVarNew: -0.208
# ExplainedVarOld: -0.199
# ValFuncLoss: 431
#
#
# ***** Episode 1020, Mean Return = 3665.2, Mean Discounted Return = 28.3 *****
# ExplainedVarNew: -0.219
# ExplainedVarOld: -0.211
# ValFuncLoss: 430
#
#
# ***** Episode 1040, Mean Return = 3656.7, Mean Discounted Return = 24.4 *****
# ExplainedVarNew: -0.208
# ExplainedVarOld: -0.216
# ValFuncLoss: 432
#
#
# ***** Episode 1060, Mean Return = 3604.5, Mean Discounted Return = 30.9 *****
# ExplainedVarNew: -0.203
# ExplainedVarOld: -0.208
# ValFuncLoss: 431
#
#
# ***** Episode 1080, Mean Return = 3574.1, Mean Discounted Return = 24.0 *****
# ExplainedVarNew: -0.214
# ExplainedVarOld: -0.223
# ValFuncLoss: 396
#
#
# ***** Episode 1100, Mean Return = 3678.5, Mean Discounted Return = 27.1 *****
# ExplainedVarNew: -0.189
# ExplainedVarOld: -0.184
# ValFuncLoss: 454
#
#
# ***** Episode 1120, Mean Return = 3616.1, Mean Discounted Return = 26.4 *****
# ExplainedVarNew: -0.219
# ExplainedVarOld: -0.212
# ValFuncLoss: 416
#
#
# ***** Episode 1140, Mean Return = 3607.7, Mean Discounted Return = 28.8 *****
# ExplainedVarNew: -0.202
# ExplainedVarOld: -0.202
# ValFuncLoss: 445
# ***** Episode 1160, Mean Return = 3697.3, Mean Discounted Return = 24.4 *****
# ExplainedVarNew: -0.207
# ExplainedVarOld: -0.205
# ValFuncLoss: 440
#
#
# ***** Episode 1180, Mean Return = 3796.0, Mean Discounted Return = 26.0 *****
# ExplainedVarNew: -0.197
# ExplainedVarOld: -0.185
# ValFuncLoss: 490
#
#
# ***** Episode 1200, Mean Return = 3590.7, Mean Discounted Return = 24.1 *****
# ExplainedVarNew: -0.225
# ExplainedVarOld: -0.231
# ValFuncLoss: 426
#
#
# ***** Episode 1220, Mean Return = 3630.9, Mean Discounted Return = 19.5 *****
# ExplainedVarNew: -0.191
# ExplainedVarOld: -0.21
# ValFuncLoss: 443
#
#
# ***** Episode 1240, Mean Return = 3623.6, Mean Discounted Return = 30.2 *****
# ExplainedVarNew: -0.215
# ExplainedVarOld: -0.201
# ValFuncLoss: 427
#
#
# ***** Episode 1260, Mean Return = 3739.9, Mean Discounted Return = 28.6 *****
# ExplainedVarNew: -0.197
# ExplainedVarOld: -0.208
# ValFuncLoss: 440
#
#
# ***** Episode 1280, Mean Return = 3684.7, Mean Discounted Return = 25.6 *****
# ExplainedVarNew: -0.217
# ExplainedVarOld: -0.195
# ValFuncLoss: 449
#
#
# ***** Episode 1300, Mean Return = 3680.3, Mean Discounted Return = 26.7 *****
# ExplainedVarNew: -0.207
# ExplainedVarOld: -0.219
# ValFuncLoss: 444
#
#
# ***** Episode 1320, Mean Return = 3620.9, Mean Discounted Return = 26.2 *****
# ExplainedVarNew: -0.219
# ExplainedVarOld: -0.214
# ValFuncLoss: 432
#
#
# ***** Episode 1340, Mean Return = 3742.7, Mean Discounted Return = 25.7 *****
# ExplainedVarNew: -0.204
# ExplainedVarOld: -0.201
# ValFuncLoss: 468
#
#
# ***** Episode 1360, Mean Return = 3571.8, Mean Discounted Return = 30.1 *****
# ExplainedVarNew: -0.227
# ExplainedVarOld: -0.222
# ValFuncLoss: 436
#
#
# ***** Episode 1380, Mean Return = 3605.4, Mean Discounted Return = 30.4 *****
# ExplainedVarNew: -0.2
# ExplainedVarOld: -0.215
# ValFuncLoss: 451
#
#
# ***** Episode 1400, Mean Return = 3595.2, Mean Discounted Return = 22.1 *****
# ExplainedVarNew: -0.224
# ExplainedVarOld: -0.22
# ValFuncLoss: 417
#
#
# ***** Episode 1420, Mean Return = 3806.4, Mean Discounted Return = 19.2 *****
# ExplainedVarNew: -0.194
# ExplainedVarOld: -0.195
# ValFuncLoss: 473
#
#
# ***** Episode 1440, Mean Return = 3733.8, Mean Discounted Return = 26.2 *****
# ExplainedVarNew: -0.209
# ExplainedVarOld: -0.21
# ValFuncLoss: 439
#
#
# ***** Episode 1460, Mean Return = 3675.8, Mean Discounted Return = 22.6 *****
# ExplainedVarNew: -0.197
# ExplainedVarOld: -0.206
# ValFuncLoss: 440
#
#
# ***** Episode 1480, Mean Return = 3596.4, Mean Discounted Return = 23.1 *****
# ExplainedVarNew: -0.202
# ExplainedVarOld: -0.194
# ValFuncLoss: 447
#
#
# ***** Episode 1500, Mean Return = 3576.4, Mean Discounted Return = 21.9 *****
# ExplainedVarNew: -0.226
# ExplainedVarOld: -0.211
# ValFuncLoss: 438
#
#
# ***** Episode 1520, Mean Return = 3682.8, Mean Discounted Return = 25.5 *****
# ExplainedVarNew: -0.218
# ExplainedVarOld: -0.219
# ValFuncLoss: 449
#
#
# ***** Episode 1540, Mean Return = 3767.7, Mean Discounted Return = 28.7 *****
# ExplainedVarNew: -0.211
# ExplainedVarOld: -0.209
# ValFuncLoss: 467
#
#
# ***** Episode 1560, Mean Return = 3651.3, Mean Discounted Return = 24.6 *****
# ExplainedVarNew: -0.218
# ExplainedVarOld: -0.223
# ValFuncLoss: 444
#
#
# ***** Episode 1580, Mean Return = 3717.8, Mean Discounted Return = 23.0 *****
# ExplainedVarNew: -0.2
# ExplainedVarOld: -0.215
# ValFuncLoss: 444
#
#
# ***** Episode 1600, Mean Return = 3598.5, Mean Discounted Return = 24.9 *****
# ExplainedVarNew: -0.206
# ExplainedVarOld: -0.213
# ValFuncLoss: 419
#
#
# ***** Episode 1620, Mean Return = 3705.8, Mean Discounted Return = 25.1 *****
# ExplainedVarNew: -0.197
# ExplainedVarOld: -0.2
# ValFuncLoss: 429
#
#
# ***** Episode 1640, Mean Return = 3626.5, Mean Discounted Return = 26.9 *****
# ExplainedVarNew: -0.21
# ExplainedVarOld: -0.197
# ValFuncLoss: 433
#
#
# ***** Episode 1660, Mean Return = 3655.2, Mean Discounted Return = 24.3 *****
# ExplainedVarNew: -0.215
# ExplainedVarOld: -0.211
# ValFuncLoss: 432
#
#
# ***** Episode 1680, Mean Return = 3658.9, Mean Discounted Return = 24.1 *****
# ExplainedVarNew: -0.206
# ExplainedVarOld: -0.212
# ValFuncLoss: 437
#
#
# ***** Episode 1700, Mean Return = 3637.4, Mean Discounted Return = 19.7 *****
# ExplainedVarNew: -0.212
# ExplainedVarOld: -0.21
# ValFuncLoss: 426
#
#
# ***** Episode 1720, Mean Return = 3733.2, Mean Discounted Return = 24.7 *****
# ExplainedVarNew: -0.208
# ExplainedVarOld: -0.207
# ValFuncLoss: 437
#
#
# ***** Episode 1740, Mean Return = 3676.0, Mean Discounted Return = 28.2 *****
# ExplainedVarNew: -0.208
# ExplainedVarOld: -0.198
# ValFuncLoss: 459
#
#
# ***** Episode 1760, Mean Return = 3705.9, Mean Discounted Return = 25.8 *****
# ExplainedVarNew: -0.208
# ExplainedVarOld: -0.205
# ValFuncLoss: 465
#
#
# ***** Episode 1780, Mean Return = 3685.3, Mean Discounted Return = 30.1 *****
# ExplainedVarNew: -0.213
# ExplainedVarOld: -0.212
# ValFuncLoss: 459
#
#
# ***** Episode 1800, Mean Return = 3716.9, Mean Discounted Return = 20.3 *****
# ExplainedVarNew: -0.227
# ExplainedVarOld: -0.223
# ValFuncLoss: 443
#
#
# ***** Episode 1820, Mean Return = 3636.8, Mean Discounted Return = 27.8 *****
# ExplainedVarNew: -0.207
# ExplainedVarOld: -0.235
# ValFuncLoss: 421
#
#
# ***** Episode 1840, Mean Return = 3658.4, Mean Discounted Return = 23.3 *****
# ExplainedVarNew: -0.205
# ExplainedVarOld: -0.191
# ValFuncLoss: 454
#
#
# ***** Episode 1860, Mean Return = 3697.4, Mean Discounted Return = 25.8 *****
# ExplainedVarNew: -0.214
# ExplainedVarOld: -0.223
# ValFuncLoss: 422
#
#
# ***** Episode 1880, Mean Return = 3678.4, Mean Discounted Return = 26.0 *****
# ExplainedVarNew: -0.196
# ExplainedVarOld: -0.209
# ValFuncLoss: 424
#
#
# ***** Episode 1900, Mean Return = 3639.8, Mean Discounted Return = 23.1 *****
# ExplainedVarNew: -0.21
# ExplainedVarOld: -0.184
# ValFuncLoss: 457
#
#
# ***** Episode 1920, Mean Return = 3620.0, Mean Discounted Return = 29.8 *****
# ExplainedVarNew: -0.223
# ExplainedVarOld: -0.216
# ValFuncLoss: 449
#
#
# ***** Episode 1940, Mean Return = 3752.8, Mean Discounted Return = 23.5 *****
# ExplainedVarNew: -0.219
# ExplainedVarOld: -0.222
# ValFuncLoss: 452
#
#
# ***** Episode 1960, Mean Return = 3651.9, Mean Discounted Return = 29.7 *****
# ExplainedVarNew: -0.222
# ExplainedVarOld: -0.22
# ValFuncLoss: 448
#
#
# ***** Episode 1980, Mean Return = 3637.0, Mean Discounted Return = 21.8 *****
# ExplainedVarNew: -0.212
# ExplainedVarOld: -0.237
# ValFuncLoss: 417
#
#
# ***** Episode 2000, Mean Return = 3603.4, Mean Discounted Return = 22.9 *****
# ExplainedVarNew: -0.203
# ExplainedVarOld: -0.202
# ValFuncLoss: 435

# %%
####################   Discrete State Space - Wasserstein DR Policy     ##################### 
#'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

env_name = 'NChain-v0'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyWass(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.8
lam = 1
total_eps = 1500
batch_eps = 15
logger = Logger(logname=env_name + '_DR-Wass_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 10, Mean Return = 1272.8, Mean Discounted Return = 4.9 *****
# ExplainedVarNew: -0.000206
# ExplainedVarOld: -0.000441
# ValFuncLoss: 12.3
#
#
# ***** Episode 20, Mean Return = 2583.6, Mean Discounted Return = 5.7 *****
# ExplainedVarNew: -0.226
# ExplainedVarOld: -2.12e-05
# ValFuncLoss: 158
#
#
# ***** Episode 30, Mean Return = 2389.4, Mean Discounted Return = 6.0 *****
# ExplainedVarNew: -0.482
# ExplainedVarOld: -0.235
# ValFuncLoss: 161
#
#
# ***** Episode 40, Mean Return = 2528.8, Mean Discounted Return = 8.8 *****
# ExplainedVarNew: -0.491
# ExplainedVarOld: -0.456
# ValFuncLoss: 182
#
#
# ***** Episode 50, Mean Return = 2629.2, Mean Discounted Return = 7.7 *****
# ExplainedVarNew: -0.504
# ExplainedVarOld: -0.48
# ValFuncLoss: 193
#
#
# ***** Episode 60, Mean Return = 2423.6, Mean Discounted Return = 6.4 *****
# ExplainedVarNew: -0.518
# ExplainedVarOld: -0.546
# ValFuncLoss: 167
#
#
# ***** Episode 70, Mean Return = 2473.0, Mean Discounted Return = 6.9 *****
# ExplainedVarNew: -0.495
# ExplainedVarOld: -0.527
# ValFuncLoss: 166
#
#
# ***** Episode 80, Mean Return = 2612.0, Mean Discounted Return = 7.4 *****
# ExplainedVarNew: -0.472
# ExplainedVarOld: -0.459
# ValFuncLoss: 183
#
#
# ***** Episode 90, Mean Return = 2532.4, Mean Discounted Return = 9.7 *****
# ExplainedVarNew: -0.492
# ExplainedVarOld: -0.46
# ValFuncLoss: 185
#
#
# ***** Episode 100, Mean Return = 2577.2, Mean Discounted Return = 6.4 *****
# ExplainedVarNew: -0.504
# ExplainedVarOld: -0.521
# ValFuncLoss: 180
#
#
# ***** Episode 110, Mean Return = 2529.6, Mean Discounted Return = 5.2 *****
# ExplainedVarNew: -0.516
# ExplainedVarOld: -0.513
# ValFuncLoss: 174
#
#
# ***** Episode 120, Mean Return = 2490.2, Mean Discounted Return = 8.6 *****
# ExplainedVarNew: -0.499
# ExplainedVarOld: -0.519
# ValFuncLoss: 168
#
#
# ***** Episode 130, Mean Return = 2404.2, Mean Discounted Return = 6.0 *****
# ExplainedVarNew: -0.499
# ExplainedVarOld: -0.495
# ValFuncLoss: 166
#
#
# ***** Episode 140, Mean Return = 2511.0, Mean Discounted Return = 8.0 *****
# ExplainedVarNew: -0.484
# ExplainedVarOld: -0.489
# ValFuncLoss: 174
#
#
# ***** Episode 150, Mean Return = 2601.4, Mean Discounted Return = 7.7 *****
# ExplainedVarNew: -0.486
# ExplainedVarOld: -0.477
# ValFuncLoss: 185
#
#
# ***** Episode 160, Mean Return = 2467.4, Mean Discounted Return = 8.1 *****
# ExplainedVarNew: -0.502
# ExplainedVarOld: -0.481
# ValFuncLoss: 177
#
#
# ***** Episode 170, Mean Return = 2561.0, Mean Discounted Return = 7.1 *****
# ExplainedVarNew: -0.505
# ExplainedVarOld: -0.495
# ValFuncLoss: 186
#
#
# ***** Episode 180, Mean Return = 2434.2, Mean Discounted Return = 6.2 *****
# ExplainedVarNew: -0.495
# ExplainedVarOld: -0.535
# ValFuncLoss: 168
#
#
# ***** Episode 190, Mean Return = 2420.4, Mean Discounted Return = 7.1 *****
# ExplainedVarNew: -0.486
# ExplainedVarOld: -0.485
# ValFuncLoss: 169
#
#
# ***** Episode 200, Mean Return = 2457.8, Mean Discounted Return = 6.3 *****
# ExplainedVarNew: -0.494
# ExplainedVarOld: -0.501
# ValFuncLoss: 167
#
#
# ***** Episode 210, Mean Return = 2404.8, Mean Discounted Return = 5.7 *****
# ExplainedVarNew: -0.496
# ExplainedVarOld: -0.506
# ValFuncLoss: 161
#
#
# ***** Episode 220, Mean Return = 2492.6, Mean Discounted Return = 5.9 *****
# ExplainedVarNew: -0.477
# ExplainedVarOld: -0.473
# ValFuncLoss: 172
#
#
# ***** Episode 230, Mean Return = 2585.0, Mean Discounted Return = 6.4 *****
# ExplainedVarNew: -0.484
# ExplainedVarOld: -0.463
# ValFuncLoss: 183
#
#
# ***** Episode 240, Mean Return = 2499.6, Mean Discounted Return = 6.7 *****
# ExplainedVarNew: -0.506
# ExplainedVarOld: -0.505
# ValFuncLoss: 172
#
#
# ***** Episode 250, Mean Return = 2472.4, Mean Discounted Return = 7.9 *****
# ExplainedVarNew: -0.496
# ExplainedVarOld: -0.501
# ValFuncLoss: 171
#
#
# ***** Episode 260, Mean Return = 2309.4, Mean Discounted Return = 7.2 *****
# ExplainedVarNew: -0.5
# ExplainedVarOld: -0.536
# ValFuncLoss: 149
#
#
# ***** Episode 270, Mean Return = 2602.2, Mean Discounted Return = 6.2 *****
# ExplainedVarNew: -0.473
# ExplainedVarOld: -0.455
# ValFuncLoss: 181
#
#
# ***** Episode 280, Mean Return = 2543.6, Mean Discounted Return = 6.6 *****
# ExplainedVarNew: -0.501
# ExplainedVarOld: -0.485
# ValFuncLoss: 176
#
#
# ***** Episode 290, Mean Return = 2514.8, Mean Discounted Return = 7.7 *****
# ExplainedVarNew: -0.493
# ExplainedVarOld: -0.516
# ValFuncLoss: 169
#
#
# ***** Episode 300, Mean Return = 2522.8, Mean Discounted Return = 6.6 *****
# ExplainedVarNew: -0.49
# ExplainedVarOld: -0.474
# ValFuncLoss: 174
#
#
# ***** Episode 310, Mean Return = 2355.4, Mean Discounted Return = 8.7 *****
# ExplainedVarNew: -0.489
# ExplainedVarOld: -0.497
# ValFuncLoss: 163
#
#
# ***** Episode 320, Mean Return = 2635.6, Mean Discounted Return = 7.6 *****
# ExplainedVarNew: -0.479
# ExplainedVarOld: -0.456
# ValFuncLoss: 191
#
#
# ***** Episode 330, Mean Return = 2522.6, Mean Discounted Return = 7.3 *****
# ExplainedVarNew: -0.521
# ExplainedVarOld: -0.513
# ValFuncLoss: 176
#
#
# ***** Episode 340, Mean Return = 2679.4, Mean Discounted Return = 7.1 *****
# ExplainedVarNew: -0.483
# ExplainedVarOld: -0.48
# ValFuncLoss: 197
#
#
# ***** Episode 350, Mean Return = 2397.8, Mean Discounted Return = 7.3 *****
# ExplainedVarNew: -0.537
# ExplainedVarOld: -0.574
# ValFuncLoss: 157
#
#
# ***** Episode 360, Mean Return = 2455.6, Mean Discounted Return = 5.8 *****
# ExplainedVarNew: -0.465
# ExplainedVarOld: -0.487
# ValFuncLoss: 165
#
#
# ***** Episode 370, Mean Return = 2517.0, Mean Discounted Return = 8.9 *****
# ExplainedVarNew: -0.5
# ExplainedVarOld: -0.464
# ValFuncLoss: 175
#
#
# ***** Episode 380, Mean Return = 2454.8, Mean Discounted Return = 7.7 *****
# ExplainedVarNew: -0.486
# ExplainedVarOld: -0.507
# ValFuncLoss: 167
#
#
# ***** Episode 390, Mean Return = 2661.6, Mean Discounted Return = 8.4 *****
# ExplainedVarNew: -0.47
# ExplainedVarOld: -0.458
# ValFuncLoss: 188
#
#
# ***** Episode 400, Mean Return = 2587.8, Mean Discounted Return = 7.3 *****
# ExplainedVarNew: -0.499
# ExplainedVarOld: -0.452
# ValFuncLoss: 193
#
#
# ***** Episode 410, Mean Return = 2584.8, Mean Discounted Return = 6.8 *****
# ExplainedVarNew: -0.531
# ExplainedVarOld: -0.558
# ValFuncLoss: 178
#
#
# ***** Episode 420, Mean Return = 2558.4, Mean Discounted Return = 6.6 *****
# ExplainedVarNew: -0.478
# ExplainedVarOld: -0.497
# ValFuncLoss: 182
#
#
# ***** Episode 430, Mean Return = 2582.2, Mean Discounted Return = 7.4 *****
# ExplainedVarNew: -0.5
# ExplainedVarOld: -0.469
# ValFuncLoss: 189
#
#
# ***** Episode 440, Mean Return = 2484.6, Mean Discounted Return = 7.8 *****
# ExplainedVarNew: -0.518
# ExplainedVarOld: -0.554
# ValFuncLoss: 168
#
#
# ***** Episode 450, Mean Return = 2541.6, Mean Discounted Return = 8.0 *****
# ExplainedVarNew: -0.471
# ExplainedVarOld: -0.489
# ValFuncLoss: 175
#
#
# ***** Episode 460, Mean Return = 2443.2, Mean Discounted Return = 9.6 *****
# ExplainedVarNew: -0.492
# ExplainedVarOld: -0.475
# ValFuncLoss: 170
#
#
# ***** Episode 470, Mean Return = 2346.8, Mean Discounted Return = 7.3 *****
# ExplainedVarNew: -0.505
# ExplainedVarOld: -0.512
# ValFuncLoss: 159
#
#
# ***** Episode 480, Mean Return = 2996.2, Mean Discounted Return = 8.7 *****
# ExplainedVarNew: -0.457
# ExplainedVarOld: -0.483
# ValFuncLoss: 205
#
#
# ***** Episode 490, Mean Return = 3129.8, Mean Discounted Return = 10.7 *****
# ExplainedVarNew: -0.452
# ExplainedVarOld: -0.438
# ValFuncLoss: 217
#
#
# ***** Episode 500, Mean Return = 3008.2, Mean Discounted Return = 9.7 *****
# ExplainedVarNew: -0.471
# ExplainedVarOld: -0.475
# ValFuncLoss: 206
#
#
# ***** Episode 510, Mean Return = 2993.2, Mean Discounted Return = 10.1 *****
# ExplainedVarNew: -0.458
# ExplainedVarOld: -0.484
# ValFuncLoss: 197
#
#
# ***** Episode 520, Mean Return = 3483.8, Mean Discounted Return = 8.2 *****
# ExplainedVarNew: -0.415
# ExplainedVarOld: -0.414
# ValFuncLoss: 223
#
#
# ***** Episode 530, Mean Return = 3523.4, Mean Discounted Return = 9.1 *****
# ExplainedVarNew: -0.404
# ExplainedVarOld: -0.42
# ValFuncLoss: 219
#
#
# ***** Episode 540, Mean Return = 3513.8, Mean Discounted Return = 7.3 *****
# ExplainedVarNew: -0.394
# ExplainedVarOld: -0.385
# ValFuncLoss: 227
#
#
# ***** Episode 550, Mean Return = 3529.0, Mean Discounted Return = 13.4 *****
# ExplainedVarNew: -0.416
# ExplainedVarOld: -0.402
# ValFuncLoss: 227
#
#
# ***** Episode 560, Mean Return = 3581.6, Mean Discounted Return = 10.1 *****
# ExplainedVarNew: -0.405
# ExplainedVarOld: -0.42
# ValFuncLoss: 223
#
#
# ***** Episode 570, Mean Return = 3527.0, Mean Discounted Return = 10.6 *****
# ExplainedVarNew: -0.402
# ExplainedVarOld: -0.394
# ValFuncLoss: 229
# ***** Episode 580, Mean Return = 3415.2, Mean Discounted Return = 10.9 *****
# ExplainedVarNew: -0.415
# ExplainedVarOld: -0.417
# ValFuncLoss: 221
#
#
# ***** Episode 590, Mean Return = 3463.6, Mean Discounted Return = 9.4 *****
# ExplainedVarNew: -0.414
# ExplainedVarOld: -0.448
# ValFuncLoss: 205
#
#
# ***** Episode 600, Mean Return = 3521.0, Mean Discounted Return = 9.0 *****
# ExplainedVarNew: -0.388
# ExplainedVarOld: -0.376
# ValFuncLoss: 221
#
#
# ***** Episode 610, Mean Return = 3420.4, Mean Discounted Return = 9.9 *****
# ExplainedVarNew: -0.424
# ExplainedVarOld: -0.422
# ValFuncLoss: 208
#
#
# ***** Episode 620, Mean Return = 3531.8, Mean Discounted Return = 8.8 *****
# ExplainedVarNew: -0.388
# ExplainedVarOld: -0.376
# ValFuncLoss: 231
#
#
# ***** Episode 630, Mean Return = 1846.2, Mean Discounted Return = 5.5 *****
# ExplainedVarNew: -0.564
# ExplainedVarOld: -0.472
# ValFuncLoss: 117
#
#
# ***** Episode 640, Mean Return = 2107.0, Mean Discounted Return = 4.6 *****
# ExplainedVarNew: -0.502
# ExplainedVarOld: -0.485
# ValFuncLoss: 153
#
#
# ***** Episode 650, Mean Return = 1941.0, Mean Discounted Return = 7.2 *****
# ExplainedVarNew: -0.536
# ExplainedVarOld: -0.513
# ValFuncLoss: 137
#
#
# ***** Episode 660, Mean Return = 1965.0, Mean Discounted Return = 6.7 *****
# ExplainedVarNew: -0.534
# ExplainedVarOld: -0.568
# ValFuncLoss: 133
#
#
# ***** Episode 670, Mean Return = 1940.6, Mean Discounted Return = 7.0 *****
# ExplainedVarNew: -0.493
# ExplainedVarOld: -0.525
# ValFuncLoss: 130
#
#
# ***** Episode 680, Mean Return = 1917.6, Mean Discounted Return = 6.4 *****
# ExplainedVarNew: -0.504
# ExplainedVarOld: -0.479
# ValFuncLoss: 132
#
#
# ***** Episode 690, Mean Return = 1953.6, Mean Discounted Return = 8.5 *****
# ExplainedVarNew: -0.511
# ExplainedVarOld: -0.512
# ValFuncLoss: 133
#
#
# ***** Episode 700, Mean Return = 1990.0, Mean Discounted Return = 6.1 *****
# ExplainedVarNew: -0.507
# ExplainedVarOld: -0.499
# ValFuncLoss: 141
#
#
# ***** Episode 710, Mean Return = 2065.6, Mean Discounted Return = 6.5 *****
# ExplainedVarNew: -0.505
# ExplainedVarOld: -0.471
# ValFuncLoss: 156
#
#
# ***** Episode 720, Mean Return = 1895.2, Mean Discounted Return = 7.3 *****
# ExplainedVarNew: -0.566
# ExplainedVarOld: -0.583
# ValFuncLoss: 127
#
#
# ***** Episode 730, Mean Return = 1947.2, Mean Discounted Return = 6.1 *****
# ExplainedVarNew: -0.493
# ExplainedVarOld: -0.518
# ValFuncLoss: 134
#
#
# ***** Episode 740, Mean Return = 1971.0, Mean Discounted Return = 6.7 *****
# ExplainedVarNew: -0.541
# ExplainedVarOld: -0.492
# ValFuncLoss: 142
#
#
# ***** Episode 750, Mean Return = 2026.2, Mean Discounted Return = 6.0 *****
# ExplainedVarNew: -0.528
# ExplainedVarOld: -0.553
# ValFuncLoss: 142
#
#
# ***** Episode 760, Mean Return = 1966.8, Mean Discounted Return = 6.9 *****
# ExplainedVarNew: -0.548
# ExplainedVarOld: -0.57
# ValFuncLoss: 131
#
#
# ***** Episode 770, Mean Return = 1977.4, Mean Discounted Return = 5.4 *****
# ExplainedVarNew: -0.498
# ExplainedVarOld: -0.474
# ValFuncLoss: 145
#
#
# ***** Episode 780, Mean Return = 1944.2, Mean Discounted Return = 7.0 *****
# ExplainedVarNew: -0.53
# ExplainedVarOld: -0.529
# ValFuncLoss: 137
#
#
# ***** Episode 790, Mean Return = 1968.2, Mean Discounted Return = 5.9 *****
# ExplainedVarNew: -0.546
# ExplainedVarOld: -0.579
# ValFuncLoss: 129
#
#
# ***** Episode 800, Mean Return = 1985.8, Mean Discounted Return = 4.9 *****
# ExplainedVarNew: -0.503
# ExplainedVarOld: -0.51
# ValFuncLoss: 135
#
#
# ***** Episode 810, Mean Return = 1958.8, Mean Discounted Return = 6.5 *****
# ExplainedVarNew: -0.522
# ExplainedVarOld: -0.552
# ValFuncLoss: 124
#
#
# ***** Episode 820, Mean Return = 1953.2, Mean Discounted Return = 5.3 *****
# ExplainedVarNew: -0.488
# ExplainedVarOld: -0.475
# ValFuncLoss: 132
#
#
# ***** Episode 830, Mean Return = 2026.4, Mean Discounted Return = 6.7 *****
# ExplainedVarNew: -0.511
# ExplainedVarOld: -0.498
# ValFuncLoss: 138
#
#
# ***** Episode 840, Mean Return = 1999.6, Mean Discounted Return = 6.1 *****
# ExplainedVarNew: -0.515
# ExplainedVarOld: -0.497
# ValFuncLoss: 139
#
#
# ***** Episode 850, Mean Return = 1897.0, Mean Discounted Return = 5.4 *****
# ExplainedVarNew: -0.517
# ExplainedVarOld: -0.508
# ValFuncLoss: 130
#
#
# ***** Episode 860, Mean Return = 1953.8, Mean Discounted Return = 5.5 *****
# ExplainedVarNew: -0.521
# ExplainedVarOld: -0.554
# ValFuncLoss: 128
#
#
# ***** Episode 870, Mean Return = 2050.8, Mean Discounted Return = 7.1 *****
# ExplainedVarNew: -0.502
# ExplainedVarOld: -0.473
# ValFuncLoss: 147
#
#
# ***** Episode 880, Mean Return = 1952.8, Mean Discounted Return = 5.8 *****
# ExplainedVarNew: -0.536
# ExplainedVarOld: -0.531
# ValFuncLoss: 136
#
#
# ***** Episode 890, Mean Return = 1947.0, Mean Discounted Return = 6.5 *****
# ExplainedVarNew: -0.522
# ExplainedVarOld: -0.543
# ValFuncLoss: 133
#
#
# ***** Episode 900, Mean Return = 1912.8, Mean Discounted Return = 5.3 *****
# ExplainedVarNew: -0.51
# ExplainedVarOld: -0.553
# ValFuncLoss: 123
