# %%
import gym
import pybullet
import pybullet_envs
from gym import wrappers
from datetime import datetime

# DR TRPO related files
from train_helper import *
from value import NNValueFunction
from utils import Logger
from dr_policy import DRPolicyKL, DRPolicyWass

# %% [markdown]
# # Discrete State Space - KL DR TRPO Policy
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyKL(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 5000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-KL_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 60, Mean Return = -765.9, Mean Discounted Return = -39.9 *****
# ExplainedVarNew: -8.31e-09
# ExplainedVarOld: -4.01e-06
# ValFuncLoss: 676
#
#
# ***** Episode 120, Mean Return = -499.3, Mean Discounted Return = -29.1 *****
# ExplainedVarNew: -8.27e-10
# ExplainedVarOld: -8.8e-09
# ValFuncLoss: 108
#
#
# ***** Episode 180, Mean Return = -305.3, Mean Discounted Return = -20.1 *****
# ExplainedVarNew: -1.35e-08
# ExplainedVarOld: -3.09e-09
# ValFuncLoss: 103
#
#
# ***** Episode 240, Mean Return = -254.0, Mean Discounted Return = -15.9 *****
# ExplainedVarNew: -0.00981
# ExplainedVarOld: -2.01e-08
# ValFuncLoss: 49
#
#
# ***** Episode 300, Mean Return = -182.4, Mean Discounted Return = -12.0 *****
# ExplainedVarNew: -0.00545
# ExplainedVarOld: -0.0155
# ValFuncLoss: 29.4
#
#
# ***** Episode 360, Mean Return = -171.2, Mean Discounted Return = -13.6 *****
# ExplainedVarNew: -0.0015
# ExplainedVarOld: -0.0041
# ValFuncLoss: 26.6
#
#
# ***** Episode 420, Mean Return = -142.7, Mean Discounted Return = -11.1 *****
# ExplainedVarNew: -0.00177
# ExplainedVarOld: -0.000637
# ValFuncLoss: 26
#
#
# ***** Episode 480, Mean Return = -81.9, Mean Discounted Return = -8.0 *****
# ExplainedVarNew: -0.0237
# ExplainedVarOld: -0.00162
# ValFuncLoss: 47.8
#
#
# ***** Episode 540, Mean Return = -97.6, Mean Discounted Return = -9.7 *****
# ExplainedVarNew: -0.0118
# ExplainedVarOld: -0.0154
# ValFuncLoss: 33.2
#
#
# ***** Episode 600, Mean Return = -54.6, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.0169
# ExplainedVarOld: -0.0154
# ValFuncLoss: 53.7
#
#
# ***** Episode 660, Mean Return = -48.5, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.018
# ExplainedVarOld: -0.0196
# ValFuncLoss: 58.4
#
#
# ***** Episode 720, Mean Return = -57.4, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.0127
# ExplainedVarOld: -0.0157
# ValFuncLoss: 50.2
#
#
# ***** Episode 780, Mean Return = -44.8, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.00905
# ExplainedVarOld: -0.00994
# ValFuncLoss: 65.9
#
#
# ***** Episode 840, Mean Return = -49.6, Mean Discounted Return = -5.2 *****
# ExplainedVarNew: -0.0182
# ExplainedVarOld: -0.0144
# ValFuncLoss: 63.8
#
#
# ***** Episode 900, Mean Return = -32.5, Mean Discounted Return = -5.9 *****
# ExplainedVarNew: -0.0123
# ExplainedVarOld: -0.0116
# ValFuncLoss: 71.4
#
#
# ***** Episode 960, Mean Return = -32.5, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.0227
# ExplainedVarOld: -0.0249
# ValFuncLoss: 72.8
#
#
# ***** Episode 1020, Mean Return = -39.8, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.015
# ExplainedVarOld: -0.0107
# ValFuncLoss: 74.4
#
#
# ***** Episode 1080, Mean Return = -36.1, Mean Discounted Return = -5.2 *****
# ExplainedVarNew: -0.0374
# ExplainedVarOld: -0.0368
# ValFuncLoss: 71.1
#
#
# ***** Episode 1140, Mean Return = -33.8, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.0266
# ExplainedVarOld: -0.0304
# ValFuncLoss: 82.6
#
#
# ***** Episode 1200, Mean Return = -24.6, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.01
# ExplainedVarOld: -0.00994
# ValFuncLoss: 108
#
#
# ***** Episode 1260, Mean Return = -10.1, Mean Discounted Return = -3.4 *****
# ExplainedVarNew: -0.0197
# ExplainedVarOld: -0.0197
# ValFuncLoss: 98.5
#
#
# ***** Episode 1320, Mean Return = -21.8, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0457
# ExplainedVarOld: -0.0316
# ValFuncLoss: 88.3
#
#
# ***** Episode 1380, Mean Return = -19.6, Mean Discounted Return = -5.1 *****
# ExplainedVarNew: -0.00487
# ExplainedVarOld: -0.00422
# ValFuncLoss: 120
#
#
# ***** Episode 1440, Mean Return = -14.6, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.00801
# ExplainedVarOld: -0.00847
# ValFuncLoss: 129
#
#
# ***** Episode 1500, Mean Return = -12.4, Mean Discounted Return = -4.8 *****
# ExplainedVarNew: -0.0244
# ExplainedVarOld: -0.00693
# ValFuncLoss: 110
#
#
# ***** Episode 1560, Mean Return = -13.1, Mean Discounted Return = -4.1 *****
# ExplainedVarNew: -0.0478
# ExplainedVarOld: -0.0406
# ValFuncLoss: 127
#
#
# ***** Episode 1620, Mean Return = -27.6, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.00501
# ExplainedVarOld: -0.00913
# ValFuncLoss: 162
#
#
# ***** Episode 1680, Mean Return = -14.1, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0429
# ExplainedVarOld: -0.00986
# ValFuncLoss: 134
#
#
# ***** Episode 1740, Mean Return = -32.2, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0447
# ExplainedVarOld: -0.0408
# ValFuncLoss: 90.3
#
#
# ***** Episode 1800, Mean Return = -4.8, Mean Discounted Return = -3.1 *****
# ExplainedVarNew: -0.0535
# ExplainedVarOld: -0.0665
# ValFuncLoss: 111
#
#
# ***** Episode 1860, Mean Return = -14.9, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0352
# ExplainedVarOld: -0.0373
# ValFuncLoss: 151
#
#
# ***** Episode 1920, Mean Return = 0.3, Mean Discounted Return = -3.4 *****
# ExplainedVarNew: -0.0499
# ExplainedVarOld: -0.0768
# ValFuncLoss: 104
#
#
# ***** Episode 1980, Mean Return = -23.1, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0181
# ExplainedVarOld: -0.0153
# ValFuncLoss: 156
#
#
# ***** Episode 2040, Mean Return = -13.5, Mean Discounted Return = -5.3 *****
# ExplainedVarNew: -0.0504
# ExplainedVarOld: -0.032
# ValFuncLoss: 160
#
#
# ***** Episode 2100, Mean Return = -2.6, Mean Discounted Return = -3.3 *****
# ExplainedVarNew: -0.0939
# ExplainedVarOld: -0.0753
# ValFuncLoss: 119
#
#
# ***** Episode 2160, Mean Return = -13.0, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0286
# ExplainedVarOld: -0.0293
# ValFuncLoss: 152
#
#
# ***** Episode 2220, Mean Return = -3.3, Mean Discounted Return = -4.2 *****
# ExplainedVarNew: -0.0644
# ExplainedVarOld: -0.0467
# ValFuncLoss: 135
#
#
# ***** Episode 2280, Mean Return = -6.6, Mean Discounted Return = -2.8 *****
# ExplainedVarNew: -0.0586
# ExplainedVarOld: -0.0488
# ValFuncLoss: 144
#
#
# ***** Episode 2340, Mean Return = -4.0, Mean Discounted Return = -3.1 *****
# ExplainedVarNew: -0.0225
# ExplainedVarOld: -0.0192
# ValFuncLoss: 246
#
#
# ***** Episode 2400, Mean Return = -17.0, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -0.0198
# ExplainedVarOld: -0.0185
# ValFuncLoss: 200
#
#
# ***** Episode 2460, Mean Return = -1.2, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0562
# ExplainedVarOld: -0.0508
# ValFuncLoss: 132
#
#
# ***** Episode 2520, Mean Return = -13.9, Mean Discounted Return = -5.5 *****
# ExplainedVarNew: -0.0488
# ExplainedVarOld: -0.0532
# ValFuncLoss: 99.3
#
#
# ***** Episode 2580, Mean Return = 4.3, Mean Discounted Return = -2.8 *****
# ExplainedVarNew: -0.0849
# ExplainedVarOld: -0.0797
# ValFuncLoss: 108
#
#
# ***** Episode 2640, Mean Return = -11.9, Mean Discounted Return = -7.0 *****
# ExplainedVarNew: -0.0847
# ExplainedVarOld: -0.0502
# ValFuncLoss: 180
#
#
# ***** Episode 2700, Mean Return = -14.1, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0405
# ExplainedVarOld: -0.038
# ValFuncLoss: 196
#
#
# ***** Episode 2760, Mean Return = -26.8, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.0304
# ExplainedVarOld: -0.0372
# ValFuncLoss: 241
#
#
# ***** Episode 2820, Mean Return = -4.7, Mean Discounted Return = -5.5 *****
# ExplainedVarNew: -0.0766
# ExplainedVarOld: -0.0749
# ValFuncLoss: 155
#
#
# ***** Episode 2880, Mean Return = -16.0, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.202
# ExplainedVarOld: -0.0594
# ValFuncLoss: 139
#
#
# ***** Episode 2940, Mean Return = -8.6, Mean Discounted Return = -4.3 *****
# ExplainedVarNew: -0.0816
# ExplainedVarOld: -0.112
# ValFuncLoss: 165
#
#
# ***** Episode 3000, Mean Return = -11.7, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.0111
# ExplainedVarOld: -0.0117
# ValFuncLoss: 505
#
#
# ***** Episode 3060, Mean Return = -16.1, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -0.0269
# ExplainedVarOld: -0.0185
# ValFuncLoss: 305
#
#
# ***** Episode 3120, Mean Return = 4.1, Mean Discounted Return = -2.7 *****
# ExplainedVarNew: -0.106
# ExplainedVarOld: -0.132
# ValFuncLoss: 132
#
#
# ***** Episode 3180, Mean Return = -11.1, Mean Discounted Return = -5.3 *****
# ExplainedVarNew: -0.061
# ExplainedVarOld: -0.062
# ValFuncLoss: 136
#
#
# ***** Episode 3240, Mean Return = -8.9, Mean Discounted Return = -5.2 *****
# ExplainedVarNew: -0.0556
# ExplainedVarOld: -0.0553
# ValFuncLoss: 111
#
#
# ***** Episode 3300, Mean Return = -10.7, Mean Discounted Return = -3.3 *****
# ExplainedVarNew: -0.0258
# ExplainedVarOld: -0.0276
# ValFuncLoss: 118
#
#
# ***** Episode 3360, Mean Return = -13.2, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.0347
# ExplainedVarOld: -0.0318
# ValFuncLoss: 164
# ***** Episode 3420, Mean Return = -27.8, Mean Discounted Return = -6.0 *****
# ExplainedVarNew: -0.0228
# ExplainedVarOld: -0.0205
# ValFuncLoss: 197
#
#
# ***** Episode 3480, Mean Return = -5.6, Mean Discounted Return = -5.7 *****
# ExplainedVarNew: -0.049
# ExplainedVarOld: -0.048
# ValFuncLoss: 150
#
#
# ***** Episode 3540, Mean Return = -15.2, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0276
# ExplainedVarOld: -0.0351
# ValFuncLoss: 208
#
#
# ***** Episode 3600, Mean Return = -21.0, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0297
# ExplainedVarOld: -0.0238
# ValFuncLoss: 221
#
#
# ***** Episode 3660, Mean Return = -7.1, Mean Discounted Return = -3.8 *****
# ExplainedVarNew: -0.0413
# ExplainedVarOld: -0.0487
# ValFuncLoss: 194
#
#
# ***** Episode 3720, Mean Return = -6.6, Mean Discounted Return = -4.8 *****
# ExplainedVarNew: -0.0386
# ExplainedVarOld: -0.049
# ValFuncLoss: 179
#
#
# ***** Episode 3780, Mean Return = -16.1, Mean Discounted Return = -8.0 *****
# ExplainedVarNew: -0.0577
# ExplainedVarOld: -0.0408
# ValFuncLoss: 124
#
#
# ***** Episode 3840, Mean Return = -19.3, Mean Discounted Return = -4.7 *****
# ExplainedVarNew: -0.0209
# ExplainedVarOld: -0.0146
# ValFuncLoss: 280
#
#
# ***** Episode 3900, Mean Return = -10.1, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.0653
# ExplainedVarOld: -0.0847
# ValFuncLoss: 134
#
#
# ***** Episode 3960, Mean Return = -15.0, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.0237
# ExplainedVarOld: -0.0284
# ValFuncLoss: 165
#
#
# ***** Episode 4020, Mean Return = 0.7, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.0786
# ExplainedVarOld: -0.0879
# ValFuncLoss: 107
#
#
# ***** Episode 4080, Mean Return = -17.5, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0244
# ExplainedVarOld: -0.0246
# ValFuncLoss: 169
#
#
# ***** Episode 4140, Mean Return = -2.3, Mean Discounted Return = -3.2 *****
# ExplainedVarNew: -0.0401
# ExplainedVarOld: -0.0351
# ValFuncLoss: 116
#
#
# ***** Episode 4200, Mean Return = -7.6, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -0.0313
# ExplainedVarOld: -0.035
# ValFuncLoss: 112
#
#
# ***** Episode 4260, Mean Return = -18.2, Mean Discounted Return = -6.8 *****
# ExplainedVarNew: -0.0964
# ExplainedVarOld: -0.0244
# ValFuncLoss: 178
#
#
# ***** Episode 4320, Mean Return = -10.6, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0382
# ExplainedVarOld: -0.0356
# ValFuncLoss: 237
#
#
# ***** Episode 4380, Mean Return = -10.8, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.09
# ExplainedVarOld: -0.0733
# ValFuncLoss: 150
#
#
# ***** Episode 4440, Mean Return = -15.4, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.104
# ExplainedVarOld: -0.103
# ValFuncLoss: 161
#
#
# ***** Episode 4500, Mean Return = -2.3, Mean Discounted Return = -3.9 *****
# ExplainedVarNew: -0.134
# ExplainedVarOld: -0.116
# ValFuncLoss: 139
#
#
# ***** Episode 4560, Mean Return = -3.7, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -0.0573
# ExplainedVarOld: -0.0491
# ValFuncLoss: 138
#
#
# ***** Episode 4620, Mean Return = -10.7, Mean Discounted Return = -5.3 *****
# ExplainedVarNew: -0.17
# ExplainedVarOld: -0.159
# ValFuncLoss: 188
#
#
# ***** Episode 4680, Mean Return = -18.5, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.164
# ExplainedVarOld: -0.187
# ValFuncLoss: 159
#
#
# ***** Episode 4740, Mean Return = -22.4, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.0594
# ExplainedVarOld: -0.105
# ValFuncLoss: 132
#
#
# ***** Episode 4800, Mean Return = -25.1, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.0324
# ExplainedVarOld: -0.0316
# ValFuncLoss: 193
#
#
# ***** Episode 4860, Mean Return = -5.8, Mean Discounted Return = -4.7 *****
# ExplainedVarNew: -0.0858
# ExplainedVarOld: -0.0922
# ValFuncLoss: 138
#
#
# ***** Episode 4920, Mean Return = -6.4, Mean Discounted Return = -3.1 *****
# ExplainedVarNew: -0.0526
# ExplainedVarOld: -0.0687
# ValFuncLoss: 165
#
#
# ***** Episode 4980, Mean Return = -1.4, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.0433
# ExplainedVarOld: -0.0546
# ValFuncLoss: 146
#
#
# ***** Episode 5040, Mean Return = -7.6, Mean Discounted Return = -4.9 *****
# ExplainedVarNew: -0.0406
# ExplainedVarOld: -0.0389
# ValFuncLoss: 177

# %% [markdown]
# # Discrete State Space - Wasserstein DR TRPO Policy
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
pybullet.connect(pybullet.DIRECT)
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyWass(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 5000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-Wass_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()
# Out:
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 60, Mean Return = -768.6, Mean Discounted Return = -38.4 *****
# ExplainedVarNew: -6.23e-09
# ExplainedVarOld: -6.45e-06
# ValFuncLoss: 760
#
#
# ***** Episode 120, Mean Return = -704.8, Mean Discounted Return = -36.1 *****
# ExplainedVarNew: -6.48e-10
# ExplainedVarOld: -1.41e-08
# ValFuncLoss: 239
#
#
# ***** Episode 180, Mean Return = -675.8, Mean Discounted Return = -37.2 *****
# ExplainedVarNew: -5.75e-11
# ExplainedVarOld: -1.2e-10
# ValFuncLoss: 183
#
#
# ***** Episode 240, Mean Return = -607.8, Mean Discounted Return = -34.9 *****
# ExplainedVarNew: -1.21e-10
# ExplainedVarOld: -1.28e-10
# ValFuncLoss: 177
#
#
# ***** Episode 300, Mean Return = -599.6, Mean Discounted Return = -34.7 *****
# ExplainedVarNew: -2.62e-10
# ExplainedVarOld: -1.97e-10
# ValFuncLoss: 190
#
#
# ***** Episode 360, Mean Return = -542.6, Mean Discounted Return = -37.4 *****
# ExplainedVarNew: -1.05e-10
# ExplainedVarOld: -7.28e-11
# ValFuncLoss: 193
#
#
# ***** Episode 420, Mean Return = -529.2, Mean Discounted Return = -34.4 *****
# ExplainedVarNew: -0.000614
# ExplainedVarOld: -3.06e-10
# ValFuncLoss: 210
#
#
# ***** Episode 480, Mean Return = -434.9, Mean Discounted Return = -33.3 *****
# ExplainedVarNew: -0.00162
# ExplainedVarOld: -0.000518
# ValFuncLoss: 221
#
#
# ***** Episode 540, Mean Return = -477.5, Mean Discounted Return = -29.4 *****
# ExplainedVarNew: -0.0108
# ExplainedVarOld: -0.000908
# ValFuncLoss: 200
#
#
# ***** Episode 600, Mean Return = -393.5, Mean Discounted Return = -30.1 *****
# ExplainedVarNew: -0.0115
# ExplainedVarOld: -0.00947
# ValFuncLoss: 238
#
#
# ***** Episode 660, Mean Return = -342.9, Mean Discounted Return = -30.3 *****
# ExplainedVarNew: -0.0112
# ExplainedVarOld: -0.0117
# ValFuncLoss: 280
#
#
# ***** Episode 720, Mean Return = -343.1, Mean Discounted Return = -26.6 *****
# ExplainedVarNew: -0.0198
# ExplainedVarOld: -0.0104
# ValFuncLoss: 256
#
#
# ***** Episode 780, Mean Return = -405.7, Mean Discounted Return = -28.7 *****
# ExplainedVarNew: -0.0164
# ExplainedVarOld: -0.0161
# ValFuncLoss: 234
#
#
# ***** Episode 840, Mean Return = -384.5, Mean Discounted Return = -28.3 *****
# ExplainedVarNew: -0.0168
# ExplainedVarOld: -0.0179
# ValFuncLoss: 254
#
#
# ***** Episode 900, Mean Return = -222.5, Mean Discounted Return = -22.0 *****
# ExplainedVarNew: -0.0203
# ExplainedVarOld: -0.0169
# ValFuncLoss: 292
#
#
# ***** Episode 960, Mean Return = -236.9, Mean Discounted Return = -22.2 *****
# ExplainedVarNew: -0.0152
# ExplainedVarOld: -0.024
# ValFuncLoss: 267
#
#
# ***** Episode 1020, Mean Return = -272.9, Mean Discounted Return = -24.8 *****
# ExplainedVarNew: -0.0137
# ExplainedVarOld: -0.00799
# ValFuncLoss: 283
#
#
# ***** Episode 1080, Mean Return = -211.9, Mean Discounted Return = -21.3 *****
# ExplainedVarNew: -0.0327
# ExplainedVarOld: -0.0228
# ValFuncLoss: 283
#
#
# ***** Episode 1140, Mean Return = -243.9, Mean Discounted Return = -23.1 *****
# ExplainedVarNew: -0.0269
# ExplainedVarOld: -0.0602
# ValFuncLoss: 255
#
#
# ***** Episode 1200, Mean Return = -248.1, Mean Discounted Return = -20.5 *****
# ExplainedVarNew: -0.014
# ExplainedVarOld: -0.0135
# ValFuncLoss: 249
#
#
# ***** Episode 1260, Mean Return = -272.8, Mean Discounted Return = -25.3 *****
# ExplainedVarNew: -0.0229
# ExplainedVarOld: -0.017
# ValFuncLoss: 226
#
#
# ***** Episode 1320, Mean Return = -233.4, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -0.0268
# ExplainedVarOld: -0.0239
# ValFuncLoss: 220
#
#
# ***** Episode 1380, Mean Return = -151.8, Mean Discounted Return = -20.9 *****
# ExplainedVarNew: -0.0489
# ExplainedVarOld: -0.0636
# ValFuncLoss: 253
#
#
# ***** Episode 1440, Mean Return = -201.7, Mean Discounted Return = -20.7 *****
# ExplainedVarNew: -0.0306
# ExplainedVarOld: -0.0331
# ValFuncLoss: 229
#
#
# ***** Episode 1500, Mean Return = -155.0, Mean Discounted Return = -17.0 *****
# ExplainedVarNew: -0.0329
# ExplainedVarOld: -0.03
# ValFuncLoss: 225
#
#
# ***** Episode 1560, Mean Return = -214.0, Mean Discounted Return = -20.0 *****
# ExplainedVarNew: -0.0198
# ExplainedVarOld: -0.015
# ValFuncLoss: 210
#
#
# ***** Episode 1620, Mean Return = -183.6, Mean Discounted Return = -19.6 *****
# ExplainedVarNew: -0.0296
# ExplainedVarOld: -0.024
# ValFuncLoss: 214
#
#
# ***** Episode 1680, Mean Return = -124.4, Mean Discounted Return = -16.2 *****
# ExplainedVarNew: -0.0282
# ExplainedVarOld: -0.05
# ValFuncLoss: 215
#
#
# ***** Episode 1740, Mean Return = -123.0, Mean Discounted Return = -17.3 *****
# ExplainedVarNew: -0.0322
# ExplainedVarOld: -0.0339
# ValFuncLoss: 217
#
#
# ***** Episode 1800, Mean Return = -124.6, Mean Discounted Return = -18.5 *****
# ExplainedVarNew: -0.0415
# ExplainedVarOld: -0.0286
# ValFuncLoss: 182
#
#
# ***** Episode 1860, Mean Return = -182.7, Mean Discounted Return = -19.9 *****
# ExplainedVarNew: -0.0411
# ExplainedVarOld: -0.0703
# ValFuncLoss: 215
#
#
# ***** Episode 1920, Mean Return = -135.5, Mean Discounted Return = -16.9 *****
# ExplainedVarNew: -0.0321
# ExplainedVarOld: -0.0319
# ValFuncLoss: 184
#
#
# ***** Episode 1980, Mean Return = -154.7, Mean Discounted Return = -16.7 *****
# ExplainedVarNew: -0.0535
# ExplainedVarOld: -0.0432
# ValFuncLoss: 164
#
#
# ***** Episode 2040, Mean Return = -138.5, Mean Discounted Return = -16.5 *****
# ExplainedVarNew: -0.0448
# ExplainedVarOld: -0.0602
# ValFuncLoss: 183
#
#
# ***** Episode 2100, Mean Return = -115.1, Mean Discounted Return = -15.4 *****
# ExplainedVarNew: -0.0495
# ExplainedVarOld: -0.0587
# ValFuncLoss: 183
#
#
# ***** Episode 2160, Mean Return = -134.9, Mean Discounted Return = -17.2 *****
# ExplainedVarNew: -0.035
# ExplainedVarOld: -0.0358
# ValFuncLoss: 192
#
#
# ***** Episode 2220, Mean Return = -99.8, Mean Discounted Return = -16.6 *****
# ExplainedVarNew: -0.0329
# ExplainedVarOld: -0.0321
# ValFuncLoss: 196
#
#
# ***** Episode 2280, Mean Return = -100.4, Mean Discounted Return = -16.2 *****
# ExplainedVarNew: -0.046
# ExplainedVarOld: -0.0397
# ValFuncLoss: 175
#
#
# ***** Episode 2340, Mean Return = -73.4, Mean Discounted Return = -10.8 *****
# ExplainedVarNew: -0.0424
# ExplainedVarOld: -0.0463
# ValFuncLoss: 198
#
#
# ***** Episode 2400, Mean Return = -118.6, Mean Discounted Return = -13.8 *****
# ExplainedVarNew: -0.0415
# ExplainedVarOld: -0.0409
# ValFuncLoss: 157
#
#
# ***** Episode 2460, Mean Return = -92.4, Mean Discounted Return = -14.3 *****
# ExplainedVarNew: -0.0396
# ExplainedVarOld: -0.0392
# ValFuncLoss: 162
#
#
# ***** Episode 2520, Mean Return = -131.7, Mean Discounted Return = -16.8 *****
# ExplainedVarNew: -0.0422
# ExplainedVarOld: -0.0382
# ValFuncLoss: 177
#
#
# ***** Episode 2580, Mean Return = -65.7, Mean Discounted Return = -12.9 *****
# ExplainedVarNew: -0.0493
# ExplainedVarOld: -0.0516
# ValFuncLoss: 163
#
#
# ***** Episode 2640, Mean Return = -113.2, Mean Discounted Return = -13.8 *****
# ExplainedVarNew: -0.0598
# ExplainedVarOld: -0.0732
# ValFuncLoss: 137
#
#
# ***** Episode 2700, Mean Return = -87.6, Mean Discounted Return = -13.3 *****
# ExplainedVarNew: -0.0451
# ExplainedVarOld: -0.0419
# ValFuncLoss: 169
#
#
# ***** Episode 2760, Mean Return = -75.4, Mean Discounted Return = -11.2 *****
# ExplainedVarNew: -0.0389
# ExplainedVarOld: -0.0368
# ValFuncLoss: 164
#
#
# ***** Episode 2820, Mean Return = -109.0, Mean Discounted Return = -15.2 *****
# ExplainedVarNew: -0.0414
# ExplainedVarOld: -0.0418
# ValFuncLoss: 127
#
#
# ***** Episode 2880, Mean Return = -144.7, Mean Discounted Return = -13.1 *****
# ExplainedVarNew: -0.0431
# ExplainedVarOld: -0.0502
# ValFuncLoss: 114
#
#
# ***** Episode 2940, Mean Return = -121.1, Mean Discounted Return = -16.6 *****
# ExplainedVarNew: -0.0249
# ExplainedVarOld: -0.0249
# ValFuncLoss: 115
#
#
# ***** Episode 3000, Mean Return = -107.3, Mean Discounted Return = -12.3 *****
# ExplainedVarNew: -0.0626
# ExplainedVarOld: -0.0614
# ValFuncLoss: 126
#
#
# ***** Episode 3060, Mean Return = -109.8, Mean Discounted Return = -10.6 *****
# ExplainedVarNew: -0.0596
# ExplainedVarOld: -0.0536
# ValFuncLoss: 146
#
#
# ***** Episode 3120, Mean Return = -104.7, Mean Discounted Return = -13.0 *****
# ExplainedVarNew: -0.0754
# ExplainedVarOld: -0.0723
# ValFuncLoss: 138
#
#
# ***** Episode 3180, Mean Return = -131.6, Mean Discounted Return = -13.0 *****
# ExplainedVarNew: -0.0526
# ExplainedVarOld: -0.0542
# ValFuncLoss: 91.7
#
#
# ***** Episode 3240, Mean Return = -69.2, Mean Discounted Return = -10.1 *****
# ExplainedVarNew: -0.0591
# ExplainedVarOld: -0.0558
# ValFuncLoss: 102
#
#
# ***** Episode 3300, Mean Return = -99.0, Mean Discounted Return = -12.3 *****
# ExplainedVarNew: -0.0434
# ExplainedVarOld: -0.0823
# ValFuncLoss: 82.9
#
#
# ***** Episode 3360, Mean Return = -68.9, Mean Discounted Return = -10.8 *****
# ExplainedVarNew: -0.0386
# ExplainedVarOld: -0.0392
# ValFuncLoss: 98.2
# ***** Episode 3420, Mean Return = -76.2, Mean Discounted Return = -11.2 *****
# ExplainedVarNew: -0.0538
# ExplainedVarOld: -0.0518
# ValFuncLoss: 95.6
#
#
# ***** Episode 3480, Mean Return = -138.2, Mean Discounted Return = -13.3 *****
# ExplainedVarNew: -0.0319
# ExplainedVarOld: -0.0325
# ValFuncLoss: 105
#
#
# ***** Episode 3540, Mean Return = -98.6, Mean Discounted Return = -11.2 *****
# ExplainedVarNew: -0.0474
# ExplainedVarOld: -0.0559
# ValFuncLoss: 91.5
#
#
# ***** Episode 3600, Mean Return = -76.9, Mean Discounted Return = -10.5 *****
# ExplainedVarNew: -0.0599
# ExplainedVarOld: -0.0559
# ValFuncLoss: 80.5
#
#
# ***** Episode 3660, Mean Return = -68.5, Mean Discounted Return = -9.4 *****
# ExplainedVarNew: -0.073
# ExplainedVarOld: -0.0875
# ValFuncLoss: 71.7
#
#
# ***** Episode 3720, Mean Return = -87.8, Mean Discounted Return = -10.5 *****
# ExplainedVarNew: -0.0546
# ExplainedVarOld: -0.0523
# ValFuncLoss: 91.1
#
#
# ***** Episode 3780, Mean Return = -49.1, Mean Discounted Return = -8.9 *****
# ExplainedVarNew: -0.0458
# ExplainedVarOld: -0.0462
# ValFuncLoss: 85.6
#
#
# ***** Episode 3840, Mean Return = -82.4, Mean Discounted Return = -11.6 *****
# ExplainedVarNew: -0.0633
# ExplainedVarOld: -0.0558
# ValFuncLoss: 89
#
#
# ***** Episode 3900, Mean Return = -88.1, Mean Discounted Return = -9.4 *****
# ExplainedVarNew: -0.045
# ExplainedVarOld: -0.044
# ValFuncLoss: 94.6
#
#
# ***** Episode 3960, Mean Return = -73.1, Mean Discounted Return = -7.9 *****
# ExplainedVarNew: -0.0749
# ExplainedVarOld: -0.0652
# ValFuncLoss: 90.9
#
#
# ***** Episode 4020, Mean Return = -73.0, Mean Discounted Return = -9.3 *****
# ExplainedVarNew: -0.0561
# ExplainedVarOld: -0.0643
# ValFuncLoss: 68.6
#
#
# ***** Episode 4080, Mean Return = -96.4, Mean Discounted Return = -9.9 *****
# ExplainedVarNew: -0.0224
# ExplainedVarOld: -0.0339
# ValFuncLoss: 87
#
#
# ***** Episode 4140, Mean Return = -76.4, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -0.0753
# ExplainedVarOld: -0.0611
# ValFuncLoss: 79.8
#
#
# ***** Episode 4200, Mean Return = -91.8, Mean Discounted Return = -9.1 *****
# ExplainedVarNew: -0.0187
# ExplainedVarOld: -0.0182
# ValFuncLoss: 209
#
#
# ***** Episode 4260, Mean Return = -71.9, Mean Discounted Return = -9.7 *****
# ExplainedVarNew: -0.0396
# ExplainedVarOld: -0.0471
# ValFuncLoss: 106
#
#
# ***** Episode 4320, Mean Return = -89.6, Mean Discounted Return = -10.0 *****
# ExplainedVarNew: -0.0413
# ExplainedVarOld: -0.0473
# ValFuncLoss: 64.9
#
#
# ***** Episode 4380, Mean Return = -114.7, Mean Discounted Return = -9.6 *****
# ExplainedVarNew: -0.0307
# ExplainedVarOld: -0.0276
# ValFuncLoss: 59.7
#
#
# ***** Episode 4440, Mean Return = -82.1, Mean Discounted Return = -9.7 *****
# ExplainedVarNew: -0.022
# ExplainedVarOld: -0.0743
# ValFuncLoss: 53.4
#
#
# ***** Episode 4500, Mean Return = -54.7, Mean Discounted Return = -8.2 *****
# ExplainedVarNew: -0.0344
# ExplainedVarOld: -0.0239
# ValFuncLoss: 78.3
#
#
# ***** Episode 4560, Mean Return = -63.8, Mean Discounted Return = -8.0 *****
# ExplainedVarNew: -0.0712
# ExplainedVarOld: -0.0405
# ValFuncLoss: 59.4
#
#
# ***** Episode 4620, Mean Return = -70.6, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.0465
# ExplainedVarOld: -0.0396
# ValFuncLoss: 66.5
#
#
# ***** Episode 4680, Mean Return = -73.6, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.036
# ExplainedVarOld: -0.0366
# ValFuncLoss: 81.1
#
#
# ***** Episode 4740, Mean Return = -61.7, Mean Discounted Return = -6.9 *****
# ExplainedVarNew: -0.0701
# ExplainedVarOld: -0.079
# ValFuncLoss: 65.4
#
#
# ***** Episode 4800, Mean Return = -58.2, Mean Discounted Return = -6.2 *****
# ExplainedVarNew: -0.0522
# ExplainedVarOld: -0.0624
# ValFuncLoss: 61.7
#
#
# ***** Episode 4860, Mean Return = -75.1, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.175
# ExplainedVarOld: -0.0374
# ValFuncLoss: 69.3
#
#
# ***** Episode 4920, Mean Return = -68.9, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.0526
# ExplainedVarOld: -0.0569
# ValFuncLoss: 60.1
#
#
# ***** Episode 4980, Mean Return = -30.7, Mean Discounted Return = -6.9 *****
# ExplainedVarNew: -0.111
# ExplainedVarOld: -0.0955
# ValFuncLoss: 86.6
#
#
# ***** Episode 5040, Mean Return = -76.2, Mean Discounted Return = -9.1 *****
# ExplainedVarNew: -0.0372
# ExplainedVarOld: -0.0448
# ValFuncLoss: 92.9
